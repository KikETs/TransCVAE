# %%
from rdkit import Chem
from rdkit.Chem import AllChem
from group_selfies import(
    fragment_mols,
    Group,
    MolecularGraph,
    GroupGrammar,
    group_encoder
)
from rdkit.Chem.Draw import IPythonConsole
from rdkit import RDLogger
from psmiles import PolymerSmiles as PS
import numpy as np
import pandas as pd
import selfies as sf
RDLogger.DisableLog('rdApp.*')
import re
from group_selfies import grammar_rules as gr
gr._PROCESS_ATOM_CACHE.clear()

# %%
# %load_ext autoreload
# %autoreload 2

# %%
df = pd.read_csv("simulation-trajectory-aggregate.csv")
df.head()
# Out:
#    Trajectory ID                         SMILES  Molality  \
# 0           9425        COCC(CNCC(CF)OC(=O)*)O*      1.40
# 1           9426     O=C(CCNC(=O)COC(=O)*)NCCN*      1.47
# 2           9427    NC(=O)C(COC(=O)*)NC(=O)CCO*      1.44
# 3           9428  CC(COC(=O)*)COC(=O)C(C)(C)CO*      1.43
# 4           9429   COC(=O)CC(=O)NC(CO*)COC(=O)*      1.47
#
#    Monomer Molecular Weight  Degree of Polymerization  Density  CONDUCTIVITY  \
# 0                     468.0                      19.0     1.35      0.000076
# 1                     476.0                      13.0     1.46      0.000069
# 2                     463.0                      17.0     1.53      0.000104
# 3                     477.0                      16.0     1.28      0.000027
# 4                     478.0                      26.0     1.49      0.000039
#
#    TFSI Diffusivity  Li Diffusivity  Poly Diffusivity  Transference Number
# 0      3.230000e-08    1.260000e-08      1.530000e-08              -0.1630
# 1      1.320000e-08    1.110000e-08      8.640000e-09               0.3180
# 2      1.400000e-08    1.950000e-08      9.180000e-09               0.5300
# 3      2.420000e-08    1.190000e-08      1.400000e-08              -0.3190
# 4      1.350000e-08    6.580000e-09      8.670000e-09               0.0806

# %%
smiles = df.iloc[:,1].values
ess = GroupGrammar.essential_set()
psmiles = [PS(s).canonicalize.psmiles for s in smiles]
gpselfies = [ess.full_encoder(Chem.MolFromSmiles(s)) for s in psmiles]

# %%
from rdkit import Chem
from group_selfies import group_grammar
from group_selfies.group_decoder import (
    _tokenize_selfies, Counter,
    selfies_to_graph_iterative, form_rings_bilocally_iterative
)

def decode_keep_star(grammar, selfies, sanitize=False, verbose=False):
    """
    Group SELFIES → RDKit Mol, but KEEP '*' dummy atoms (do not H-cap).
    """
    rings = []
    place_from_idx = {}
    inverse_place = []
    dummy_counter = Counter(1)
    group_atom = {}

    mol = selfies_to_graph_iterative(
        grammar=grammar,
        symbol_iter=_tokenize_selfies(selfies),
        selfies=selfies,
        rings=rings,
        dummy_counter=dummy_counter,
        place_from_idx=place_from_idx,
        inverse_place=inverse_place,
        verbose=verbose,
        group_atom=group_atom,
    )
    form_rings_bilocally_iterative(
        mol, rings, place_from_idx, inverse_place,
        dummy_counter, group_atom, verbose=verbose
    )

    res = mol.GetMol()  # convert RWMol→Mol
    if sanitize:
        # 기본 Sanitize는 '*'에도 대체로 안전하지만 필요시 제약 완화
        Chem.SanitizeMol(res, sanitizeOps=Chem.SanitizeFlags.SANITIZE_NONE)
    return res
psmiles_dec = [decode_keep_star(ess, s) for s in gpselfies]
print(psmiles_dec)
# Out:
# [<rdkit.Chem.rdchem.Mol object at 0x7fdb405f68f0>, <rdkit.Chem.rdchem.Mol object at 0x7fdb405f6d50>, <rdkit.Chem.rdchem.Mol object at 0x7fdb405f5b60>, <rdkit.Chem.rdchem.Mol object at 0x7fdb405bace0>, <rdkit.Chem.rdchem.Mol object at 0x7fdb405bb610>, <rdkit.Chem.rdchem.Mol object at 0x7fdb405bab20>, <rdkit.Chem.rdchem.Mol object at 0x7fdb405ba490>, <rdkit.Chem.rdchem.Mol object at 0x7fdb405ba5e0>, <rdkit.Chem.rdchem.Mol object at 0x7fdb405b9310>, <rdkit.Chem.rdchem.Mol object at 0x7fdb405bb680>, <rdkit.Chem.rdchem.Mol object at 0x7fdb405ba6c0>, <rdkit.Chem.rdchem.Mol object at 0x7fdb405bb760>, <rdkit.Chem.rdchem.Mol object at 0x7fdb405bb6f0>, <rdkit.Chem.rdchem.Mol object at 0x7fdb405ba8f0>, <rdkit.Chem.rdchem.Mol object at 0x7fdb405b93f0>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40472260>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40470dd0>, <rdkit.Chem.rdchem.Mol object at 0x7fdb404722d0>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40470f90>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40471540>, <rdkit.Chem.rdchem.Mol object at 0x7fdb404710e0>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40471000>, <rdkit.Chem.rdchem.Mol object at 0x7fdb404712a0>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40471150>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40471380>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40471230>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40471070>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40471310>, <rdkit.Chem.rdchem.Mol object at 0x7fdb404713f0>, <rdkit.Chem.rdchem.Mol object at 0x7fdb404715b0>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40471620>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40471700>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40471690>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40470e40>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40471770>, <rdkit.Chem.rdchem.Mol object at 0x7fdb404718c0>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40470eb0>, <rdkit.Chem.rdchem.Mol object at 0x7fdb404717e0>, <rdkit.Chem.rdchem.Mol object at 0x7fdb404723b0>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40471930>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40472340>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40471850>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40472570>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40472420>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40472500>, <rdkit.Chem.rdchem.Mol object at 0x7fdb404726c0>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40472650>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40471fc0>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40472730>, <rdkit.Chem.rdchem.Mol object at 0x7fdb404727a0>, <rdkit.Chem.rdchem.Mol object at 0x7fdb404725e0>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40472880>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40472810>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40472960>, <rdkit.Chem.rdchem.Mol object at 0x7fdb404729d0>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40472ab0>, <rdkit.Chem.rdchem.Mol object at 0x7fdb404728f0>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40472b90>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40472a40>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40472c70>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40472b20>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40472d50>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40472c00>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40472dc0>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40472ce0>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40472e30>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40472f10>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40472ea0>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40472f80>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40473060>, <rdkit.Chem.rdchem.Mol object at 0x7fdb404730d0>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40472ff0>, <rdkit.Chem.rdchem.Mol object at 0x7fdb404731b0>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40473140>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40473290>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40473220>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40473300>, <rdkit.Chem.rdchem.Mol object at 0x7fdb404733e0>, <rdkit.Chem.rdchem.Mol object at 0x7fdb40473370>, <rdkit.Chem.rdchem.Mol object at 0x7fdb404734c0>, ...

# %%
psmiless = [PS(Chem.MolToSmiles(s)).canonicalize.psmiles for s in psmiles_dec]
print(psmiless)
# Out:
# ['[*]CNCC(CF)OC(=O)OC([*])COC', '[*]CCNC(=O)COC(=O)NCCNC([*])=O', '[*]COC(=O)OCCC(=O)NC([*])C(N)=O', '[*]COC(=O)OCC(C)(C)C(=O)OCC([*])C', '[*]COC(=O)OCC([*])NC(=O)CC(=O)OC', '[*]COC(=O)OC([*])CNC(=O)CC(=O)OC', '[*]OC(=O)OC(C)(C)C(C)NC(=O)C([*])C', '[*]CCN(C)C(=O)CCNC(=O)OC([*])C', '[*]CNC(COC(=O)OC([*])C)C(N)=O', '[*]COC(=O)OC([*])CNC(=O)NC(C)C', '[*]COC(=O)OCC([*])(C)NC(=O)CC#N', '[*]CNCC(C)OC(=O)OC([*])CSC', '[*]NC(=O)NCCNC(=O)C([*])CC#C', '[*]CC(C)OC(=O)OCC(C)N([*])CCC', '[*]COC(=O)OCCC(=O)NC([*])CCOC', '[*]CN(C)CC(C)(OC(=O)OC([*])C)C(F)F', '[*]CCCCOC(=O)NCCN([*])CC', '[*]COC(=O)NC([*])C(=O)NCCOCC', '[*]CCOC(=O)OC(C)(C)CCN([*])CCC', '[*]COC(=O)OC([*])CNC(CC)CCC', '[*]COC(=O)OCC([*])NC(=S)NCOC', '[*]C(=O)N(C)CCOC(=O)OC(C)C([*])CC', '[*]CCNC(=O)NCCN([*])C(CC)CCC', '[*]COC(=O)OCC([*])NC(=O)OC', '[*]COC(=O)OCCC(C)(C)NC(=O)C([*])=C', '[*]COC(=O)OCC([*])NC(=O)CCCCC', '[*]OC(=O)OCCN(C)C(=O)C([*])C(C)C', '[*]CCOC(=O)OCCC(=O)N([*])C', '[*]COC(=O)OC([*])CN(C)C(C)C(=O)OC', '[*]COC(=O)OC(C)C([*])NC(=S)NC', '[*]CNC(=O)CCCCCNC(=O)NC([*])C', '[*]CNC(=O)OCC(C)(C)NC(=O)C([*])C', '[*]COC(=O)OCCCS(=O)(=O)CC([*])C', '[*]NC(=O)NC(C)CCNC(=O)C([*])COC', '[*]NC(=O)OCCCNC(=O)C([*])CCCC', '[*]OC(=O)OCC(C#N)NC(=O)C([*])C(C)C', '[*]CNC(=O)NCCOCC(=O)N(C)C([*])C', '[*]CNCC(C)OC(=O)OC([*])C(=O)NC', '[*]CCOC(=O)OCCS(=O)(=O)C([*])C', '[*]CNC(=O)OC([*])CN(C)CC(=C)Cl', '[*]COC(=O)OCC(=O)NC([*])(C)CC', '[*]COC(=O)OC([*])CN(C)C(=O)C(C)C#N', '[*]CNC(=O)COCCNC(=O)NC([*])CC', '[*]CCNC(=O)OC([*])C=C', '[*]CC(=O)NCCCOC(=O)NC([*])C', '[*]COC(=O)OC([*])CNC(=O)C#CC', '[*]COC(=O)OCC([*])(C)C(=O)OCC(F)F', '[*]CNC(=O)OC([*])CNC(CC)CCC', '[*]NC(=O)NCCCN(C)C(=O)C([*])C', '[*]COC(=O)OCC(=O)NC([*])(C)C', '[*]CCCNC(=O)C(C)OC(=O)OC([*])C', '[*]CCCC(=O)OCC(C)OC(=O)OC([*])C', '[*]CNC(=O)NCC(=O)NC([*])CCCC', '[*]COC(=O)OC([*])CN(C)C(=O)C(C)CC', '[*]COC(=O)OCC([*])(C)C(=O)OCC#CC', '[*]COC(=O)OC([*])CN(C)CCSC', '[*]NC(=O)C(C)(C)OC(=O)OC(C)C([*])CC', '[*]COC(=O)OCC([*])NCCCCC', '[*]CNC(=O)OC([*])CNC(=O)C(C)NCC', '[*]CCOC(=O)NCCC(=O)NC([*])C', '[*]COC(=O)NC([*])C(=O)NCC(C)NCC', '[*]COC(=O)C(C)(C)OC(=O)OC([*])C', '[*]CCNC(=O)C(OC(=O)OC([*])C)C(C)C', '[*]COC(=O)OC(C)CCNC([*])(C)COC', '[*]CNC(C)C(C)OC(=O)OC([*])COC', '[*]CCNC(=O)OCCN([*])CCCC(=O)O', '[*]OC(=O)OCC(CC(F)F)NC(=O)C([*])C', '[*]CNC(=O)NCC(C)N(C)C(=O)C([*])C', '[*]COC(=O)OC(CNC([*])CC)C(=O)OC', '[*]CCOC(=O)OCCC(C)NC([*])COC', '[*]CN(C)C(=O)CC(C)(C)OC(=O)OC([*])C', '[*]CNC(=O)NC(C)(C)C(=O)NCC([*])C', '[*]OC(=O)OC(C(=O)O)C([*])CCCCC', '[*]CCN(C)CCNC(=O)OC([*])C', '[*]COC(=O)OC([*])CN(CC(=O)O)C(C)C', '[*]CCC(=O)NCCNC(=O)NC([*])(C)C', '[*]COC(=O)OC(C)(C)CC(=O)N(C)C([*])C', '[*]CNC(=O)CNCCNC(=O)NC([*])CC', '[*]COC(=O)OCC([*])(C)CSCC(N)=O', '[*]CNC(=O)CC(C)NC(=O)NCC([*])C', '[*]OC(=O)OC(C)(C)CN(C)C(=O)C([*])C', '[*]NC(=O)NC(C)CNC(=O)C([*])CC', '[*]OC(=O)NC(C(O)=NO)C([*])C', '[*]COC(=O)OC(C)CNC([*])CC#CC', '[*]COC(=O)OC([*])CN(C)CC(=O)O', '[*]COC(=O)OCC([*])(C)NC(=O)C(C)C', '[*]OC(=O)OCC(NC(=O)C(C)(C)C)C([*])C', '[*]CN(C)C(C)COC(=O)OC([*])C', '[*]CS(=O)(=O)C(C)COC(=O)OC([*])C', '[*]OC(=O)OCC(F)(F)CNC(=O)C([*])C', '[*]COC(=O)OC(CC)CNC([*])CC', '[*]COC(=O)NCC(C)(C)C(=O)NC([*])CC', '[*]CNCCCCCCOC(=O)OC([*])C', '[*]CNC(=O)CC(CC)OC(=O)OC([*])CC', '[*]CNC(=O)OC([*])CNC(=O)C(C)CC', '[*]CNC(=O)C(C)CNC(=O)NC([*])C', '[*]CC(C)(C)CNC(=O)COC(=O)OC([*])C', '[*]CNC(=O)OC([*])C(=O)NCC(C)(C)CC#N', '[*]COC(=O)OCC([*])(C)NC(=O)CN(C)C', '[*]CNC(=O)C(C)C(C)NC(=O)NC([*])C', '[*]COC(=O)OC(C)C([*])NC(=O)C=CC=CC', '[*]COC(=O)OCC([*])(C)Cl', '[*]COC(=O)OCC([*])NCC(=O)NCC=C', '[*]CNC(=O)NCC([*])NC(C)COC', '[*]CC(C)(C)OC(=O)OC([*])CNC(C)CC', '[*]NC(=O)NCCNC(=O)C(C)C([*])C', '[*]CNC(COC(=O)OC([*])C=C)C(F)(F)F', '[*]OC(=O)OCC(C)(C)NC(=O)C([*])C(C)C', '[*]COC(=O)NC([*])C#C', '[*]CC(C)(C)CNC(=O)NCCC(=O)N([*])C', '[*]CN(CCCF)CCOC(=O)OC([*])C', '[*]COC(=O)NC([*])C(=O)NCC(C)CNC', '[*]COC(=O)OCC([*])(C)NC(=O)C(C)(C)C', '[*]C#CC#CC=CCOC(=O)OC([*])CC', '[*]CNC(=O)OC([*])CC(=O)N(C)CC(C)C', '[*]COC(=O)OCC([*])NC(=O)C=CSC', '[*]COC(=O)OC(C)C(=O)NC([*])CC=CC', '[*]CNC(=O)N ...
