# %%
import torch
import numpy as np
import torch.nn as nn
import pandas as pd
from psmiles import PolymerSmiles as PS
from torch.utils.data import DataLoader, Dataset, random_split
from rdkit import Chem
from rdkit.Chem import Draw
from PIL import Image
from scipy.sparse import csr_matrix, lil_matrix
import atomInSmiles
from collections import Counter
from IPython.display import clear_output, display
import ipywidgets as widgets
from tqdm.notebook import tqdm
import os
import sys
import matplotlib.pyplot as plt
from matplotlib.ticker import LogFormatter, LogLocator, LogFormatterMathtext
from typing import List, Dict, Tuple
from torch.distributions import Normal, kl_divergence
import torch.nn.functional as F
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
os.environ['CUDA_VISIBLE_DEVICES'] = "0"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#device=torch.device('cpu')
print(device)
# os.chdir("C:\\Users\\user\\test.venv")
# print(os.getcwd())
from sklearn.preprocessing import MinMaxScaler, FunctionTransformer
from sklearn.pipeline import Pipeline

log_transformer = FunctionTransformer(np.log1p, validate=True)
log_minmax_pipeline = Pipeline(steps=[
    ('log', log_transformer),
    ('minmax', MinMaxScaler())
])
# Out:
# cuda

# %%
mm_scaler = MinMaxScaler()
class load_data(Dataset):
    def __init__(self, path):
        #csv 읽기
        self.raw = pd.read_csv(path)

        #SMILES
        self.SMILES = self.raw.iloc[:, 1:2].values
        self.SMILES = np.squeeze(self.SMILES)

        #Li-ion Conductivity
        self.conductivity = self.raw.iloc[:, 6:7].values
        self.conductivity = mm_scaler.fit_transform(self.conductivity.reshape(-1, 1))
        self.conductivity = log_minmax_pipeline.fit_transform(self.conductivity.reshape(-1, 1))

        #Degree of Polymerization
        self.DP = self.raw.iloc[:, 4:5].values
        self.DP = mm_scaler.fit_transform(self.DP.reshape(-1, 1))

        #Transfer Number
        self.tn = self.raw.iloc[:, 10:11].values
        self.tn = mm_scaler.fit_transform(self.tn.reshape(-1, 1))

        self.properties = np.concat((self.conductivity, self.DP, self.tn), axis=-1)
        mean_vec = self.properties.mean(axis=0)
        std_vec  = self.properties.std(axis=0)
        self.properties = (self.properties - mean_vec) / std_vec  # 정규화된 3차원 조건 벡터

        #PSMILES 변환
        psmiles = []
        for smiles in self.SMILES:
            ps = PS(smiles)
            ps.canonicalize
            psmiles.append(ps.psmiles)

        #Atom-In-SMILES Encoding
        ais_encoding = []
        for smiles in psmiles:
            ais_encoding.append(atomInSmiles.encode(smiles))
        

        #Atom-In-SMILES Tokenization (Encoder)
        ais_tokens = []
        for smiles in ais_encoding:
            ais_tokens.append(atomInSmiles.smiles_tokenizer("[SOS] " + smiles +" [EOS]"))

        max_len = len(max(ais_encoding, key=len)) + 1
        self.max_len = max_len
        print("max sequence length : ", max_len)

        #vocab 구성
        corpus = []
        for frags in ais_tokens:
            corpus.extend(frags)
        corpus.append("[PAD]")
        token_count = Counter(corpus)
        vocab = { token:i for i, (token, count) in enumerate(sorted(token_count.items(), key=lambda x: x[1], reverse=True))}
        vocab_size = len(vocab)
        
        self.vocab = vocab

        num_data = len(ais_tokens)
        print(vocab)

        ais_tokens_enc = ais_tokens
        ais_tokens_enc = [[tok for tok in tokens if tok not in ['[SOS]', '[EOS]']] for tokens in ais_tokens_enc]

        ais_tokens_dec_input = ais_tokens
        ais_tokens_dec_input = [[tok for tok in tokens if tok not in ['[EOS]']] for tokens in ais_tokens_dec_input]

        ais_tokens_dec_output = ais_tokens
        ais_tokens_dec_output = [[tok for tok in tokens if tok not in ['[SOS]']] for tokens in ais_tokens_dec_output]

        #Tokens to number (encoder)
        ais_token_num_enc = torch.full((num_data, max_len),166, dtype=torch.long)
        i=0
        for tokens in ais_tokens_enc:
            for length in range((len(tokens))):
                ais_token_num_enc[i, length] = vocab[tokens[length]]
            i += 1

        #Tokens to number (Decoder Input)
        ais_token_num_dec_input = torch.full((num_data, max_len),166, dtype=torch.long)
        i=0
        for tokens in ais_tokens_dec_input:
            for length in range((len(tokens))):
                ais_token_num_dec_input[i, length] = vocab[tokens[length]]
            i += 1

        #Tokens to number (Decoder Output)
        ais_token_num_dec_output = torch.full((num_data, max_len),166, dtype=torch.long)
        i=0
        for tokens in ais_tokens_dec_output:
            for length in range((len(tokens))):
                ais_token_num_dec_output[i, length] = vocab[tokens[length]]
            i += 1

        dec_input_temp = torch.ones((6270, 268),dtype=torch.long) + 165
        dec_input_temp[:,:265]=ais_token_num_dec_input

        dec_output_temp = torch.ones((6270, 268),dtype=torch.long) + 165
        dec_output_temp[:,:265]=ais_token_num_dec_output


        self.SMILES_enc = ais_token_num_enc
        self.SMILES_dec_input = dec_input_temp
        self.SMILES_dec_output = dec_output_temp

        vocab_size, num_data
        print("vocab size : ", vocab_size,"\nnumber of data : ",num_data)
        self.num_data = num_data
        
        self.vocab = vocab
        self.vocab_size = vocab_size


        print(self.SMILES_enc.shape)
        self.properties = torch.tensor(self.properties, dtype=torch.float).unsqueeze(-1)
        print(self.properties.shape)

        self.test_data = self.SMILES_enc[50]

        print("PSMILES : ", psmiles[50])
        print("After AIS encoding : ", ais_encoding[50])
        print("After AIS Tokenization : ", ais_tokens_enc[50])
        print("After to number : ", ais_token_num_enc[50])
        print("Properties : ",self.properties)
        print(len(ais_token_num_enc[50]))
        
    
    def __getitem__(self, i):
        return self.SMILES_enc[i], self.SMILES_dec_input[i], self.SMILES_dec_output[i], self.properties[i]
    
    def __len__(self):
        return self.SMILES_enc.shape[0]
    
    def vocab_len(self):
        return self.vocab_size

# %%
Polymers = "simulation-trajectory-aggregate.csv"
dataset = load_data(Polymers)

generator = torch.Generator().manual_seed(42)
train_dataset, val_dataset = random_split(dataset, [0.75, 0.25], generator=generator)

train_dataloader = DataLoader(train_dataset, batch_size=256, shuffle=True, drop_last=False)
val_dataloader = DataLoader(val_dataset, batch_size=256, shuffle=False, drop_last=False)
# Out:
# max sequence length :  265
# {'(': 0, ')': 1, '=': 2, '[O;!R;C]': 3, '[CH3;!R;C]': 4, '[CH2;!R;CN]': 5, '[CH2;!R;CC]': 6, '[CH2;!R;CO]': 7, '[*;!R;C]': 8, '[SOS]': 9, '[EOS]': 10, '[O;!R;CC]': 11, '[NH;!R;CC]': 12, '[*;!R;O]': 13, '[O;!R;*C]': 14, '[C;!R;*OO]': 15, '[CH;!R;CCO]': 16, '[CH;!R;CCN]': 17, '[C;!R;CNO]': 18, '[N;!R;CCC]': 19, '[C;!R;*NO]': 20, '[*;!R;N]': 21, '[NH;!R;*C]': 22, '[CH3;!R;N]': 23, '[CH;!R;CCC]': 24, '[C;!R;CCCO]': 25, '[CH;!R;CC]': 26, '[F;!R;C]': 27, '[CH2;!R;C]': 28, '[C;!R;COO]': 29, '[CH3;!R;O]': 30, '[C;!R;CCCN]': 31, '#': 32, '[C;!R;CCCC]': 33, '[CH2;!R;CS]': 34, '[C;!R;CC]': 35, '[OH;!R;C]': 36, '[S;!R;CC]': 37, '[N;!R;C]': 38, '[C;!R;CN]': 39, '[CH;!R;C]': 40, '[C;!R;CCC]': 41, '[NH2;!R;C]': 42, '[CH;!R;CFF]': 43, '[O;!R;S]': 44, '[O;!R;CN]': 45, '[CH;!R;CCS]': 46, '[CH2;!R;CF]': 47, '[CH3;!R;S]': 48, '[C;!R;CCO]': 49, '[NH;!R;CO]': 50, '[C;!R;NNO]': 51, '[CH2;!R;*C]': 52, '[C;!R;CFFF]': 53, '[C;!R;CCFF]': 54, '[C;!R;NOO]': 55, '[C;!R;OOO]': 56, '[S;!R;CCOO]': 57, '[CH3;!R;Si]': 58, '[C;!R;NNS]': 59, '[S;!R;C]': 60, '[Cl;!R;C]': 61, '[NH;!R;C]': 62, '[OH;!R;P]': 63, '1': 64, '[C;!R;CNN]': 65, '[CH;!R;CN]': 66, '[SH;!R;C]': 67, '[CH;!R;CCF]': 68, '[O;!R;P]': 69, '[CH2;!R;NO]': 70, '[C;!R;CCCl]': 71, '[CH;!R;NN]': 72, '[CH2;!R;CSi]': 73, '[O;R;CC]': 74, '[cH;R;CC]': 75, '[c;R;CCO]': 76, '[CH;!R;CO]': 77, '[Si;!R;CCCC]': 78, '[NH;!R;CS]': 79, '[N;!R;CN]': 80, '[C;!R;CCN]': 81, '[C;!R;CCNN]': 82, '[N;!R;CCO]': 83, '[CH;!R;COO]': 84, '[P;!R;COOO]': 85, '[N;!R;CO]': 86, '[CH;!R;CCl]': 87, '[S;!R;CNOO]': 88, '[C;!R;CCCF]': 89, '[CH2;!R;NSi]': 90, '[C;!R;CCOO]': 91, '[NH2;!R;O]': 92, '[C;!R;CCF]': 93, '[CH;R;CCO]': 94, '[CH2;R;CO]': 95, '[C;R;OOO]': 96, '[O;!R;CS]': 97, '[NH;!R;CN]': 98, '[OH;!R;N]': 99, '[C;!R;NNN]': 100, '[N;!R;CS]': 101, '[S;!R;CCNO]': 102, '[N;!R;CCN]': 103, '[S;!R;CCO]': 104, '[OH;!R;S]': 105, '[CH;!R;CNP]': 106, '[CH2;!R;CP]': 107, '[CH;!R;CS]': 108, '[S;!R;NNOO]': 109, '[NH2;!R;S]': 110, '[N;!R;CC]': 111, '[NH2;!R;N]': 112, '[Si;!R;*CCC]': 113, '[*;!R;Si]': 114, '2': 115, '[CH;R;*CN]': 116, '[N;R;CCC]': 117, '[C;!R;*CO]': 118, '[S;!R;COOO]': 119, '[O;!R;CP]': 120, '[C;!R;CCCS]': 121, '[C;!R;NN]': 122, '[CH2;!R;OO]': 123, '[CH2;!R;NS]': 124, '[S;!R;COOS]': 125, '[S;!R;S]': 126, 'N': 127, '[P;!R;OOOO]': 128, '[CH;!R;CNO]': 129, '[CH;!R;FFO]': 130, '[CH;!R;CNN]': 131, '[C;!R;CSi]': 132, '[c;R;CCC]': 133, '[c;R;*CC]': 134, '[C;R;NNO]': 135, '[S;!R;OOO]': 136, '[O;!R;*S]': 137, '[CH2;!R;SS]': 138, '[CH2;!R;OP]': 139, '[C;!R;CFFO]': 140, '[C;!R;NSS]': 141, '[CH;!R;COP]': 142, '[CH;!R;CNS]': 143, '[C;!R;CCCCl]': 144, '[CH;!R;*CC]': 145, '[CH2;!R;NN]': 146, '[N;!R;CCS]': 147, '[PH;!R;CCO]': 148, '[P;!R;CCOO]': 149, '[C;!R;COS]': 150, '[C;!R;CCClCl]': 151, '[C;!R;OSS]': 152, '[CH2;!R;OSi]': 153, '[C;!R;CCFO]': 154, '[C;!R;CClCl]': 155, '[[N+]': 156, 'O': 157, '[[O-]': 158, '[N;!R;NO]': 159, '[SH;!R;O]': 160, '[CH;!R;NO]': 161, '[C;!R;CCNO]': 162, '[CH;!R;NNN]': 163, '[S;!R;OOOO]': 164, '[C;!R;CCOP]': 165, '[PAD]': 166}
# vocab size :  167
# number of data :  6270
# torch.Size([6270, 265])
# torch.Size([6270, 3, 1])
# PSMILES :  CC(CCCNC(=O)C(C)OC(=O)[*])O[*]
# After AIS encoding :  [*;!R;O] [O;!R;*C] [CH;!R;CCO] ( [CH3;!R;C] ) [CH2;!R;CC] [CH2;!R;CC] [CH2;!R;CN] [NH;!R;CC] [C;!R;CNO] ( = [O;!R;C] ) [CH;!R;CCO] ( [CH3;!R;C] ) [O;!R;CC] [C;!R;*OO] ( [*;!R;C] ) = [O;!R;C]
# After AIS Tokenization :  ['[*;!R;O]', '[O;!R;*C]', '[CH;!R;CCO]', '(', '[CH3;!R;C]', ')', '[CH2;!R;CC]', '[CH2;!R;CC]', '[CH2;!R;CN]', '[NH;!R;CC]', '[C;!R;CNO]', '(', '=', '[O;!R;C]', ')', '[CH;!R;CCO]', '(', '[CH3;!R;C]', ')', '[O;!R;CC]', '[C;!R;*OO]', '(', '[*;!R;C]', ')', '=', '[O;!R;C]']
# After to number :  tensor([ 13,  14,  16,   0,   4,   1,   6,   6,   5,  12,  18,   0,   2,   3,
#           1,  16,   0,   4,   1,  11,  15,   0,   8,   1,   2,   3, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166])
# Properties :  tensor([[[ 0.2515],
#          [-0.4077],
#          [-0.7727]],
#
#         [[ 0.1276],
#          [-1.3452],
#          [ 0.9091]],
#
#         [[ 0.8112],
#          [-0.7202],
#          [ 1.6503]],
#
#         ...,
#
#         [[-0.3383],
#          [-0.4077],
#          [-0.5391]],
#
#         [[-0.1540],
#          [-0.4077],
#          [-1.9929]],
#
#         [[ 0.4027],
#          [-0.7202],
#          [-0.5979]]])
# 265

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0), :]
        return self.dropout(x)

class MultiHeadAttention(nn.Module):
    def __init__(self, d_model=64, nhead=4):
        super(MultiHeadAttention, self).__init__()
        self.multihead_attn = nn.MultiheadAttention(d_model, nhead, batch_first=True)

    def forward(self, query, key, value, attn_mask=None):
        attn_output, _ = self.multihead_attn(query, key, value, attn_mask=attn_mask)
        return attn_output

# %%
import math
#from torch_pca import PCA
from torch.nn import LSTM


class LSTM_Encoder(nn.Module):
    def __init__(self, d_model = 256, latent_dim = 64, hidden_dim=128):
        super().__init__()
        self.d_model = d_model
        self.latent_dim = latent_dim
        self.hidden_dim = hidden_dim
        
        self.smiles_embbed = nn.Embedding(dataset.vocab_size, d_model)
        self.encoder = LSTM(input_size=d_model, hidden_size=d_model, num_layers=2, batch_first=True, dropout=0.2)
    def forward(self, smiles, properties):
        smiles = self.smiles_embbed(smiles)
        input = torch.cat((smiles, properties), dim=1)
        encoded = self.encoder(input)[0]
        
        return encoded

class LSTM_Decoder(nn.Module):
    def __init__(self, d_model = 256, latent_dim = 64, hidden_dim=128):
        super().__init__()
        self.d_model = d_model
        self.latent_dim = latent_dim
        self.hidden_dim = hidden_dim
        self.to_memory = nn.Linear(latent_dim, d_model)
        self.decoder = LSTM(input_size=d_model, hidden_size=d_model, num_layers=2, batch_first=True, dropout=0.2)
    def forward(self, latent):
        latent = self.to_memory(latent)
        decoded = self.decoder(latent)[0]
        
        return decoded

# %%
class CVAE(nn.Module):
    def __init__(self, d_model=256, latent_dim = 64, hidden_dim = 128):
        super().__init__()
        self.to_means = nn.Linear(d_model, latent_dim)
        self.to_var = nn.Linear(d_model, latent_dim)
        self.to_decoder = nn.Linear(latent_dim, d_model)

        self.encoder = LSTM_Encoder()
        self.decoder = LSTM_Decoder()
        self.pdecoder = nn.Linear(268*64, 3)
        self.to_prop_z = nn.Linear(268*64, 3)

        self.predict = nn.Linear(d_model, dataset.vocab_size)

        self.input_embedding = nn.Sequential(
            nn.Linear(1, d_model // 4),
            nn.GELU(),
            nn.Dropout(0.2),
            nn.Linear(d_model // 4, d_model // 2),
            nn.Dropout(0.2),
            nn.GELU(),
            nn.Linear(d_model // 2, d_model),
            nn.GELU()
        )

        self.crossattn = MultiHeadAttention()

        self.input_embedding_p = nn.Sequential(
            nn.Linear(1, d_model // 2),
            nn.GELU(),
            nn.Linear(d_model // 2, d_model // 4),
        )
        self.ff = nn.Sequential(
            nn.Linear(latent_dim, 32),
            nn.GELU(),
            nn.Linear(32, latent_dim)
        )
    
    def reparameterize(self, mu, log_var):
        std = torch.exp(0.5 * log_var).to(device)
        eps = torch.rand_like(std).to(device)
        return mu + eps * std

    def forward(self, smiles_enc, smiles_dec_input, properties):
        properties_e = self.input_embedding(properties)

        encoded = self.encoder(smiles_enc, properties_e)

        means = self.to_means(encoded)
        log_var = self.to_var(encoded)
        prop_p = self.input_embedding_p(properties)

        z = self.reparameterize(means, log_var) # [B, L, d]
        z_z = self.crossattn(z, prop_p, prop_p)
        z_z = self.ff(z_z)
        output = self.decoder(z_z)
        tgt = self.pdecoder(means.view(-1, 268*64))
        tgt_z = self.to_prop_z(z.view(-1, 268*64))

        output = self.predict(output)

        return output, tgt, means, log_var, tgt_z

class PriorNet(nn.Module):
    """
    Simple Prior Network that maps condition y to prior distribution parameters (mu_p, logvar_p).

    Args:
        y_dim (int): Dimensionality of condition vector y.
        latent_dim (int): Dimensionality of latent space.
        hidden_dim (int): Hidden size for MLP.
    """
    def __init__(self, y_dim: int, latent_dim: int, hidden_dim: int = 256):
        super().__init__()
        self.mlp = nn.Sequential(
            nn.utils.weight_norm(nn.Linear(y_dim, hidden_dim)),
            nn.GELU(),
            nn.utils.weight_norm(nn.Linear(hidden_dim, hidden_dim)),
            nn.GELU(),
            nn.utils.weight_norm(nn.Linear(hidden_dim, hidden_dim)),
        )
        self.fc_mu = nn.Linear(hidden_dim, latent_dim)
        self.fc_logvar = nn.Linear(hidden_dim, latent_dim)
        nn.init.constant_(self.fc_logvar.bias, -3.0)

    def forward(self, y: torch.Tensor) -> tuple[torch.Tensor, torch.Tensor]:
        """
        Compute mu_p and logvar_p given condition y.

        Args:
            y: Tensor of shape [batch_size, y_dim]

        Returns:
            mu_p: Tensor of shape [batch_size, latent_dim]
            logvar_p: Tensor of same shape
        """
        h = self.mlp(y)
        print
        mu = self.fc_mu(h).unsqueeze(1).expand(-1, 268, -1)
        lv = self.fc_logvar(h).clamp_(-8,-1).unsqueeze(1).expand_as(mu)
        return mu, lv

# %%
class ConditionalVAELoss(nn.Module):
    def __init__(
        self,
        vocab_size      : int,
        max_beta        : float = 1.0,     # β-VAE 상한
        anneal_steps    : int   = 1000,    # β 스케줄 길이
        free_bits       : float = 0.02,    # per-dim nats
        capacity_max    : float = 0.0,     # 0이면 β-VAE, >0이면 Burgess-C
        capacity_inc    : float = 0.002,   # C(t) 증가속도 (nats/step)
        gamma           : float = 5.0,     # Burgess 벌점 계수
        prop_w          : float = 1.0      # property loss 가중
    ):
        super().__init__()
        self.V  = vocab_size
        self.fb = free_bits
        self.max_beta = max_beta
        self.anneal   = anneal_steps
        self.C_max    = capacity_max
        self.C_inc    = capacity_inc
        self.gamma    = gamma
        self.prop_w   = prop_w
        self.proj = nn.Linear(3, 64)

    def info_nce(self, z, y, temperature=0.2):
        """
        z : [B, d]  (posterior sample or mean)
        y : [B, k]  (조건 벡터)
        반환 : scalar loss
        """
        z = F.normalize(z, dim=-1)
        y = F.normalize(y, dim=-1)

        logits = torch.mm(z, y.t()) / temperature        # [B, B]
        labels = torch.arange(z.size(0), device=z.device)
        return F.cross_entropy(logits, labels)
    # --------------------------------------------------------------
    def reparameterize(self, mu, log_var):
        std = torch.exp(0.5 * log_var)
        eps = torch.randn_like(std)
        return mu + eps * std


    # --------------------------------------------------------------
    def forward(
        self, logits, target_tokens,
        mu_q, lv_q, mu_p, lv_p,
        prop_pred_mu, true_prop, prop_pred_z,
        step:int
    ):
        B, L, _ = logits.size()
        D       = mu_q.size(-1)

        # 1) Reconstruction
        recon = F.cross_entropy(
            logits.view(-1, self.V),           # (B·L, V)
            target_tokens.view(-1),            # (B·L,)
            reduction='sum'
        ) / B

        # 2) KL(q‖p)   -------------------------------------------------
        q = Normal(mu_q, torch.exp(0.5 * lv_q))
        p = Normal(mu_p, torch.exp(0.5 * lv_p))
        kld_dim = kl_divergence(q, p)               # (B, L, D)

        # 2-a) free-bits (per-dim clamp)
        if self.fb > 0.0:
            kld_dim = torch.clamp(kld_dim, min=self.fb)

        kld_sample = kld_dim.sum(-1).sum(-1).mean()   # scalar – batch 평균
        kld_token = kld_dim.sum(-1)
        kld_per_token = kld_token.mean()
        kld_raw    = kld_dim.mean()                   # 모니터링용

        # 2-b) KL term
        beta = min(self.max_beta, self.max_beta * step / self.anneal)
        kl_term = beta * kld_per_token

        # if self.C_max > 0:          # Burgess Capacity-VAE 모드
        #     C_t     = min(self.C_max, self.C_inc * step)
        #     kl_term = self.gamma * F.relu(kld_sample - C_t)
        # else:                       # 순수 β-VAE
        #     kl_term = beta * kld_sample

        # 3) Property losses ------------------------------------------
        prop_loss_mu = F.mse_loss(prop_pred_mu, true_prop)
        prop_loss_z  = F.mse_loss(prop_pred_z , true_prop)

    
        # 4) InfoNCE
        cond = F.relu(self.proj.cuda().forward(true_prop.squeeze()))
        z = self.reparameterize(mu_q, lv_q)
        info_nce = self.info_nce(z.mean(1), cond)

        imb = ((kld_dim - kld_dim.mean())**2).mean()

        sig_pen = torch.exp(lv_p).mean()
        sig_pen_q = torch.exp(lv_q).mean()

        # 4) 최종 손실 -------------------------------------------------
        loss = (
            recon
            + kl_term
            + self.prop_w * (prop_loss_mu + 0.5 * prop_loss_z)
            + 0.2 * info_nce
            + 0.5 * sig_pen
            + 0.5 * imb
            + 1.0 * sig_pen_q
        )

        return loss, recon, kld_sample, kld_raw, prop_loss_mu

# %%
def reverse_one_hot_encoding(one_hot_tensor, vocab):
    # 인덱스 → 토큰 매핑 생성
    index_to_token = {idx: token for token, idx in vocab.items()}

    # 복원된 토큰 시퀀스를 저장할 리스트
    original_tokens_list = []

    # GPU 텐서면 CPU로
    if one_hot_tensor.is_cuda:
        one_hot_tensor = one_hot_tensor.cpu()

    # one-hot → argmax (인덱스 시퀀스)
    try:
        _ = one_hot_tensor.shape[1]
        one_hot_tensor = torch.argmax(one_hot_tensor, dim=-1)
    except:
        pass  # 이미 1D 라면 그대로 둠

    # “값이 166인” 위치만 추출
    idx_166 = torch.nonzero(one_hot_tensor == 166, as_tuple=True)[0]

    # 만약 166 토큰이 하나도 없으면 전체 길이 사용
    end_pos = idx_166[0].item() if len(idx_166) > 0 else one_hot_tensor.size(0)

    # 0부터 end_pos 직전까지 토큰 복원
    for i in range(end_pos):
        token_idx = one_hot_tensor[i].item()
        original_tokens_list.append(index_to_token.get(token_idx, "<UNK>"))

    return original_tokens_list
print(dataset.test_data)
test = reverse_one_hot_encoding(dataset.test_data, dataset.vocab)
print(test)
print(atomInSmiles.decode(' '.join(test)))
#print(dataset.vocab)
# Out:
# tensor([ 13,  14,  16,   0,   4,   1,   6,   6,   5,  12,  18,   0,   2,   3,
#           1,  16,   0,   4,   1,  11,  15,   0,   8,   1,   2,   3, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166])
# ['[*;!R;O]', '[O;!R;*C]', '[CH;!R;CCO]', '(', '[CH3;!R;C]', ')', '[CH2;!R;CC]', '[CH2;!R;CC]', '[CH2;!R;CN]', '[NH;!R;CC]', '[C;!R;CNO]', '(', '=', '[O;!R;C]', ')', '[CH;!R;CCO]', '(', '[CH3;!R;C]', ')', '[O;!R;CC]', '[C;!R;*OO]', '(', '[*;!R;C]', ')', '=', '[O;!R;C]']
# *OC(C)CCCNC(=O)C(C)OC(*)=O

# %%
from torch.optim import AdamW


model = CVAE(d_model = 256, latent_dim=64)
model.cuda()

prior = PriorNet(y_dim=3, latent_dim=64)
prior.cuda()


lr = 3e-5
lr_prior = 1e-4
optim = AdamW(model.parameters(), lr=lr)
optim2 = AdamW(prior.parameters(), lr=lr_prior)
loss_fn = ConditionalVAELoss(
    vocab_size=dataset.vocab_size,
    max_beta=0.005,          # KL penalty 강하게
    anneal_steps=2400,
    free_bits=0.03,
    capacity_max=0.0,
    capacity_inc=0.0,
    gamma=0.0,
    prop_w=3.0
).cuda()
# Out:
# /home/kiket/torch.venv/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)

# %%
from torchinfo import summary
smiles = torch.ones([256, 265], dtype=torch.long).to(device)
pp = torch.ones([256, 3, 1], dtype=torch.float).to(device)
summary(model, input_data=(smiles, smiles, pp))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CVAE                                     [256, 268, 167]           16,640
# ├─Sequential: 1-1                        [256, 3, 256]             --
# │    └─Linear: 2-1                       [256, 3, 64]              128
# │    └─GELU: 2-2                         [256, 3, 64]              --
# │    └─Dropout: 2-3                      [256, 3, 64]              --
# │    └─Linear: 2-4                       [256, 3, 128]             8,320
# │    └─Dropout: 2-5                      [256, 3, 128]             --
# │    └─GELU: 2-6                         [256, 3, 128]             --
# │    └─Linear: 2-7                       [256, 3, 256]             33,024
# │    └─GELU: 2-8                         [256, 3, 256]             --
# ├─LSTM_Encoder: 1-2                      [256, 268, 256]           --
# │    └─Embedding: 2-9                    [256, 265, 256]           42,752
# │    └─LSTM: 2-10                        [256, 268, 256]           1,052,672
# ├─Linear: 1-3                            [256, 268, 64]            16,448
# ├─Linear: 1-4                            [256, 268, 64]            16,448
# ├─Sequential: 1-5                        [256, 3, 64]              --
# │    └─Linear: 2-11                      [256, 3, 128]             256
# │    └─GELU: 2-12                        [256, 3, 128]             --
# │    └─Linear: 2-13                      [256, 3, 64]              8,256
# ├─MultiHeadAttention: 1-6                [256, 268, 64]            --
# │    └─MultiheadAttention: 2-14          [256, 268, 64]            16,640
# ├─Sequential: 1-7                        [256, 268, 64]            --
# │    └─Linear: 2-15                      [256, 268, 32]            2,080
# │    └─GELU: 2-16                        [256, 268, 32]            --
# │    └─Linear: 2-17                      [256, 268, 64]            2,112
# ├─LSTM_Decoder: 1-8                      [256, 268, 256]           --
# │    └─Linear: 2-18                      [256, 268, 256]           16,640
# │    └─LSTM: 2-19                        [256, 268, 256]           1,052,672
# ├─Linear: 1-9                            [256, 3]                  51,459
# ├─Linear: 1-10                           [256, 3]                  51,459
# ├─Linear: 1-11                           [256, 268, 167]           42,919
# ==========================================================================================
# Total params: 2,430,925
# Trainable params: 2,430,925
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 144.52
# ==========================================================================================
# Input size (MB): 1.09
# Forward/backward pass size (MB): 779.01
# Params size (MB): 9.59
# Estimated Total Size (MB): 789.69
# ==========================================================================================

# %%
import datetime

status_out = widgets.Output()
display(status_out)
epoch = 600
model.train()
prior.train()
progress = tqdm(range(epoch), desc="Training")
loss_arr = list()
real = list()
predict = list()
for i in progress:
    log_var_extract=[]
    log_var_p_extract = []
    batchloss = 0.0
    embeddings = []
    mean_extract = []
    kld_raw_batch = 0.0
    bce = 0.0
    kld = 0.0
    for (smiles_enc, smiles_dec_input, smiles_dec_output, properties) in train_dataloader:
        optim.zero_grad()
        optim2.zero_grad()

        smiles_enc = smiles_enc.to(device)
        smiles_dec_input = smiles_dec_input.to(device)
        smiles_dec_output = smiles_dec_output.to(device)
        properties = properties.to(device)

        output, tgt, means, log_var, tgt_z = model.forward(smiles_enc, smiles_dec_input, properties)
        mu_p, logvar_p = prior.forward(properties.squeeze())
        with torch.no_grad():
          log_var_extract.append(torch.exp(0.5 * log_var.cpu()).to(device))
          log_var_p_extract.append(torch.exp(0.5 * logvar_p.cpu()).to(device))
          mean_extract.append(means.cpu())
        loss, BCE, KLD, prop, kld_raw = loss_fn.forward(output.float(), smiles_dec_output,
                                means, log_var, mu_p, logvar_p,
                                tgt, properties.float().squeeze(), tgt_z,
                                i)
        loss.backward()
        optim.step()
        optim2.step()

        batchloss += loss.item()
        kld_raw_batch += kld_raw.item()
        bce += BCE.item()
        kld += KLD.item()
        
    #Loss 값 추가
    loss = batchloss / len(train_dataloader)
    loss_arr.append(loss)

    # 토큰 복원
    original_tokens = reverse_one_hot_encoding(smiles_dec_output[50], dataset.vocab)
    predicted_tokens = reverse_one_hot_encoding(output[50], dataset.vocab)

    original_str = atomInSmiles.decode(' '.join(original_tokens))
    predicted_str = atomInSmiles.decode(' '.join(predicted_tokens))


    # 진행 바의 속성으로부터 필요한 값들 추출 (예시)
    elapsed = int(progress.format_dict.get("elapsed", 0))
    formatted_elap = str(datetime.timedelta(seconds=elapsed))
    rate = progress.format_dict.get("rate", None)
    sec_per_iter = 1 / rate if rate and rate != 0 else 0
    total = int(sec_per_iter * 600)
    formatted_total = str(datetime.timedelta(seconds=total))
    
    # 고정된 상태 정보를 업데이트 (Output 위젯에 출력)
    with status_out:
        clear_output(wait=True)
        print(f"🔹 Elapsed: {formatted_elap} | sec/iter: {sec_per_iter:.3f}s")
        print("🔹 Total time: ", formatted_total)
        print(f"🔹 Step: {i+1}/{progress.total}")
        print("🔹 loss: {:0.6f}".format(loss))
        print("[Posterior] sigma mean : {:0.6f}, ".format(torch.cat(log_var_extract).mean().item()),
              "sigma std : {:0.6f}".format(torch.cat(log_var_extract).std().mean()))
        print("[Prior]     sigma mean : {:0.6f}, ".format(torch.cat(log_var_p_extract).mean().item()),
              "sigma std : {:0.6f}".format(torch.cat(log_var_p_extract).std().mean()))
        print("∥grad to_var∥ =", model.to_var.weight.grad.norm().item(),
      "∥grad fc_logvar_p∥ =", prior.fc_logvar.weight.grad.norm().item())
        print("raw KLD : ", kld_raw_batch / len(train_dataloader))
        print("Posterior μ per-dim std:", torch.cat(mean_extract,dim=0).view(-1, 64).std(axis=0).detach().cpu().numpy().mean())
        print("Posterior μ overall std:", torch.cat(mean_extract,dim=0).view(-1, 64).std().item())
        print("BCE : {:0.6f},".format(bce / 268 / len(train_dataloader)),
              "KLD : {:0.6f},".format(kld / 268 / len(train_dataloader)),
              "prop : {:0.6f},".format(prop))
        print(f"[Epoch {i}] Original : {original_str}")
        print(f"[Epoch {i}] Predict  : {predicted_str}")
# Out:
# Output()
# Training:   0%|          | 0/600 [00:00<?, ?it/s]

# %% [markdown]
# 🔹 Elapsed: 0:31:42 | sec/iter: 3.186s
#
# 🔹 Total time:  0:31:51
#
# 🔹 Step: 600/600
#
# 🔹 loss: 11.805434
#
# [Posterior] sigma mean : 0.097504,  sigma std : 0.045396
#
# [Prior]     sigma mean : 0.284749,  sigma std : 0.047100
#
# ∥grad to_var∥ = 0.4763147532939911 ∥grad fc_logvar_p∥ = 0.0015044281026348472
#
# raw KLD :  0.01979320363974885
#
# Posterior μ per-dim std: 0.15214768
#
# Posterior μ overall std: 0.17853331565856934
#
# BCE : 0.039568, KLD : 53.247721, prop : 0.829417,
#
# [Epoch 599] Original : *OCCC(CCOC(*)=O)NC(CC)CCEOS
#
# [Epoch 599] Predict  : *OCCC(CCOC(*)=O)NC(CC)CCEOS

# %%
model.eval()
prior.eval()
results = []
origin = []

properties_results=[]
properties_origin=[]
print(len(val_dataset))
with torch.no_grad():
    for (smiles_enc, smiles_dec_input, smiles_dec_output, properties) in val_dataloader:

        smiles_enc = smiles_enc.to(device)
        smiles_dec_input = smiles_dec_input.to(device)
        smiles_dec_output = smiles_dec_output.to(device)
        properties = properties.to(device)

        result, tgt, means, log_var, z = model(smiles_enc, smiles_dec_input, properties)

        results.append(result)
        origin.append(smiles_dec_output)

        properties_results.append(tgt)
        properties_origin.append(properties)

results = torch.cat(results, dim=0)
origin = torch.cat(origin, dim=0)
results = nn.functional.softmax(results, dim=-1) 
argmax_indices = torch.argmax(results, dim=-1)
output = torch.nn.functional.one_hot(argmax_indices, num_classes=results.size(-1))

print(results.shape)
print(origin.shape)

from sklearn.metrics import mean_absolute_error
properties_origin=torch.cat(properties_origin,dim=0)
properties_results=torch.cat(properties_results,dim=0)
MAE_2 = mean_absolute_error(properties_origin.squeeze().cpu(), properties_results.squeeze().cpu())
print("MAE(properties) : ", MAE_2)


results_smiles = []
origin_smiles = []
for i in range(results.shape[0]):
    results_smiles.append(atomInSmiles.decode(' '.join(reverse_one_hot_encoding(results[i], dataset.vocab))))
    origin_smiles.append(atomInSmiles.decode(' '.join(reverse_one_hot_encoding(origin[i], dataset.vocab))))
# Out:
# 1567
# torch.Size([1567, 268, 167])
# torch.Size([1567, 268])
# MAE(properties) :  0.04068427265065904

# %%
origin_smiles = [smiles.removesuffix("EOS").strip() for smiles in origin_smiles]
results_smiles = [smiles.removesuffix("EOS").strip() for smiles in results_smiles]


for i in range(len(results_smiles)):
    if(origin_smiles[i] != results_smiles[i]):
        print(i, "번째 다름!")
    print("real smiles      : ", origin_smiles[i])
    print("predicted smiles : ", results_smiles[i])


MAE = mean_absolute_error(origin.cpu(), torch.argmax(results.cpu(), dim=-1))
print("MAE : ", MAE)
# Out:
# 0 번째 다름!
# real smiles      :  *OC(CC)CNC(C=C)COC(*)=O
# predicted smiles :  *OC(CC)CNC((=C)COC(*)=O
# 1 번째 다름!
# real smiles      :  *NCC(C)(CC)C(C)OC(*)=O
# predicted smiles :  *NCC(C)(CC)C(C)CC(*)=O
# 2 번째 다름!
# real smiles      :  *OCCCOC(=O)CC(CCC)OC(*)=O
# predicted smiles :  *OCCCCN(=O)CC(C)C)OC(*)=O
# 3 번째 다름!
# real smiles      :  *OCC(C)(CNC(=O)C=CC)COC(*)=O
# predicted smiles :  *OCC(C)(CNC(=O)(==C)OOC(*)=O
# 4 번째 다름!
# real smiles      :  *OCCN(CCC)C(=O)C(C)OC(*)=O
# predicted smiles :  *OCCN(C)C)C(=O)C(C)OC(*)=O
# 5 번째 다름!
# real smiles      :  *OC(C)CN(N)CC(C)OC(*)=O
# predicted smiles :  *OC(C)CN(C)CC(C)OC(*)=O
# 6 번째 다름!
# real smiles      :  *OC(CNC(=O)C(F)F)COC(*)=O
# predicted smiles :  *OC(CNC(=O)C(=)=)COC(*)=O
# 7 번째 다름!
# real smiles      :  *NCCCN(C)CCC(NC(*)=O)C(C)C
# predicted smiles :  *NCCCN(C)CCC(CC(*)=O)C(C)C
# real smiles      :  *OCC(C)(C)CNCC(CC)OC(*)=O
# predicted smiles :  *OCC(C)(C)CNCC(CC)OC(*)=O
# 9 번째 다름!
# real smiles      :  *OC(C)C(COC(*)=O)NC(=O)C(F)CC
# predicted smiles :  *OC(C)C(COC(*)=O)NC(=O)N(C)CC
# 10 번째 다름!
# real smiles      :  *OCCN(C)CC(COCC#C)OC(*)=O
# predicted smiles :  *OCCN(C)CC(COOC#N)OC(*)=O
# 11 번째 다름!
# real smiles      :  *CCN*
# predicted smiles :  *CCCC(*
# 12 번째 다름!
# real smiles      :  *OC(CNC(=O)C(=O)OCC)COC(*)=O
# predicted smiles :  *OC(CNC(=O)C(=O)COO)OOC(*)=O
# 13 번째 다름!
# real smiles      :  *OC(C)C(CN(C)CC#CC)OC(*)=O
# predicted smiles :  *OC(C)C(CN(C)CN#=C)OC(*)=O
# 14 번째 다름!
# real smiles      :  *NC(C(=O)NOCC(C)NC(*)=O)C(C)C
# predicted smiles :  *NC(((=O)CCCC(C)NC(*)=O)C(C)C
# 15 번째 다름!
# real smiles      :  *OC(C)(C)C(CN(C)CCOC)OC(*)=O
# predicted smiles :  *OC(C)(C)C(CN(C)COOC)OC(*)=O
# real smiles      :  *OC(C)CCCNCC(C)OC(*)=O
# predicted smiles :  *OC(C)CCCNCC(C)OC(*)=O
# real smiles      :  *CCCCCCOC(=O)O*
# predicted smiles :  *CCCCCCOC(=O)O*
# 18 번째 다름!
# real smiles      :  *OC(C)C(=O)NC(C#N)COC(*)=O
# predicted smiles :  *OC(C)C(=O)NC(CCC)OOC(*)=O
# 19 번째 다름!
# real smiles      :  *OC(C)CNC(C)C(COC(*)=O)SC
# predicted smiles :  *OC(C)CNC(C)C(COC(*)=O)CC
# 20 번째 다름!
# real smiles      :  *OCC(COC(*)=O)=NO
# predicted smiles :  *OCC(COC(*)=O)CCCC
# 21 번째 다름!
# real smiles      :  *OCC(CN(C)CCCSC)OC(*)=O
# predicted smiles :  *OCC(CN(C)CCCCC)OC(*)=O
# 22 번째 다름!
# real smiles      :  *OCCC(=O)N(CC)CC(C)(C)OC(*)=O
# predicted smiles :  *OCCC(=O)N(CO)CC(C)(C)OC(*)=O
# 23 번째 다름!
# real smiles      :  *NC(C(=O)N(C)CCCOC(*)=O)C(C)C
# predicted smiles :  *NC(C(=C)C(C)CCCOC(*)=O)C(C)C
# real smiles      :  *OCC(CC)NC(CCOC(*)=O)C(C)C
# predicted smiles :  *OCC(CC)NC(CCOC(*)=O)C(C)C
# real smiles      :  *OC(CN(CC=C)CC=C)C(C)OC(*)=O
# predicted smiles :  *OC(CN(CC=C)CC=C)C(C)OC(*)=O
# 26 번째 다름!
# real smiles      :  *OC(C)(C)CC(=O)NCCOC(*)=O
# predicted smiles :  *OC(C)(C)C((=O)NCCOC(*)=O
# 27 번째 다름!
# real smiles      :  *OCC(CN(C)CCCC)OC(*)=O
# predicted smiles :  *OCC(CN(C)CCCN)CC(*)=O
# real smiles      :  *OCCN(C)C(=O)CCOC(*)=O
# predicted smiles :  *OCCN(C)C(=O)CCOC(*)=O
# 29 번째 다름!
# real smiles      :  *NCC(=O)NCCCNC(=O)CNC(*)=O
# predicted smiles :  *NCC(=O)NCCCNC(=O)ONC(*)=O
# real smiles      :  *NCCC(C)NC(=O)C(CNC(*)=O)OC
# predicted smiles :  *NCCC(C)NC(=O)C(CNC(*)=O)OC
# real smiles      :  *OCC(C)(C)COC(*)=O
# predicted smiles :  *OCC(C)(C)COC(*)=O
# real smiles      :  *NCCNC(=O)C(C)C(C)NC(*)=O
# predicted smiles :  *NCCNC(=O)C(C)C(C)NC(*)=O
# real smiles      :  *OC(C)C(C)NC(C)C(C)OC(*)=O
# predicted smiles :  *OC(C)C(C)NC(C)C(C)OC(*)=O
# 34 번째 다름!
# real smiles      :  *OCC(CCC)OC(*)=O
# predicted smiles :  *OCC(CCC)CC(*)=O
# real smiles      :  *OC(C)(CN(C)CC(C)OC(*)=O)C(=O)O
# predicted smiles :  *OC(C)(CN(C)CC(C)OC(*)=O)C(=O)O
# real smiles      :  *OCCCCCCOC(*)=O
# predicted smiles :  *OCCCCCCOC(*)=O
# real smiles      :  *OCC(C)CNC(*)=O
# predicted smiles :  *OCC(C)CNC(*)=O
# 38 번째 다름!
# real smiles      :  *NC(CCNC(*)=O)C(=O)NCCN(C)C
# predicted smiles :  *NC(CCNC(*)=O)C(=O)NCCC(F)F
# real smiles      :  *NCC(CNC(=O)C(C)(C)CC)OC(*)=O
# predicted smiles :  *NCC(CNC(=O)C(C)(C)CC)OC(*)=O
# 40 번째 다름!
# real smiles      :  *NC(COC(*)=O)C(=O)N(C)CC(C)(C)C
# predicted smiles :  *NC(COC(*)=O)C(=O)N(C)CN(C)(C)C
# 41 번째 다름!
# real smiles      :  *NCCCC(NC(*)=O)C(=O)NCC(F)F
# predicted smiles :  *NCCCC(CC(*)=O)C(=O)NCC(C)F
# 42 번째 다름!
# real smiles      :  *NCC(CC)(CCC(F)(F)F)OC(*)=O
# predicted smiles :  *NCC(CC)(CCC(C)(C)C)OC(*)=O
# 43 번째 다름!
# real smiles      :  *OC(CNC(C)(C)CSC)COC(*)=O
# predicted smiles :  *OC(CNC(C)(C)CCC)OOC(*)=O
# real smiles      :  *OC(C)C(C)NCC(C)(CCC)OC(*)=O
# predicted smiles :  *OC(C)C(C)NCC(C)(CCC)OC(*)=O
# 45 번째 다름!
# real smiles      :  *OC(C)CCSCCOCCOC(*)=O
# predicted smiles :  *OC(C)CCCCCOOOOC(*)=O
# 46 번째 다름!
# real smiles      :  *OCCOCCOCCOC(*)=O
# predicted smiles :  *OCCCCCCCCCC(*)=O
# real smiles      :  *OC(C)C(C)(C)COC(*)=O
# predicted smiles :  *OC(C)C(C)(C)COC(*)=O
# 48 번째 다름!
# real smiles      :  *OCCC(COC)NC(=O)CCOC(*)=O
# predicted smiles :  *OCCC(CON))C(=O)CCOC(*)=O
# real smiles      :  *OCCC(C)NC(=O)C(C)(C)OC(*)=O
# predicted smiles :  *OCCC(C)NC(=O)C(C)(C)OC(*)=O
# 50 번째 다름!
# real smiles      :  *OCC(COC(*)=O)NC(=O)C=CC=CC
# predicted smiles :  *OCC(COC(*)=O)NC(=O)C=====C
# real smiles      :  *OCC(C)(COC(*)=O)NC(=O)C(C)OC
# predicted smiles :  *OCC(C)(COC(*)=O)NC(=O)C(C)OC
# real smiles      :  *OCC(C)NC(=O)CCOC(*)=O
# predicted smiles :  *OCC(C)NC(=O)CCOC(*)=O
# 53 번째 다름!
# real smiles      :  *OCC(CSC(C)C(=O)O)OC(*)=O
# predicted smiles :  *OCC(CNC(C)((=O)))OC(*)=O
# 54 번째 다름!
# real smiles      :  *OC(CNC(=O)CCOC(*)=O)COC
# predicted smiles :  *OC(CNC(=O)CCOC(*)=O)OOC
# 55 번째 다름!
# real smiles      :  *NC(C)C(=O)NOC(COC(*)=O)C(C)C
# predicted smiles :  *NC(C)C(=O)NCC(COC(*)=O)C(C)C
# 56 번째 다름!
# real smiles      :  *NCCN(CC(C)NC(*)=O)CC(F)(F)F
# predicted smiles :  *NCCN(C)(C)NC(*)=O)CC(F)(F)F
# 57 번째 다름!
# real smiles      :  *OC(C)C(=O)NC(C)(COC(*)=O)C(=O)O
# predicted smiles :  *OC(C)C(=O)NN(C)(COC(*)=O)C(=O)O
# 58 번째 다름!
# real smiles      :  *NCC(F)(F)CNC(*)=O
# predicted smiles :  *NCC(C)(C)CNC(*)=O
# real smiles      :  *NC(COC(*)=O)C(=O)N(CC)CCCC
# predicted smiles :  *NC(COC(*)=O)C(=O)N(CC)CCCC
# 60 번째 다름!
# real smiles      :  *OC(C)(C)CC(=O)N(C)C(C)COC(*)=O
# predicted smiles :  *OC(C)(C)CC(=O)C(C)C(C)OOC(*)=O
# real smiles      :  *NCCN(C)C(=O)CCCNC(*)=O
# predicted smiles :  *NCCN(C)C(=O)CCCNC(*)=O
# 62 번째 다름!
# real smiles      :  *OCCCN(CCOC(*)=O)CC(N)=O
# predicted smiles :  *OCCCN(COOC(*)=O)CC(O)=O
# 63 번째 다름!
# real smiles      :  *OCC(C)(COC(*)=O)C(=O)OCC(N)=O
# predicted smiles :  *OCC(C)(COC(*)=O)C(=O)COEOS(FEOS=O
# 64 번째 다름!
# real smiles      :  *NC(CC)CN(C)CC(OC(*)=O)C(C)C
# predicted smiles :  *NCCCC)NN(C)NC(CC(*)=O)C(C)C
# 65 번째 다름!
# real smiles      :  *OCC(=O)NC(C)CC(C)(C)OC(*)=O
# predicted smiles :  *OCC(=O)NC(C)C((C)(C)OC(*)=O
# 66 번째 다름!
# real smiles      :  *OCC(NC(*)=O)C(=O)NCCCN(C)C
# predicted smiles :  *OCC(CC(*)=O)C(=O)NCCCC(C)N
# real smiles      :  *OC(C)(CN(C)CCCOC(*)=O)C(=O)O
# predicted smiles :  *OC(C)(CN(C)CCCOC(*)=O)C(=O)O
# 68 번째 다름!
# real smiles      :  *OC(C=C)C(=O)NCCOC(*)=O
# predicted smiles :  *OC(C=C)C(=O)NCOOC(*)=O
# real smiles      :  *OCCCC(C)NC(=O)CCOC(*)=O
# predicted smiles :  *OCCCC(C)NC(=O)CCOC(*)=O
# 70 번째 다름!
# real smiles      :  *OC(C)CNCC(C)(C)C(C)OC(*)=O
# predicted smiles :  *OC(C)CNCN(C)(C)C(C)OC(*)=O
# 71 번째 다름!
# real smiles      :  *OCC(CNCC(=O)CC)OC(*)=O
# predicted smiles :  *OCC(CNCN(=O)CC)OC(*)=O
# 72 번째 다름!
# real smiles      :  *OCC(C)(COC(*)=O)C(=O)OCCC#C
# predicted smiles :  *OCC(C)(COC(*)=O)C(=O)COCC#C
# 73 번째 다름!
# real smiles      :  *OCC(CC)(CCCC)NC(*)=O
# predicted smiles :  *OCC(CC)(CC#C)NC(*)=O
# 74 번째 다름!
# real smiles      :  *OC(C)(C)C(C)(C)OC(*)=O
# predicted smiles :  *OC(C)(C)C(C)(C)CC(*)=O
# real smiles      :  *OC(C)(C)CNC(CCOC(*)=O)C(C)C
# predicted smiles :  *OC(C)(C)CNC(CCOC(*)=O)C(C)C
# real smiles      :  *OCC(C)(C)CCNC(C)CCOC(*)=O
# predicted smiles :  *OCC(C)(C)CCNC(C)CCOC(*)=O
# 77 번째 다름!
# real smiles      :  *OCCCNC(=O)C(C)(OC(*)=O)C(C)C
# predicted smiles :  *OCCCNC(=O)C(C)(CC(*)=O)C(C)C
# 78 번째 다름!
# real smiles      :  *OCC(COC(*)=O)NCCCCF
# predicted smiles :  *OCC(COC(*)=O)NCCC#F
# 79 번째 다름!
# real smiles      :  *NC(C)C(=O)NC(CNC(*)=O)CC(C)C
# predicted smiles :  *NC(C)C(=O)NC(C)C(*)=O)CC(C)C
# real smiles      :  *NC(C)(CNC(*)=O)C(=O)OC(C)(C)C
# predicted smiles :  *NC(C)(CNC(*)=O)C(=O)OC(C)(C)C
# 81 번째 다름!
# real smiles      :  *OC(C)C(COC(*)=O)NC(=O)C(N)=O
# predicted smiles :  *OC(C)C(COC(*)=O)NC(=O)C(=)=O
# 82 번째 다름!
# real smiles      :  *OCC(C)(C)CCNC(=O)COC(*)=O
# predicted smiles :  *OCC(C)(C)CCNC(=O)OOC(*)=O
# 83 번째 다름!
# real smiles      :  *OC(CNCCCC#N)COC(*)=O
# predicted smiles :  *OC(CNCCC##N)OOC(*)=O
# 84 번째 다름!
# real smiles      :  *OC(C)CN(CCC=C)C(C)COC(*)=O
# predicted smiles :  *OC(C)CN(C)(CC)C(C)OOC(*)=O
# 85 번째 다름!
# real smiles      :  *NC(C)CONC(=O)C(C)NC(*)=O
# predicted smiles :  *NC(C)CNNC(=O)C(C)NC(*)=O
# 86 번째 다름!
# real smiles      :  *OC(C)(C)CC(CNCCCF)OC(*)=O
# predicted smiles :  *OC(C)(C)CC(CNOC(C)OC(*)=O
# 87 번째 다름!
# real smiles      :  *NC(C)CCNC(=S)NCCNC(*)=O
# predicted smiles :  *NC(C)CCNN(=C)NCCNC(*)=O
# real smiles      :  *OC(C)(C)CNC(COC(*)=O)C(C)CC
# predicted smiles :  *OC(C)(C)CNC(COC(*)=O)C(C)CC
# 89 번째 다름!
# real smiles      :  *OC(C)CN(CC#N)C(C)COC(*)=O
# predicted smiles :  *OC(C)CN(CNCC)C(C)OOC(*)=O
# 90 번째 다름!
# real smiles      :  *NC(COC(*)=O)C(=O)NCC(C)(C)F
# predicted smiles :  *NC(COC(*)=O)C(=O)NCN(C)(C)C
# 91 번째 다름!
# real smiles      :  *OCC(=O)NCC(C)(C)C(C)(C)OC(*)=O
# predicted smiles :  *OCC(=O)NCN(C)(C)C(C)(C)OC(*)=O
# 92 번째 다름!
# real smiles      :  *NCCOCC(=O)NCCCCOC(*)=O
# predicted smiles :  *NCCCCC(=O)NCCCCOC(*)=O
# real smiles      :  *OCCCCC(C)NC(C)CCOC(*)=O
# predicted smiles :  *OCCCCC(C)NC(C)CCOC(*)=O
# real smiles      :  *NCCN(C)CCC(C)OC(*)=O
# predicted smiles :  *NCCN(C)CCC(C)OC(*)=O
# 95 번째 다름!
# real smiles      :  *OC(CCC)C(=O)NCC=CCOC(*)=O
# predicted smiles :  *OC(CCC)C(=O)NCCC=COC(*)=O
# real smiles      :  *OCC(C)NC(=O)NCCC(C)NC(*)=O
# predicted smiles :  *OCC(C)NC(=O)NCCC(C)NC(*)=O
# 97 번째 다름!
# real smiles      :  *OC(CSC)CN(CC)CCOC(*)=O
# predicted smiles :  *OC(CCC)CN(CN)COOC(*)=O
# 98 번째 다름!
# real smiles      :  *OC(C)(C(C)=O)C(C)(OC(*)=O)C(C)=O
# predicted smiles :  *OC(C)(C(C)=O)N(C)(CC(*)=O)N(C)=O
# real smiles      :  *OCC(C)CNC(=O)C(C)(C=C)OC(*)=O
# predicted smiles :  *OCC(C)CNC(=O)C(C)(C=C)OC(*)=O
# 100 번째 다름!
# real smiles      :  *OC(COC(*)=O)CSCC=C(C)C
# predicted smiles :  *OC(COC(*)=O)CCCC==(C)C
# real smiles      :  *OC(C)C(=O)NCC(C)CCCOC(*)=O
# predicted smiles :  *OC(C)C(=O)NCC(C)CCCOC(*)=O
# 102 번째 다름!
# real smiles      :  *OC(C)CC(C(C=O)OC(*)=O)N(C)C
# predicted smiles :  *OC(C)CC(C(==O)OC(*)=O)C(F)O
# 103 번째 다름!
# real smiles      :  *OCCN(CCOC(*)=O)C(C)C(C)C
# predicted smiles :  *OCCN(COOC(*)=O)C(C)C(C)C
# real smiles      :  *OC(CC)CNC(C)C(C)OC(*)=O
# predicted smiles :  *OC(CC)CNC(C)C(C)OC(*)=O
# real smiles      :  *NC(CNC(*)=O)C(=O)OC(C)(C)C
# predicted smiles :  *NC(CNC(*)=O)C(=O)OC(C)(C)C
# 106 번째 다름!
# real smiles      :  *OC(C(=O)N(CC)OC)C(C)(C)OC(*)=O
# predicted smiles :  *OC(C(=O)C(CO)CC))(C)(C)OC(*)=O
# 107 번째 다름!
# real smiles      :  *OCC(=O)N(CC)CC(C)(C)OC(*)=O
# predicted smiles :  *OCC(=O)N(CO)CC(C)(C)OC(*)=O
# real smiles      :  *OCCCNC(*)=O
# predicted smiles :  *OCCCNC(*)=O
# 109 번째 다름!
# real smiles      :  *OC(C)C(OC(*)=O)C(C)C
# predicted smiles :  *OC(C)C(CC(*)=O)C(C)C
# real smiles      :  *OCC(CC)NCC(C)OC(*)=O
# predicted smiles :  *OCC(CC)NCC(C)OC(*)=O
# real smiles      :  *OC(C)C(C)NC(COC(*)=O)CC(C)C
# predicted smiles :  *OC(C)C(C)NC(COC(*)=O)CC(C)C
# 112 번째 다름!
# real smiles      :  *OCC(NC(*)=O)C(=O)N(C)C(C)(C)C
# predicted smiles :  *OCC(CC(*)=O)C(=O)N(C)C(C)(C)C
# 113 번째 다름!
# real smiles      :  *OC(CNC(*)=O)C(C)CC
# predicted smiles :  *OC(CNC(*)=O)N(C)CC
# real smiles      :  *OCCCNC(=O)CCNC(*)=O
# predicted smiles :  *OCCCNC(=O)CCNC(*)=O
# 115 번째 다름!
# real smiles      :  *OCC(F)(F)C(F)(F)COC(*)=O
# predicted smiles :  *OCC(C)(F)C(F)(C)COC(*)=O
# real smiles      :  *OC(CNC(*)=O)CC(=O)NCCC(C)C
# predicted smiles :  *OC(CNC(*)=O)CC(=O)NCCC(C)C
# real smiles      :  *OC(CNC(*)=O)C(=O)N(CC)C(C)C#N
# predicted smiles :  *OC(CNC(*)=O)C(=O)N(CC)C(C)C#N
# 118 번째 다름!
# real smiles      :  *OCC(CNCCC(F)(F)F)OC(*)=O
# predicted smiles :  *OCC(CNCCC(C)(C)C)OC(*)=O
# real smiles      :  *OC(CCC)CCNCC(CC)OC(*)=O
# predicted smiles :  *OC(CCC)CCNCC(CC)OC(*)=O
# 120 번째 다름!
# real smiles      :  *OC(C)(C)CN(C)CC(C)(C)NC(*)=O
# predicted smiles :  *OC(C)(C)CN(C)CN(C)(C)NC(*)=O
# 121 번째 다름!
# real smiles      :  *OC(C)C(COC(*)=O)NC(=S)NCC
# predicted smiles :  *OC(C)C(COC(*)=O)NC(=C)NCN
# real smiles      :  *NCC(CNC(*)=O)NCC(CC)CC
# predicted smiles :  *NCC(CNC(*)=O)NCC(CC)CC
# 123 번째 다름!
# real smiles      :  *OC(CNC)C(C)C(=O)NCCNC(*)=O
# predicted smiles :  *OC(CNNCC(C)((=O)NOONC(*)=O
# real smiles      :  *OCCN(CCCC)CCCNC(*)=O
# predicted smiles :  *OCCN(CCCC)CCCNC(*)=O
# real smiles      :  *OCCC(=O)NCC(CC(C)C)OC(*)=O
# predicted smiles :  *OCCC(=O)NCC(CC(C)C)OC(*)=O
# real smiles      :  *OCCC(C)(C)CNCC(CC)OC(*)=O
# predicted smiles :  *OCCC(C)(C)CNCC(CC)OC(*)=O
# 127 번째 다름!
# real smiles      :  *NCCN(CCCCC)CCNC(*)=O
# predicted smiles :  *NCCN(C)CCC)CONC(*)=O
# real smiles      :  *OC(CNCCCCOC(*)=O)C(C)(C)C
# predicted smiles :  *OC(CNCCCCOC(*)=O)C(C)(C)C
# 129 번째 다름!
# real smiles      :  *OCC(C)(C)ONC(=O)C(C)OC(*)=O
# predicted smiles :  *OCC(C)(C)CCC(=O)C(C)OC(*)=O
# 130 번째 다름!
# real smiles      :  *OCC#CCNC(=O)C(C)(CCC)OC(*)=O
# predicted smiles :  *OCCCCCNC(=O)C(C)(CCC)OC(*)=O
# real smiles      :  *OC(C)C(CN(CC=C)C(C)C)OC(*)=O
# predicted smiles :  *OC(C)C(CN(CC=C)C(C)C)OC(*)=O
# real smiles      :  *OC(C)(C)CNC(CC)COC(*)=O
# predicted smiles :  *OC(C)(C)CNC(CC)COC(*)=O
# real smiles      :  *NC(COC(*)=O)C(=O)NC(C)C(C)OC
# predicted smiles :  *NC(COC(*)=O)C(=O)NC(C)C(C)OC
# 134 번째 다름!
# real smiles      :  *OC(C)(CC)C(=O)NOCCOC(*)=O
# predicted smiles :  *OC(C)(CC)C(=O)CCCOOC(*)=O
# 135 번째 다름!
# real smiles      :  *OC(C)(CNC(=O)C(C)OC(*)=O)COC
# predicted smiles :  *OC(C)(CNC(=O)C(C)OC(*)=O)OOC
# 136 번째 다름!
# real smiles      :  *NCCCC(NC(*)=O)C(=O)NCC#C
# predicted smiles :  *NCCCC(CC(*)=O)C(=O)NCCCN
# 137 번째 다름!
# real smiles      :  *OCC(C)N(CC(C)C)CC(C)OC(*)=O
# predicted smiles :  *OCC(C)N(CN(C)C)CC(C)OC(*)=O
# 138 번째 다름!
# real smiles      :  *OC(C=C)C(=O)NCC(C)(CC)OC(*)=O
# predicted smiles :  *OC((=C)C(=O)NCN(C)(CC)OC(*)=O
# 139 번째 다름!
# real smiles      :  *OC(C)(CCC)C(=O)OCCCOC(*)=O
# predicted smiles :  *OC(C)(CCC)C(=O)COCCOC(*)=O
# 140 번째 다름!
# real smiles      :  *NC(COC(*)=O)C(=O)NC(C#N)CC(C)C
# predicted smiles :  *NC(COC(*)=O)C(=O)NC(CCF)CC(C)C
# real smiles      :  *OC(CNC(=O)CCOC(*)=O)C(C)CC
# predicted smiles :  *OC(CNC(=O)CCOC(*)=O)C(C)CC
# 142 번째 다름!
# real smiles      :  *NC(COC(*)=O)C(=O)N(C)C(C)C(=O)O
# predicted smiles :  *NC(COC(*)=O)C(=O)N(C)C(C)EOS(=O)O
# real smiles      :  *OCCC(C)COC(*)=O
# predicted smiles :  *OCCC(C)COC(*)=O
# 144 번째 다름!
# real smiles      :  *OCC(CF)NC(*)=O
# predicted smiles :  *OCC(CC)NC(*)=O
# 145 번째 다름!
# real smiles      :  *OCC(COC(*)=O)NC(=O)NOCC=C
# predicted smiles :  *OCC(COC(*)=O)NC(=O)NCCEOS=C
# 146 번째 다름!
# real smiles      :  *NCCCCC(NC(*)=O)C(=O)OC
# predicted smiles :  *NCCCCC(CC(*)=O)C(=O)OC
# 147 번째 다름!
# real smiles      :  *NC(COC(*)=O)C(=O)OCC
# predicted smiles :  *NC(COC(*)=O)C(=O)OOC
# 148 번째 다름!
# real smiles      :  *OC(COC)CN(CCOC(*)=O)C(C)C
# predicted smiles :  *OC(CONCCN(COOC(*)=O)C(C)C
# 149 번째 다름!
# real smiles      :  *NC(C(=O)NCCNC(*)=O)C(C)(C)C
# predicted smiles :  *NCCCCCCCCC))CC))))))))))C)
# 150 번째 다름!
# real smiles      :  *CCOCCOCCOCCOCCOCCOC(=O)O*
# predicted smiles :  *CCCCCCCCCCCCCCCCCCCEOS=OOOO
# 151 번째 다름!
# real smiles      :  *OCCOCCN(CCC)CCOC(*)=O
# predicted smiles :  *OCCCCCN(CCC)COOC(*)=O
# 152 번째 다름!
# real smiles      :  *NC(CC)C(NC(*)=O)C(=O)OC
# predicted smiles :  *NC(CC)C(CC(*)=O)C(=O)OC
# 153 번째 다름!
# real smiles      :  *NCC(=O)NC(C(=O)O)C(C)OC(*)=O
# predicted smiles :  *NCC(=O)NC(C(=O)N)C(C)OC(*)=O
# 154 번째 다름!
# real smiles      :  *OCCN(CCOC)CCC(C)OC(*)=O
# predicted smiles :  *OCCN(COOCCCCC(C)OC(*)=O
# real smiles      :  *OCC(CC(C)C)NC(*)=O
# predicted smiles :  *OCC(CC(C)C)NC(*)=O
# 156 번째 다름!
# real smiles      :  *OCCN(CC#N)CCOC(*)=O
# predicted smiles :  *OCCN(CNCC)COOC(*)=O
# 157 번째 다름!
# real smiles      :  *OCC(=O)NCC(C)(OC(*)=O)C(=O)OC
# predicted smiles :  *OCC(=O)NCN(C)(CC(*)=O)C(=O)OC
# 158 번째 다름!
# real smiles      :  *OCCC(=O)NCCC(OC(*)=O)C(F)F
# predicted smiles :  *OCCC(=O)NCCC(CC(*)=O)C(F)F
# 159 번째 다름!
# real smiles      :  *OC(C)(C)C(CN(CC)C(C)C)OC(*)=O
# predicted smiles :  *OC(C)(C)C(CN(C))C(C)C)OC(*)=O
# 160 번째 다름!
# real smiles      :  *NCC(CNC(CC)CC#N)OC(*)=O
# predicted smiles :  *NCC(CNC(CC)C##N)OC(*)=O
# 161 번째 다름!
# real smiles      :  *NCCNC(=O)C(OC(*)=O)C(C)C
# predicted smiles :  *NCCNC(=O)C(CC(*)=O)C(C)C
# real smiles      :  *OCC(C)(COC(*)=O)CN(C)C(C)=O
# predicted smiles :  *OCC(C)(COC(*)=O)CN(C)C(C)=O
# 163 번째 다름!
# real smiles      :  *OC(C)CCNCC(CCC=C)OC(*)=O
# predicted smiles :  *OC(C)CCNCC(CC(=C)OC(*)=O
# 164 번째 다름!
# real smiles      :  *OC(C)(CNC(=O)COC(*)=O)CN(C)C
# predicted smiles :  *OC(C)(CNC(=O)COC(*)=O)CC(C))
# real smiles      :  *NCC(CNC(CC)CCC)OC(*)=O
# predicted smiles :  *NCC(CNC(CC)CCC)OC(*)=O
# 166 번째 다름!
# real smiles      :  *OCP(=O)CCC(NC(*)=O)C(=O)O
# predicted smiles :  *OCC(=C)CCC(CC(*)=O)C(=O)O
# 167 번째 다름!
# real smiles      :  *OCCCCNCC(C=C)OC(*)=O
# predicted smiles :  *OCCCCNCC(CCC)OC(*)=O
# 168 번째 다름!
# real smiles      :  *OCC(NC(=O)COCC)C(C)OC(*)=O
# predicted smiles :  *OCC(CC(=O)COOO)C(C)OC(*)=O
# real smiles      :  *OC(C)(CNC(=O)C(C)OC(*)=O)C(C)C
# predicted smiles :  *OC(C)(CNC(=O)C(C)OC(*)=O)C(C)C
# 170 번째 다름!
# real smiles      :  *NCC(OC(*)=O)C(=O)NC
# predicted smiles :  *NCC(CC(*)=O)C(=O)NCC
# 171 번째 다름!
# real smiles      :  *OC(C)CC(=O)OCC(C)(C)OC(*)=O
# predicted smiles :  *OC(C)C((=O)CCC(C)(C)OC(*)=O
# real smiles      :  *NC(C)(C)CC(=O)NCCC(C)NC(*)=O
# predicted smiles :  *NC(C)(C)CC(=O)NCCC(C)NC(*)=O
# real smiles      :  *OC(CC)CCNC(=O)CNC(*)=O
# predicted smiles :  *OC(CC)CCNC(=O)CNC(*)=O
# 174 번째 다름!
# real smiles      :  *OC(CN(C)CCC=C)C(C)OC(*)=O
# predicted smiles :  *OC(CN(C)CC(CC)C(C)OC(*)=O
# real smiles      :  *NCCCCCCC(=O)NCCNC(*)=O
# predicted smiles :  *NCCCCCCC(=O)NCCNC(*)=O
# real smiles      :  *OC(C)CC(C)NC(=O)CCOC(*)=O
# predicted smiles :  *OC(C)CC(C)NC(=O)CCOC(*)=O
# 177 번째 다름!
# real smiles      :  *OC(C)(C)CC(CNC(C)CF)OC(*)=O
# predicted smiles :  *OC(C)(C)CC(CNC(C)#N)OC(*)=O
# 178 번째 다름!
# real smiles      :  *OC(CNC(*)=O)CC(=O)NCCON
# predicted smiles :  *OC(CNC(*)=O)NC(=O)NCCCC
# 179 번째 다름!
# real smiles      :  *OCC(CC)NCC(OC(*)=O)C(=O)OC
# predicted smiles :  *OCC(CC)NCC(CC(*)=O)C(=O)OC
# 180 번째 다름!
# real smiles      :  *NC(C)(CNC(*)=O)C(F)(F)F
# predicted smiles :  *NC(C)(C)C(*)=O)N(C)(F)F
# 181 번째 다름!
# real smiles      :  *OC(CNCC(C#N)CCC#N)COC(*)=O
# predicted smiles :  *OC(CNCN(=)C)C###N)OOC(*)=O
# real smiles      :  *OC(C)C(C)NCCCCOC(*)=O
# predicted smiles :  *OC(C)C(C)NCCCCOC(*)=O
# 183 번째 다름!
# real smiles      :  *OC(C)CNC(CCCC)COC(*)=O
# predicted smiles :  *OCCCCNNC(C))C)OOC(*)=O
# 184 번째 다름!
# real smiles      :  *NCCN(CCCCC=C)CCNC(*)=O
# predicted smiles :  *NCCN(C)CCC=C)CONC(*)=O
# 185 번째 다름!
# real smiles      :  *OCC(C)SCCC(C)OC(*)=O
# predicted smiles :  *OCC(C)CCCC(C)OC(*)=O
# real smiles      :  *NCCC(CCNC(*)=O)C(=O)OC
# predicted smiles :  *NCCC(CCNC(*)=O)C(=O)OC
# 187 번째 다름!
# real smiles      :  *OCC(CSCC(C)=O)OC(*)=O
# predicted smiles :  *OCC(CCCC(C)=O)OC(*)=O
# 188 번째 다름!
# real smiles      :  *NCCC(NC(*)=O)C(=O)NCCCS
# predicted smiles :  *NCCC(CC(*)=O)C(=O)NCCCC
# real smiles      :  *NC(COC(*)=O)C(=O)NCCCCC
# predicted smiles :  *NC(COC(*)=O)C(=O)NCCCCC
# real smiles      :  *OC(C)(C)CNC(COC(*)=O)C(C)CC
# predicted smiles :  *OC(C)(C)CNC(COC(*)=O)C(C)CC
# real smiles      :  *NCC(CC)(CC)NC(=O)CNC(*)=O
# predicted smiles :  *NCC(CC)(CC)NC(=O)CNC(*)=O
# 192 번째 다름!
# real smiles      :  *NC(C)(C)CN(CC)CCCOC(*)=O
# predicted smiles :  *NC(C)(C)CN(CO)CCCOC(*)=O
# 193 번째 다름!
# real smiles      :  *OC(CNC(CCF)COC(*)=O)COC
# predicted smiles :  *OC(CNC(CCC)COC(*)=O)OOC
# 194 번째 다름!
# real smiles      :  *OCCS(=O)(=O)C(C)C(C)OC(*)=O
# predicted smiles :  *OCCC(=C)(=O)C(C)C(C)OC(*)=O
# 195 번째 다름!
# real smiles      :  *NC(C)C(=O)NCC(C)CC(C)OC(*)=O
# predicted smiles :  *NC(C)C(=O)NCN(C)CC(C)OC(*)=O
# real smiles      :  *NC(C)(C)CC(C)(C)NC(*)=O
# predicted smiles :  *NC(C)(C)CC(C)(C)NC(*)=O
# 197 번째 다름!
# real smiles      :  *NC(CNC(*)=O)C(=O)OCC
# predicted smiles :  *NC(CNC(*)=O)C(=O)OOC
# 198 번째 다름!
# real smiles      :  *NC(CC)(CC)COC(*)=O
# predicted smiles :  *NC(CC)(CC)CCC(*)=O
# real smiles      :  *NCCCNCCCNC(*)=O
# predicted smiles :  *NCCCNCCCNC(*)=O
# 200 번째 다름!
# real smiles      :  *CCCCCCOCCOCCOCCOCCOCC*
# predicted smiles :  *CCCCCCOCCCCCCCCCCCCCCEOS*
# real smiles      :  *OCCCC(C)NC(C)CCOC(*)=O
# predicted smiles :  *OCCCC(C)NC(C)CCOC(*)=O
# 202 번째 다름!
# real smiles      :  *OCC(CN(C)CC(CC)CC)OC(*)=O
# predicted smiles :  *OCC(CN(C)CN(CC)CC)OC(*)=O
# 203 번째 다름!
# real smiles      :  *NC(C)C(COC(*)=O)SC
# predicted smiles :  *NC(C)C(COC(*)=O)CC
# 204 번째 다름!
# real smiles      :  *OC(CNC(*)=O)CC(=O)NC(CC)CC#N
# predicted smiles :  *OC(CNC(*)=O)CC(=O)NC(=C)C##N
# 205 번째 다름!
# real smiles      :  *OCCNC(=O)C(OC(*)=O)C(F)(F)F
# predicted smiles :  *OCCNC(=O)C(CC(*)=O)C(F)(F)F
# 206 번째 다름!
# real smiles      :  *NCCCCCN(C)CCOC(*)=O
# predicted smiles :  *NCCCCCN(C)CCCC(*)=O
# real smiles      :  *NCCCCNC(=O)CC(C)OC(*)=O
# predicted smiles :  *NCCCCNC(=O)CC(C)OC(*)=O
# real smiles      :  *OC(CC)CCCNC(C)CCOC(*)=O
# predicted smiles :  *OC(CC)CCCNC(C)CCOC(*)=O
# real smiles      :  *OCC(CNC(=O)C(CC)OC)OC(*)=O
# predicted smiles :  *OCC(CNC(=O)C(CC)OC)OC(*)=O
# 210 번째 다름!
# real smiles      :  *NC(COC(*)=O)C(=O)N(CC)CC(=O)O
# predicted smiles :  *NC(COC(*)=O)C(=O)N(CC)CEOS(=O)O
# 211 번째 다름!
# real smiles      :  *OCCN(CC)CC(OC(*)=O)C(C)C
# predicted smiles :  *OCCN(CNNCC(CC(*)=O)C(C)C
# real smiles      :  *OCCCNC(=O)CCOC(*)=O
# predicted smiles :  *OCCCNC(=O)CCOC(*)=O
# real smiles      :  *NCC(CC(=O)NC(C)(C)CC)OC(*)=O
# predicted smiles :  *NCC(CC(=O)NC(C)(C)CC)OC(*)=O
# 214 번째 다름!
# real smiles      :  *NC(CCCC#N)C(=O)NCC(C)NC(*)=O
# predicted smiles :  *NC(CCCCCC)C(=O)NCC(C)NC(*)=O
# 215 번째 다름!
# real smiles      :  *OC(C)(CC)C(=O)NCCOC(*)=O
# predicted smiles :  *OC(C)(CC)C(=O)NCOOC(*)=O
# 216 번째 다름!
# real smiles      :  *NCC(CC(=O)NCC(C)C#N)OC(*)=O
# predicted smiles :  *NCC(CC(=O)NCN(C)C#C)OC(*)=O
# real smiles      :  *NCCCCCCCN(C)CCNC(*)=O
# predicted smiles :  *NCCCCCCCN(C)CCNC(*)=O
# 218 번째 다름!
# real smiles      :  *OC(COC)C(COC)OC(*)=O
# predicted smiles :  *OC(CONC)(COC)OC(*)=O
# 219 번째 다름!
# real smiles      :  *OCCN(CC)CCC(OC(*)=O)C(C)C
# predicted smiles :  *OCCN(CN)CCC(CC(*)=O)C(C)C
# real smiles      :  *OC(C)CNC(COC(*)=O)C(=O)OC
# predicted smiles :  *OC(C)CNC(COC(*)=O)C(=O)OC
# 221 번째 다름!
# real smiles      :  *OCC(CCC=C)NC(=O)C(C=C)OC(*)=O
# predicted smiles :  *OCC(CCC=C)NC(=O)C((=C)OC(*)=O
# real smiles      :  *OCCC(=O)CCOC(*)=O
# predicted smiles :  *OCCC(=O)CCOC(*)=O
# 223 번째 다름!
# real smiles      :  *OC(CC)CNC(CC=CC)COC(*)=O
# predicted smiles :  *OC(CC)CNC(C(=CC)OOC(*)=O
# 224 번째 다름!
# real smiles      :  *OC(C)CNC(CCSC)COC(*)=O
# predicted smiles :  *OC(C)CNC(CC#C)OOC(*)=O
# 225 번째 다름!
# real smiles      :  *OCCN(CC(C)COC(*)=O)C(C)CC
# predicted smiles :  *OCCN(CN(C)COC(*)=O)C(C)CC
# 226 번째 다름!
# real smiles      :  *OC(CC)C(NC(*)=O)C(=O)O
# predicted smiles :  *OC(CC)C(CC(*)=O)C(=O)O
# 227 번째 다름!
# real smiles      :  *NC(CC#C)C(=O)NCCCCNC(*)=O
# predicted smiles :  *NC(CCCC)C(=O)NCCCCNC(*)=O
# 228 번째 다름!
# real smiles      :  *OCC(OC(*)=O)C(=C)Cl
# predicted smiles :  *OCC(CC(*)=O)N(=C)O
# 229 번째 다름!
# real smiles      :  *OCC(CN(C)CC(=C)C)OC(*)=O
# predicted smiles :  *OCC(CN(C)CN(=C)C)OC(*)=O
# 230 번째 다름!
# real smiles      :  *OCC(NCC(COC)OC(*)=O)C(C)C
# predicted smiles :  *OCC(COC(COCCOC(*)=O)C(C)C
# 231 번째 다름!
# real smiles      :  *OCC(C)(COC(*)=O)NC(=O)CCC=C
# predicted smiles :  *OCC(C)(COC(*)=O)NC(=O)NC(=C
# real smiles      :  *NCCCC(=O)NCCNC(*)=O
# predicted smiles :  *NCCCC(=O)NCCNC(*)=O
# real smiles      :  *OCCCN(C)CC(CC)OC(*)=O
# predicted smiles :  *OCCCN(C)CC(CC)OC(*)=O
# 234 번째 다름!
# real smiles      :  *OC(C=C)C(=O)N(C)CC(C)OC(*)=O
# predicted smiles :  *OC((=C)C(=O)N(C)CC(C)OC(*)=O
# 235 번째 다름!
# real smiles      :  *CCCCCCCCCCCCOC(=O)O*
# predicted smiles :  **CCCCCCCCCCCOC(=O)O*
# 236 번째 다름!
# real smiles      :  *NCCCC(NC(*)=O)C(=O)N(C)CC#N
# predicted smiles :  *NCCCC(CC(*)=O)C(=O)N(C)CN#F
# 237 번째 다름!
# real smiles      :  *OCCN(CCOC(*)=O)C(C)CCCC
# predicted smiles :  *OCCC(CNNC(*==O)C(C)CCCC
# real smiles      :  *OC(C)CCN(C)CCOC(*)=O
# predicted smiles :  *OC(C)CCN(C)CCOC(*)=O
# 239 번째 다름!
# real smiles      :  *OCC(C)(CNC(=O)C(F)F)COC(*)=O
# predicted smiles :  *OCC(C)(CNC(=O)C(=)F)COC(*)=O
# real smiles      :  *OC(C)(C=C)C(=O)NCC(C)OC(*)=O
# predicted smiles :  *OC(C)(C=C)C(=O)NCC(C)OC(*)=O
# 241 번째 다름!
# real smiles      :  *OCCS(=O)CCCCCOC(*)=O
# predicted smiles :  *OCCN(=C)C)CCCOC(*)=O
# real smiles      :  *OC(C)CNC(C)(C)CCOC(*)=O
# predicted smiles :  *OC(C)CNC(C)(C)CCOC(*)=O
# 243 번째 다름!
# real smiles      :  *OCC(NC(=O)C(CC)NC(*)=O)C(C)C
# predicted smiles :  *OCC(CC(=O)C(=C)NC(*)=O)C(C)C
# 244 번째 다름!
# real smiles      :  *OC(CCC)C(=O)OCC(C)OC(*)=O
# predicted smiles :  *OC(CCC)C(=O)CCC(C)OC(*)=O
# 245 번째 다름!
# real smiles      :  *OC(C)CCNC(=O)C(CC)CNC(*)=O
# predicted smiles :  *OC(C)CCNC(=O)C(CC)ONC(*)=O
# 246 번째 다름!
# real smiles      :  *OC(COC(*)=O)CS(=O)(=O)O
# predicted smiles :  *OC(COC(*)=O)CC(=C)(=C)C
# real smiles      :  *OCC(C)(C)NC(=O)C(C)NC(*)=O
# predicted smiles :  *OCC(C)(C)NC(=O)C(C)NC(*)=O
# 248 번째 다름!
# real smiles      :  *OC(C=C)CN(CCCOC(*)=O)C(C)C
# predicted smiles :  *OC((=C)CN(C)COC(*)=O)C(C)C
# 249 번째 다름!
# real smiles      :  *OCCC(C)N(C)CCCCCOC(*)=O
# predicted smiles :  *OCCC(C)C(C)CCCCCOC(*)=O
# real smiles      :  *OCCCNC(=O)CC(C)NC(*)=O
# predicted smiles :  *OCCCNC(=O)CC(C)NC(*)=O
# 251 번째 다름!
# real smiles      :  *NCC(CNC(*)=O)NCCSCC
# predicted smiles :  *NCC(CNC(*)=O)NCCCCC
# 252 번째 다름!
# real smiles      :  *OCC(COC(*)=O)(C(=O)O)C(=O)O
# predicted smiles :  *OCC(COC(*)=O)CC(=O)C)EOS(=O)O
# 253 번째 다름!
# real smiles      :  *OCCN(CC)CC(C)(C)NC(*)=O
# predicted smiles :  *OCCN(CO)CN(C)(C)NC(*)=O
# 254 번째 다름!
# real smiles      :  *OCC(CC=CC)NC(=O)COC(*)=O
# predicted smiles :  *OCC(CC==O)NC(=O)OOC(*)=O
# 255 번째 다름!
# real smiles      :  *OC(COC(*)=O)CN(C)C(=O)C(C)C
# predicted smiles :  *OC(COC(*)=O)CN(C)C(=O)N(C)C
# 256 번째 다름!
# real smiles      :  *OC(C=C)C(=O)NCC(OC(*)=O)C(N)=O
# predicted smiles :  *OC(C=C)C(=O)NCC(CC(*)=O)C(F)=O
# 257 번째 다름!
# real smiles      :  *OC(C)(COC)C(=O)NOCCOC(*)=O
# predicted smiles :  *OC(C)(CON)C(=O)CCCOOC(*)=O
# 258 번째 다름!
# real smiles      :  *OC(C)CNCC(CF)OC(*)=O
# predicted smiles :  *OCCCCCCNCCC))))()))))C=))
# 259 번째 다름!
# real smiles      :  *OCC(NCC(OC(*)=O)C(C)C)C(N)=O
# predicted smiles :  *OCC(CO)(CC(*)=O)C(C)C)((F)=O
# real smiles      :  *OCC(COC(*)=O)NCC(C)OC
# predicted smiles :  *OCC(COC(*)=O)NCC(C)OC
# real smiles      :  *OC(C)C(C)NC(COC(*)=O)C(C)(C)C
# predicted smiles :  *OC(C)C(C)NC(COC(*)=O)C(C)(C)C
# real smiles      :  *NC(C)CN(C)C(=O)C(C)CNC(*)=O
# predicted smiles :  *NC(C)CN(C)C(=O)C(C)CNC(*)=O
# 263 번째 다름!
# real smiles      :  *OC(C)CNCC(COC(C)C)OC(*)=O
# predicted smiles :  *OC(C)CNCC(CO)(C)O)OC(*)=O
# 264 번째 다름!
# real smiles      :  *OC(COC(*)=O)CSC(C)C(C)=O
# predicted smiles :  *OC(COC(*)=O)NCC(C)#(C)=O
# real smiles      :  *OC(CC)CN(C)CC(C)OC(*)=O
# predicted smiles :  *OC(CC)CN(C)CC(C)OC(*)=O
# real smiles      :  *NCCCCC(=O)N(C)C(C)COC(*)=O
# predicted smiles :  *NCCCCC(=O)N(C)C(C)COC(*)=O
# 267 번째 다름!
# real smiles      :  *NC(CCOC)CN(C)CCCOC(*)=O
# predicted smiles :  *NC(CCON)CC(C)CCCOC(*)=O
# 268 번째 다름!
# real smiles      :  *OCC(C)(COC(*)=O)C(=O)OCC(=O)O
# predicted smiles :  *OCC(C)(COC(*)=O)C(=O)COEOS(=O)O
# 269 번째 다름!
# real smiles      :  *OC(C=C)C(=O)NCC(CC=C)COC(*)=O
# predicted smiles :  *OC((=C)C(=O)NCC(CC=C)OOC(*)=O
# 270 번째 다름!
# real smiles      :  *NC(CCNC(*)=O)P(=O)(O)O
# predicted smiles :  *NC(CONC(*)=O)N(=C)(F)F
# 271 번째 다름!
# real smiles      :  *OCC(CNCCN(CC)CC)OC(*)=O
# predicted smiles :  *OCC(CNCOC(C))CO)OC(*)=O
# real smiles      :  *CCCCCCCCOC(=O)O*
# predicted smiles :  *CCCCCCCCOC(=O)O*
# 273 번째 다름!
# real smiles      :  *OC(CCSC(C)COC(*)=O)C(C)C
# predicted smiles :  *OC(CCCC(C)OOC(*)=O)C(C)C
# 274 번째 다름!
# real smiles      :  *OC(CNC(C)(C#C)CC)C(C)OC(*)=O
# predicted smiles :  *OC(CNN(C)(=)C)CC)C(C)OC(*)=O
# 275 번째 다름!
# real smiles      :  *OC(COC(*)=O)CN(C)CC#CC
# predicted smiles :  *OC(COC(*)=O)CN(C)CCCCC
# 276 번째 다름!
# real smiles      :  *OC(C)(C)C(NC(*)=O)C(=O)NCCC
# predicted smiles :  *OC(C)(C)C(CC(*)=O)C(=O)NCCC
# real smiles      :  *NC(C)(CCCCNC(*)=O)C(=O)O
# predicted smiles :  *NC(C)(CCCCNC(*)=O)C(=O)O
# 278 번째 다름!
# real smiles      :  *NCCCC(C)NCC(C)(C)NC(*)=O
# predicted smiles :  *NCCCC(C)NCN(C)(C)NC(*)=O
# real smiles      :  *OC(C(=O)NC(C)CCOC(*)=O)C(C)C
# predicted smiles :  *OC(C(=O)NC(C)CCOC(*)=O)C(C)C
# 280 번째 다름!
# real smiles      :  *OC(C)(C)CCSCC(C)OC(*)=O
# predicted smiles :  *OC(C)(C)CNCCC(C)OC(*)=O
# 281 번째 다름!
# real smiles      :  *OC(C(=O)NCC)C(C)(C)OC(*)=O
# predicted smiles :  *OC(C(=O)NCONC(C)(C)OC(*)=O
# 282 번째 다름!
# real smiles      :  *OCCCOC(=O)CC(C)OC(*)=O
# predicted smiles :  *OCCCCC(=O)CC(C)OC(*)=O
# 283 번째 다름!
# real smiles      :  *OC(CSCC(C)COC(*)=O)C(C)C
# predicted smiles :  *OC(CCCC(C)COC(*)=O)C(C)C
# 284 번째 다름!
# real smiles      :  *NCC(=O)NOCC(C)NC(*)=O
# predicted smiles :  *NCC(=O)CCCC(C)NC(*)=O
# 285 번째 다름!
# real smiles      :  *OCCN(CCNC(*)=O)C(C)CCCC#N
# predicted smiles :  *OCCN(CONC(*)=O)C(C)CCC##N
# 286 번째 다름!
# real smiles      :  *OCC(CNC(=O)NCC)OC(*)=O
# predicted smiles :  *OCC(CNC(=O)NCO)CC(*)=O
# real smiles      :  *OC(CN(C)C(C)(C)CC)C(C)OC(*)=O
# predicted smiles :  *OC(CN(C)C(C)(C)CC)C(C)OC(*)=O
# 288 번째 다름!
# real smiles      :  *OC(C)(C=C)C(=O)N(C)CCCNC(*)=O
# predicted smiles :  *OC(C)((=C)C(=O)N(C)CCCNC(*)=O
# 289 번째 다름!
# real smiles      :  *OC(CNC(=O)OC(C)(C)C)COC(*)=O
# predicted smiles :  *OC(CNN(=O)CN(C)(C)C)OOC(*)=O
# 290 번째 다름!
# real smiles      :  *OCC(NC(*)=O)C(=O)NCC(F)F
# predicted smiles :  *OCC(CC(*)=O)C(=O)NCN(C)C
# 291 번째 다름!
# real smiles      :  *OCC(COC(*)=O)NC(=O)C(C)N(C)C
# predicted smiles :  *OCC(COC(*)=O)NC(=O)C(C)C(F)C
# real smiles      :  *OC(C)CN(C)C(=O)CCOC(*)=O
# predicted smiles :  *OC(C)CN(C)C(=O)CCOC(*)=O
# 293 번째 다름!
# real smiles      :  *OC(CCC)CC(=O)OCCOC(*)=O
# predicted smiles :  *OC(CCC)CC(=O)COOOC(*)=O
# 294 번째 다름!
# real smiles      :  *OCCCNCCOC(*)=O
# predicted smiles :  *OCCCNCCCC(*)=O
# 295 번째 다름!
# real smiles      :  *OC(CN(C)CCOC)C(C)OC(*)=O
# predicted smiles :  *OC(CN(C)COOC))(C)OC(*)=O
# real smiles      :  *OCCCCNCC(C)OC(*)=O
# predicted smiles :  *OCCCCNCC(C)OC(*)=O
# 297 번째 다름!
# real smiles      :  *OC(CN(CC)C(C)(C)C)C(C)OC(*)=O
# predicted smiles :  *OC(CN(CO)C(C)(C)C)C(C)OC(*)=O
# 298 번째 다름!
# real smiles      :  *OCC(COC(*)=O)NC(=O)C=C(C)Cl
# predicted smiles :  *OCC(COC(*)=O)NC(=O)C==(C)C
# 299 번째 다름!
# real smiles      :  *OCCC(C)NC(CC#C)COC(*)=O
# predicted smiles :  *OCCC(C)NC(CC#C)OOC(*)=O
# real smiles      :  *OCCCCNC(=O)C(C)(C)NC(*)=O
# predicted smiles :  *OCCCCNC(=O)C(C)(C)NC(*)=O
# 301 번째 다름!
# real smiles      :  *OCCCCNCC(CCC=C)OC(*)=O
# predicted smiles :  *OCCCCNCC(CC(=C)OC(*)=O
# real smiles      :  *OCC(C)(COC(*)=O)NC(=O)C(F)F
# predicted smiles :  *OCC(C)(COC(*)=O)NC(=O)C(F)F
# 303 번째 다름!
# real smiles      :  *OC(CNCC(=O)OCCC)COC(*)=O
# predicted smiles :  *OC(CNCC(=O)COCC)OOC(*)=O
# real smiles      :  *OCC(C)(COC(*)=O)NC(=O)COC
# predicted smiles :  *OCC(C)(COC(*)=O)NC(=O)COC
# 305 번째 다름!
# real smiles      :  *NC(CCOC(*)=O)CSC
# predicted smiles :  *NC(CCOC(*)=O)CCC
# 306 번째 다름!
# real smiles      :  *OC(C)C(=O)NCC(C)(C)COC(*)=O
# predicted smiles :  *OC(C)C(=O)NCN(C)(C)OOC(*)=O
# 307 번째 다름!
# real smiles      :  *OC(C)(C)C(C)N(C)CCC(C)OC(*)=O
# predicted smiles :  *OC(C)(C)C(C)C(C)OCC(C)OC(*)=O
# 308 번째 다름!
# real smiles      :  *NCC(OC)C(=O)NCC=CCOC(*)=O
# predicted smiles :  *NCC(CNCC(=O)NCCCCCOC(*)=O
# 309 번째 다름!
# real smiles      :  *NC(C)CCNC(=O)C(C)(C)CNC(*)=O
# predicted smiles :  *NC(C)CCNC(=O)C(C)(C)ONC(*)=O
# 310 번째 다름!
# real smiles      :  *OCC(COC(*)=O)NC(=O)C(C)(C)C
# predicted smiles :  *OCC(COC(*)=O)NC(=O)N(C)(C)C
# 311 번째 다름!
# real smiles      :  *OC(C)CN(C(N)=O)C(C)COC(*)=O
# predicted smiles :  *OC(C)CN(===)=O)C(C)OOC(*)=O
# 312 번째 다름!
# real smiles      :  *NCCNS(=O)(=O)NCCNC(*)=O
# predicted smiles :  *NCCNC(CC)(CC)CCONC(*)=O
# 313 번째 다름!
# real smiles      :  *OCC(=C)C(=O)N(CC)CCOC(*)=O
# predicted smiles :  *OCN(=C)C(=O)N(CN)COOC(*)=O
# 314 번째 다름!
# real smiles      :  *OCC(COC(*)=O)NC(=O)OCC(C)C
# predicted smiles :  *OCC(COC(*)=O)NN(=O)COC(C)C
# 315 번째 다름!
# real smiles      :  *OCC(=N)NOCCC(C)(C)OC(*)=O
# predicted smiles :  *OCN(=C)CCCCC(C)(C)OC(*)=O
# real smiles      :  *OCCN(C)C(=O)C(C=C)OC(*)=O
# predicted smiles :  *OCCN(C)C(=O)C(C=C)OC(*)=O
# 317 번째 다름!
# real smiles      :  *OCC(C)(COC(*)=O)NC(=O)CN(C)C
# predicted smiles :  *OCC(C)(COC(*)=O)NC(=O)CC(F)C
# 318 번째 다름!
# real smiles      :  *OC(C)CN(CCOC)CCOC(*)=O
# predicted smiles :  *OC(C)CN(COOC)OOOC(*)=O
# 319 번째 다름!
# real smiles      :  *OCC(COC(*)=O)NC(=O)C(C)C(=O)O
# predicted smiles :  *OCC(COC(*)=O)NC(=O)C(C)((=O)O
# 320 번째 다름!
# real smiles      :  *OC(C)(C)C(OC(*)=O)C(=O)NCCCC
# predicted smiles :  *OC(C)(C)C(CC(*)=O)C(=O)NCCCC
# real smiles      :  *NCC(C)C(=O)NC(C)C(C)(C)OC(*)=O
# predicted smiles :  *NCC(C)C(=O)NC(C)C(C)(C)OC(*)=O
# 322 번째 다름!
# real smiles      :  *OCC(COC(*)=O)NC(=O)C=C(C)CC
# predicted smiles :  *OCC(COC(*)=O)NC(=O)C==(C)CC
# 323 번째 다름!
# real smiles      :  *OCCNCC(COCC#C)OC(*)=O
# predicted smiles :  *OCCNCC(COOC(N)OC(*)=O
# 324 번째 다름!
# real smiles      :  *OC(CCC(OC(*)=O)C(=C)C)C(=C)C
# predicted smiles :  *OC(CCC(CC(*)=O)C(=C)C)EOS(=C)C
# real smiles      :  *OCCNC(=O)C(COC(C)=O)NC(*)=O
# predicted smiles :  *OCCNC(=O)C(COC(C)=O)NC(*)=O
# 326 번째 다름!
# real smiles      :  *OCC(NC(C)CCOC(*)=O)C(C)C
# predicted smiles :  *OCC(C)(C)CCOC(*)=O)C(C)C
# 327 번째 다름!
# real smiles      :  *OCC(C)CSCCC(C)OC(*)=O
# predicted smiles :  *OCC(C)CCCCC(C)OC(*)=O
# 328 번째 다름!
# real smiles      :  *NC(C)CN(C)C(=O)COCCNC(*)=O
# predicted smiles :  *NC(C)CN(C)C(=O)COOONC(*)=O
# real smiles      :  *OC(C)CN(C)C(COC(*)=O)C(C)(C)C
# predicted smiles :  *OC(C)CN(C)C(COC(*)=O)C(C)(C)C
# real smiles      :  *NC(CCOC(*)=O)C(C)C
# predicted smiles :  *NC(CCOC(*)=O)C(C)C
# 331 번째 다름!
# real smiles      :  *OC(C)C(=O)OCCCCOC(*)=O
# predicted smiles :  *OC(C)C(=O)CCCCCOC(*)=O
# 332 번째 다름!
# real smiles      :  *OCC(NC(=O)NCCC)C(C)OC(*)=O
# predicted smiles :  *OCC(CC(=O)NCCC)C(C)OC(*)=O
# 333 번째 다름!
# real smiles      :  *OCC(=C)C(=O)N(C)C(C)COC(*)=O
# predicted smiles :  *OCC(=C)C(=O)N(C)C(C)OOC(*)=O
# 334 번째 다름!
# real smiles      :  *OCCCC(NC(*)=O)C(=O)O
# predicted smiles :  *OCCCC(CC(*)=O)C(=O)O
# 335 번째 다름!
# real smiles      :  *OCC(CNCC(=O)N(C)C)OC(*)=O
# predicted smiles :  *OCC(CNCC(=O)C(C)))OC(*)=O
# 336 번째 다름!
# real smiles      :  *OC(C)(C(=O)NCC#CCOC(*)=O)C(C)C
# predicted smiles :  *OC(C)(C(=O)NCN#CCOC(*)=O)C(C)C
# 337 번째 다름!
# real smiles      :  *NCCN(CCNCC)CCNC(*)=O
# predicted smiles :  *NCCN(CONCO)CONC(*)=O
# 338 번째 다름!
# real smiles      :  *OCC(NC(*)=O)C(=O)N(CC)CCC
# predicted smiles :  *OCC(CC(*)=O)C(=O)N(CC)CCC
# real smiles      :  *OCC(C=C)NCCCC(C)OC(*)=O
# predicted smiles :  *OCC(C=C)NCCCC(C)OC(*)=O
# real smiles      :  *OC(CNC(*)=O)CNC(C)CCCC
# predicted smiles :  *OC(CNC(*)=O)CNC(C)CCCC
# real smiles      :  *NCC(CN(C)CCCCCC)OC(*)=O
# predicted smiles :  *NCC(CN(C)CCCCCC)OC(*)=O
# real smiles      :  *OCCCN(C)C(=O)CC(C)NC(*)=O
# predicted smiles :  *OCCCN(C)C(=O)CC(C)NC(*)=O
# 343 번째 다름!
# real smiles      :  *OCC(C#N)NC(=O)CCCCOC(*)=O
# predicted smiles :  *OCC(CCC)NC(=O)CCCCOC(*)=O
# 344 번째 다름!
# real smiles      :  *OCC(C)(COC(*)=O)C(=O)OCCF
# predicted smiles :  *OCC(C)(COC(*)=O)C(=O)OOEOSF
# 345 번째 다름!
# real smiles      :  *OCC(COC(*)=O)NCCSC(C)C
# predicted smiles :  *OCC(COC(*)=O)NCCCC(C)C
# 346 번째 다름!
# real smiles      :  *OCC#CCNC(=O)C(C)(C)COC(*)=O
# predicted smiles :  *OCCCCCNC(=O)C(C)(C)OOC(*)=O
# 347 번째 다름!
# real smiles      :  *NCC(NC(*)=O)C(=O)NCC(C)(C)S
# predicted smiles :  *NCC(CC(*)=O)C(=O)NCC(C)(C)C
# real smiles      :  *OCC(C)NCC(CC)OC(*)=O
# predicted smiles :  *OCC(C)NCC(CC)OC(*)=O
# 349 번째 다름!
# real smiles      :  *OCCN(CC)C(=O)C(OC(*)=O)C(C)C
# predicted smiles :  *OCCN(CC)C(=O)C(CC(*)=O)C(C)C
# 350 번째 다름!
# real smiles      :  *OC(C)(C)CCNC(=O)C(C)(C)OC(*)=O
# predicted smiles :  *OC(C)(C)NCNC(=O)C(C)(C)OC(*)=O
# 351 번째 다름!
# real smiles      :  *NCCSC(=O)SCCNC(*)=O
# predicted smiles :  *NCCCC(=O)CCCNC(*)=O
# 352 번째 다름!
# real smiles      :  *OCCC(NC(=O)CCNC(*)=O)C(C)C
# predicted smiles :  *OCCC(CC(=O)CCNC(*)=O)C(C)C
# real smiles      :  *OCC(COC(*)=O)NC(=O)NC(C)C
# predicted smiles :  *OCC(COC(*)=O)NC(=O)NC(C)C
# real smiles      :  *OC(C)(C)CNC(COC(*)=O)C(=O)OC
# predicted smiles :  *OC(C)(C)CNC(COC(*)=O)C(=O)OC
# 355 번째 다름!
# real smiles      :  *OCC(CC)(COC(*)=O)NC(=O)C(=C)F
# predicted smiles :  *OCC(CC)(COC(*)=O)NC(=O)C(=C)C
# 356 번째 다름!
# real smiles      :  *OCC(C)(COC(*)=O)CSC
# predicted smiles :  *OCC(C)(COC(*)=O)CCC
# 357 번째 다름!
# real smiles      :  *OC(CNCC(CC)OC(*)=O)COCC
# predicted smiles :  *OC(CNCC(CC)CC(*)=O)OOOC
# 358 번째 다름!
# real smiles      :  *NCC(C)(CCC)OC(*)=O
# predicted smiles :  *NCC(C)(CCC)CC(*)=O
# 359 번째 다름!
# real smiles      :  *NCCNC(=O)CC(NC(*)=O)C(C)CC
# predicted smiles :  *NCCNC(=O)CC(CC(*)=O)C(C)CC
# real smiles      :  *OCC(CC)(COC(*)=O)NC(=O)NCC
# predicted smiles :  *OCC(CC)(COC(*)=O)NC(=O)NCC
# 361 번째 다름!
# real smiles      :  *OC(C)C(C)NCC=CCOC(*)=O
# predicted smiles :  *OC(C)C(C)NCCC=COC(*)=O
# 362 번째 다름!
# real smiles      :  *OCC(C=C)NC(=O)NCC#CCOC(*)=O
# predicted smiles :  *OCC(CCC)NC(=O)NCC(CCOC(*)=O
# 363 번째 다름!
# real smiles      :  *OCC(CC#C)NC(=O)C(=C)COC(*)=O
# predicted smiles :  *OCC(CCCC)NC(=O)C(=C)COC(*)=O
# real smiles      :  *OCCNC(=O)CCCCCNC(*)=O
# predicted smiles :  *OCCNC(=O)CCCCCNC(*)=O
# real smiles      :  *OCC(CC(C)C)NC(=O)C(C)OC(*)=O
# predicted smiles :  *OCC(CC(C)C)NC(=O)C(C)OC(*)=O
# real smiles      :  *OC(CNC(C)C(C)OC(*)=O)C(=O)OC
# predicted smiles :  *OC(CNC(C)C(C)OC(*)=O)C(=O)OC
# 367 번째 다름!
# real smiles      :  *OCC(CNC(=O)C(C)CC=C)OC(*)=O
# predicted smiles :  *OCC(CNC(=O)C(C)C#=C)OC(*)=O
# 368 번째 다름!
# real smiles      :  *OC(C)(COC(*)=O)CC(C)(C)C
# predicted smiles :  *OC(C)(COC(*)=O)NC(C)(C)C
# 369 번째 다름!
# real smiles      :  *NC(CC(=C)Cl)C(=O)NCCNC(*)=O
# predicted smiles :  *NC(CC(=C)N)C(=O)NCONC(*)=O
# real smiles      :  *OC(C)(C)C(CC)NCC(CC)OC(*)=O
# predicted smiles :  *OC(C)(C)C(CC)NCC(CC)OC(*)=O
# 371 번째 다름!
# real smiles      :  *OCCCCCNC(=O)C(=C)COC(*)=O
# predicted smiles :  *OCCCCCNC(=O)N(=C)COC(*)=O
# 372 번째 다름!
# real smiles      :  *OCC(CC)N(C)C(=O)C(C)OC(*)=O
# predicted smiles :  *OCC(CC)C(C)C(=O)C(C)OC(*)=O
# real smiles      :  *OC(C)(CC)CNC(=O)CCOC(*)=O
# predicted smiles :  *OC(C)(CC)CNC(=O)CCOC(*)=O
# real smiles      :  *NC(COC(*)=O)C(C)CCC
# predicted smiles :  *NC(COC(*)=O)C(C)CCC
# 375 번째 다름!
# real smiles      :  *OC(C)(C)CNC(=O)C(CC)CNC(*)=O
# predicted smiles :  *OC(C)(C)CNC(=O)C(CC)ONC(*)=O
# real smiles      :  *OCCCCC(=O)NCCCOC(*)=O
# predicted smiles :  *OCCCCC(=O)NCCCOC(*)=O
# 377 번째 다름!
# real smiles      :  *OC(C)(CNC(C)C(C)OC(*)=O)C(C)C
# predicted smiles :  *OC(C)(C)C(C)C(C)OC(*)=O)C(C)C
# 378 번째 다름!
# real smiles      :  *OC(CNC(=O)OCCOC)COC(*)=O
# predicted smiles :  *OC(CNN(=O)COOOC)OOC(*)=O
# 379 번째 다름!
# real smiles      :  *OC(C)(C)CC(CNCC(C)C)OC(*)=O
# predicted smiles :  *OC(C)(C)CC(CNOC(C)C)OC(*)=O
# 380 번째 다름!
# real smiles      :  *OCC(NC(*)=O)C(=O)N(C)CC(=O)OC
# predicted smiles :  *OCC(CC(*)=O)C(=O)N(C)CC(=O)OC
# 381 번째 다름!
# real smiles      :  *OCC(C)(COC)CC(C)COC(*)=O
# predicted smiles :  *OCC(C)(CO)CCC(C)COC(*)=O
# real smiles      :  *OCC(C)(COC(*)=O)C(=O)OC
# predicted smiles :  *OCC(C)(COC(*)=O)C(=O)OC
# 383 번째 다름!
# real smiles      :  *NCC(OC(*)=O)C(=O)NC(C)C(=O)OC
# predicted smiles :  *NCC(CC(*)=O)C(=O)NC(C)C(=O)OC
# 384 번째 다름!
# real smiles      :  *OCC(NC(=O)CNC(*)=O)C(C)C
# predicted smiles :  *OCC(CC(=O)CNC(*)=O)C(C)C
# real smiles      :  *OCCCCNCC(CCCC)OC(*)=O
# predicted smiles :  *OCCCCNCC(CCCC)OC(*)=O
# 386 번째 다름!
# real smiles      :  *NC(CCNC(*)=O)C(=O)NCC(N)=O
# predicted smiles :  *NC(CCNC(*)=O)C(=O)NCC(C)=O
# 387 번째 다름!
# real smiles      :  *OCC(C)N(CCF)CC(C)OC(*)=O
# predicted smiles :  *OCC(C)C(CCC)CC(C)OC(*)=O
# real smiles      :  *NC(CC)(CC)CNC(=O)CCNC(*)=O
# predicted smiles :  *NC(CC)(CC)CNC(=O)CCNC(*)=O
# 389 번째 다름!
# real smiles      :  *OCC(C)(C)NCC(OC(*)=O)C(C)C
# predicted smiles :  *OCC(C)(C)NCC(CC(*)=O)C(C)C
# 390 번째 다름!
# real smiles      :  *NCC(CNC(=O)C(F)CC)OC(*)=O
# predicted smiles :  *NCC(CNC(=O)C(C)CC)OC(*)=O
# 391 번째 다름!
# real smiles      :  *OCCN(CCOC(*)=O)CCC(=N)N
# predicted smiles :  *OCCN(COOC(*)=O)CCC(=C)C
# real smiles      :  *OCC(CNCCCCCCC)OC(*)=O
# predicted smiles :  *OCC(CNCCCCCCC)OC(*)=O
# 393 번째 다름!
# real smiles      :  *OCC(=O)NCC(C)(OC(*)=O)C(=O)O
# predicted smiles :  *OCC(=O)NCN(C)(CC(*)=O)C(=O)O
# real smiles      :  *NC(C)C(=O)NC(C)CC(C)NC(*)=O
# predicted smiles :  *NC(C)C(=O)NC(C)CC(C)NC(*)=O
# real smiles      :  *NC(COC(*)=O)C(=O)NC(C)(C)C(C)C
# predicted smiles :  *NC(COC(*)=O)C(=O)NC(C)(C)C(C)C
# real smiles      :  *NC(CC)CN(C)CC(CC)NC(*)=O
# predicted smiles :  *NC(CC)CN(C)CC(CC)NC(*)=O
# 397 번째 다름!
# real smiles      :  *OC(CNC(*)=O)C(=O)NCCC(=O)OC
# predicted smiles :  *OC(CNC(*)=O)C(=O)NCC#(=O)OC
# real smiles      :  *OC(CC)CNC(COC(*)=O)CC(F)F
# predicted smiles :  *OC(CC)CNC(COC(*)=O)CC(F)F
# 399 번째 다름!
# real smiles      :  *NCC(C)NC(=O)C(NC(*)=O)C(C)C
# predicted smiles :  *NCC(C)NC(=O)C(CC(*)=O)C(C)C
# 400 번째 다름!
# real smiles      :  *OCCOC(C)COCCOC(*)=O
# predicted smiles :  *OCCCN(C)CCCCOC(*)=O
# 401 번째 다름!
# real smiles      :  *OC(C)(CCC)C(=O)NCCOC(*)=O
# predicted smiles :  *OC(C)(CCC)C(=O)NCOOC(*)=O
# real smiles      :  *OC(CCC)CN(C)CC(CC)NC(*)=O
# predicted smiles :  *OC(CCC)CN(C)CC(CC)NC(*)=O
# 403 번째 다름!
# real smiles      :  *OCC(=O)NCCC(=O)NCCOC(*)=O
# predicted smiles :  *OCC(=O)NCCC(=O)NCOOC(*)=O
# 404 번째 다름!
# real smiles      :  *OCC(C=C)NC(=O)COCCOC(*)=O
# predicted smiles :  *OCC(CCC)NC(=O)OOOOOC(*)=O
# 405 번째 다름!
# real smiles      :  *OCC(COC)NCC(C)OC(*)=O
# predicted smiles :  *OCC(CONNNCC(C)OC(*)=O
# real smiles      :  *NCCCCCCCCCCOC(*)=O
# predicted smiles :  *NCCCCCCCCCCOC(*)=O
# 407 번째 다름!
# real smiles      :  *OC(COC(*)=O)CN(C)C(=O)OCCF
# predicted smiles :  *OC(COC(*)=O)CN(C)N(=O)COCC
# 408 번째 다름!
# real smiles      :  *OC(CNCCSC)COC(*)=O
# predicted smiles :  *OC(CNCCCC)COC(*)=O
# 409 번째 다름!
# real smiles      :  *NCC(C)(C)NC(=O)CNCCNC(*)=O
# predicted smiles :  *NCN(C)(C)NC(=O)CNCONC(*)=O
# 410 번째 다름!
# real smiles      :  *NCCN(C)C(=O)CC(CNC(*)=O)OC
# predicted smiles :  *NCCN(C)C(=O)CC(C)C(*)=O)OC
# real smiles      :  *NC(C)C(=O)NC(C)C(C)(C)OC(*)=O
# predicted smiles :  *NC(C)C(=O)NC(C)C(C)(C)OC(*)=O
# real smiles      :  *NCC(=O)NC(COC(*)=O)C(F)(F)F
# predicted smiles :  *NCC(=O)NC(COC(*)=O)C(F)(F)F
# 413 번째 다름!
# real smiles      :  *NC(COC(*)=O)C(=O)NCC(C)CNC
# predicted smiles :  *NC(COC(*)=O)C(=O)NCN(C)C)N
# 414 번째 다름!
# real smiles      :  *NC(CCCC)(CCCC)COC(*)=O
# predicted smiles :  *NC(CCCC)(CCCC)OOC(*)=O
# real smiles      :  *OC(CC)CNC(=O)C(=C)COC(*)=O
# predicted smiles :  *OC(CC)CNC(=O)C(=C)COC(*)=O
# 416 번째 다름!
# real smiles      :  *OC(CF)CNCC(OC(*)=O)C(C)C
# predicted smiles :  *OC((C)CNCC(CC(*)=O)C(C)C
# 417 번째 다름!
# real smiles      :  *OC(C)(C)C(=O)NC(CC#CC)COC(*)=O
# predicted smiles :  *OC(C)(C)C(=O)NC(CC#=C)OOC(*)=O
# 418 번째 다름!
# real smiles      :  *OC(CCC)C(COC(*)=O)NC(=O)C#CC
# predicted smiles :  *OC(CCC)C(COC(*)=O)NC(=O)CCCC
# real smiles      :  *OCCC(CC(C)(C)C)OC(*)=O
# predicted smiles :  *OCCC(CC(C)(C)C)OC(*)=O
# 420 번째 다름!
# real smiles      :  *NCCCCC(CC(=O)O)NC(*)=O
# predicted smiles :  *NCCCCC(CC(=O)N)CC(*)=O
# 421 번째 다름!
# real smiles      :  *OCCN(C)C(=O)C(OC(*)=O)C(C)(C)C
# predicted smiles :  *OCCN(C)C(=O)C(CC(*)=O)C(C)(C)C
# 422 번째 다름!
# real smiles      :  *OC(COC(*)=O)C(=C)C
# predicted smiles :  *OC(COC(*)=O)N(=C)C
# 423 번째 다름!
# real smiles      :  *NCCNCC(=O)N(CC)CCNC(*)=O
# predicted smiles :  *NCCNCC(=O)N(CO)CONC(*)=O
# real smiles      :  *OC(C)C(CC)NC(C)C(C)OC(*)=O
# predicted smiles :  *OC(C)C(CC)NC(C)C(C)OC(*)=O
# real smiles      :  *OC(C)C(=O)NC(COC(*)=O)C(C)C
# predicted smiles :  *OC(C)C(=O)NC(COC(*)=O)C(C)C
# real smiles      :  *NC(C)CN(C)CCCNC(*)=O
# predicted smiles :  *NC(C)CN(C)CCCNC(*)=O
# 427 번째 다름!
# real smiles      :  *OCCCNC(=O)C(CC(F)F)NC(*)=O
# predicted smiles :  *OCCCNC(=O)C(CC(C)C)NC(*)=O
# 428 번째 다름!
# real smiles      :  *OCC(COC(*)=O)C(=O)OCC
# predicted smiles :  *OCC(COC(*)=O)C(=O)CON
# 429 번째 다름!
# real smiles      :  *OC(C=C)CNC(COC(*)=O)C(=O)OC
# predicted smiles :  *OC((=C)CNC(COC(*)=O)C(=O)OC
# real smiles      :  *NC(C)(C)CNC(=O)CNCCNC(*)=O
# predicted smiles :  *NC(C)(C)CNC(=O)CNCCNC(*)=O
# real smiles      :  *NCCN(C)C(=O)CNCCNC(*)=O
# predicted smiles :  *NCCN(C)C(=O)CNCCNC(*)=O
# 432 번째 다름!
# real smiles      :  *OCCOCCN(C)C(=O)C(C)OC(*)=O
# predicted smiles :  *OCCCCCN(C)C(=O)C(C)OC(*)=O
# 433 번째 다름!
# real smiles      :  *OC(CN(C)CC#N)C(C)OC(*)=O
# predicted smiles :  *OC(CN(C)CN#N)C(C)OC(*)=O
# 434 번째 다름!
# real smiles      :  *OC(CNCC(=O)NC)COC(*)=O
# predicted smiles :  *OC(CNCC(=O)NNNCOC(*)=O
# 435 번째 다름!
# real smiles      :  *NC(CC)C(=O)NC(C)(C)CNC(*)=O
# predicted smiles :  *NC(CC)C(=O)NN(C)(C)ONC(*)=O
# 436 번째 다름!
# real smiles      :  *OCC(C#C)NC(*)=O
# predicted smiles :  *OCC(CCC)NC(*)=O
# 437 번째 다름!
# real smiles      :  *OC(CF)CNCC(C=C)OC(*)=O
# predicted smiles :  *OC(CC)CNCC((=C)OC(*)=O
# 438 번째 다름!
# real smiles      :  *OCC(=C)C(=O)NC(CC)COC(*)=O
# predicted smiles :  *OCC(=C)C(=O)NC(CC)OOC(*)=O
# 439 번째 다름!
# real smiles      :  *OCC(CNC(=O)C(C)CC#N)OC(*)=O
# predicted smiles :  *OCC(CNC(=O)C(C)C##N)OC(*)=O
# 440 번째 다름!
# real smiles      :  *OC(COC(*)=O)CN(C)C(=O)C(=O)NC
# predicted smiles :  *OC(COC(*)=O)CN(C)C(=O)C(=O)NN
# 441 번째 다름!
# real smiles      :  *OCCOCC(=O)NCCCCNC(*)=O
# predicted smiles :  *OCCCCC(=O)NCCCCNC(*)=O
# real smiles      :  *NCC(=O)NC(C)CCCCNC(*)=O
# predicted smiles :  *NCC(=O)NC(C)CCCCNC(*)=O
# real smiles      :  *OCC(COC(*)=O)NC(=O)C(C)C
# predicted smiles :  *OCC(COC(*)=O)NC(=O)C(C)C
# 444 번째 다름!
# real smiles      :  *OC(CC)CNC(=O)C(OC(*)=O)C(C)C
# predicted smiles :  *OC(CC)CNC(=O)C(CC(*)=O)C(C)C
# 445 번째 다름!
# real smiles      :  *OCC(NC(=O)C(C)CNC(*)=O)C(C)C
# predicted smiles :  *OCC(CC(=O)C(C)C)C(*)=O)C(C)C
# real smiles      :  *OCCC(C)NC(C)COC(*)=O
# predicted smiles :  *OCCC(C)NC(C)COC(*)=O
# real smiles      :  *OCCC(C)CCNC(C)C(C)OC(*)=O
# predicted smiles :  *OCCC(C)CCNC(C)C(C)OC(*)=O
# 448 번째 다름!
# real smiles      :  *NCC(C)NC(=O)C(CC(F)F)NC(*)=O
# predicted smiles :  *NCC(C)NC(=O)C(CC(C)C)NC(*)=O
# 449 번째 다름!
# real smiles      :  *OC(CNC(*)=O)C(=O)NCC(C)(C)C#N
# predicted smiles :  *OC(CNC(*)=O)C(=O)NCN(C)(C)C#N
# 450 번째 다름!
# real smiles      :  *OCCSCCC(C)OC(*)=O
# predicted smiles :  *OCCCCCC(C)CC(*)=O
# 451 번째 다름!
# real smiles      :  *OC(C)CC(C)(C)CNC(=O)CNC(*)=O
# predicted smiles :  *OC(C)CC(C)(C)CNC(=O)ONC(*)=O
# real smiles      :  *NCCN(C)CCNC(*)=O
# predicted smiles :  *NCCN(C)CCNC(*)=O
# 453 번째 다름!
# real smiles      :  *OC(C)CN(N)CC(C)OC(*)=O
# predicted smiles :  *OC(C)CN(C)CC(C)OC(*)=O
# real smiles      :  *OC(CNCCC(C)NC(*)=O)C(C)C
# predicted smiles :  *OC(CNCCC(C)NC(*)=O)C(C)C
# 455 번째 다름!
# real smiles      :  *OCCCSCCCCCCOC(*)=O
# predicted smiles :  *OCCCCCCCCCCOC(*)=O
# real smiles      :  *NC(COC(*)=O)C(C)(C)C
# predicted smiles :  *NC(COC(*)=O)C(C)(C)C
# 457 번째 다름!
# real smiles      :  *NCC(C)(NCCOC(*)=O)C(C)C
# predicted smiles :  *NCN(C)(COOOC(*)=O)C(C)C
# 458 번째 다름!
# real smiles      :  *OCCOCCNC(=O)C(C)(C)OC(*)=O
# predicted smiles :  *OCCCCCNC(=O)C(C)(C)OC(*)=O
# 459 번째 다름!
# real smiles      :  *OCC(C)(COC(*)=O)C(=O)OCC#C
# predicted smiles :  *OCC(C)(COC(*)=O)C(=O)COCCC
# 460 번째 다름!
# real smiles      :  *OC(CNC(CC)COC)COC(*)=O
# predicted smiles :  *OC(CNC(CC)COC)OOC(*)=O
# real smiles      :  *OC(C)(C)CNC(CCC)CCOC(*)=O
# predicted smiles :  *OC(C)(C)CNC(CCC)CCOC(*)=O
# 462 번째 다름!
# real smiles      :  *OC(C)(C)C#CC(C)(C)OC(*)=O
# predicted smiles :  *OC(C)(C)CCCC(C)(C)OC(*)=O
# real smiles      :  *NC(C)C(=O)NCCCCNC(*)=O
# predicted smiles :  *NC(C)C(=O)NCCCCNC(*)=O
# 464 번째 다름!
# real smiles      :  *OCC(=O)N(CC)CCCOC(*)=O
# predicted smiles :  *OCC(=O)N(CO)CCCOC(*)=O
# real smiles      :  *NC(C)CC(=O)NCCC(C)(C)NC(*)=O
# predicted smiles :  *NC(C)CC(=O)NCCC(C)(C)NC(*)=O
# 466 번째 다름!
# real smiles      :  *OC(C)CNCC(OC(*)=O)C(C)(C)C
# predicted smiles :  *OC(C)CNCC(CC(*)=O)C(C)(C)C
# real smiles      :  *OC(CNC(=O)COC(*)=O)C(CC)CC
# predicted smiles :  *OC(CNC(=O)COC(*)=O)C(CC)CC
# real smiles      :  *OCC(CC(C)C)NCC(C)(C)OC(*)=O
# predicted smiles :  *OCC(CC(C)C)NCC(C)(C)OC(*)=O
# 469 번째 다름!
# real smiles      :  *OC(CNCC(=O)NC(C)C)COC(*)=O
# predicted smiles :  *OC(CNCC(=O)NC(C)C)OOC(*)=O
# real smiles      :  *NC(CNC(*)=O)CC(=O)OC
# predicted smiles :  *NC(CNC(*)=O)CC(=O)OC
# 471 번째 다름!
# real smiles      :  *OCC(CNC(C)C#C)OC(*)=O
# predicted smiles :  *OCC(CNC(C)C(C)OC(*)=O
# 472 번째 다름!
# real smiles      :  *NC(C(=O)N(C)OC)C(C)OC(*)=O
# predicted smiles :  *NC(((=O)C(C)CCC)(C)OC(*)=O
# 473 번째 다름!
# real smiles      :  *OCC(C)C(C)(C)OC(*)=O
# predicted smiles :  *OCC(C)C(C)(C)CC(*)=O
# 474 번째 다름!
# real smiles      :  *OC(C)C(CNC(=O)CC(N)=O)OC(*)=O
# predicted smiles :  *OC(C)C(CNC(=O)C((=)=O)OC(*)=O
# 475 번째 다름!
# real smiles      :  *NCC(C)N(C)CC(COCC)OC(*)=O
# predicted smiles :  *NCC(C)C(C)CC(COOO)OC(*)=O
# 476 번째 다름!
# real smiles      :  *OC(CC)CNC(C)CC(C)(C)OC(*)=O
# predicted smiles :  *OC(CC)CNC(C)C((C)(C)OC(*)=O
# real smiles      :  *OCCCN(C)CCCCCCOC(*)=O
# predicted smiles :  *OCCCN(C)CCCCCCOC(*)=O
# real smiles      :  *OC(COC(*)=O)C(=O)O
# predicted smiles :  *OC(COC(*)=O)C(=O)O
# 479 번째 다름!
# ...
# predicted smiles :  *NC(COC(*)=O)C(=O)NCCC(=O)OC
# 1408 번째 다름!
# real smiles      :  *OCCOCCNCC(C)(C=C)OC(*)=O
# predicted smiles :  *OCCCCCNCN(C)(CCC)OC(*)=O
# real smiles      :  *OC(C)CNCCCC(C)(C)OC(*)=O
# predicted smiles :  *OC(C)CNCCCC(C)(C)OC(*)=O
# 1410 번째 다름!
# real smiles      :  *OC(CNC(*)=O)C(F)F
# predicted smiles :  *OC(CNC(*)=O)N(C)F
# 1411 번째 다름!
# real smiles      :  *OC(C)(C)C(CN(CC)CCC)OC(*)=O
# predicted smiles :  *OC(C)(C)C(CN(CO)OCC)OC(*)=O
# 1412 번째 다름!
# real smiles      :  *OC(C)CCCC(=O)OCCOC(*)=O
# predicted smiles :  *OC(C)CCCC(=O)COOOC(*)=O
# real smiles      :  *OC(C)CNCC(C)OC(*)=O
# predicted smiles :  *OC(C)CNCC(C)OC(*)=O
# 1414 번째 다름!
# real smiles      :  *OCC(NC(*)=O)C(=O)NC(C)CNC
# predicted smiles :  *OCC(CC(*)=O)C(=O)NC(C)CNN
# 1415 번째 다름!
# real smiles      :  *OC(C)(C)CNCC(C)(C=C)OC(*)=O
# predicted smiles :  *OC(C)(C)CNCN(C)((=C)OC(*)=O
# 1416 번째 다름!
# real smiles      :  *OC(C)(C)CC(=O)N(C)CCOC(*)=O
# predicted smiles :  *OC(C)(C)CC(=O)C(C)COOC(*)=O
# real smiles      :  *OCCCNC(=O)C(CC(C)C)NC(*)=O
# predicted smiles :  *OCCCNC(=O)C(CC(C)C)NC(*)=O
# 1418 번째 다름!
# real smiles      :  *OCCCS(=O)(=O)CC(C)OC(*)=O
# predicted smiles :  *OCCCC(=C)(=C)CC(C)OC(*)=O
# 1419 번째 다름!
# real smiles      :  *OC(CC)C(=O)OCC(C)(C)COC(*)=O
# predicted smiles :  *OC(CC)C(=O)CCC(C)(C)OOC(*)=O
# real smiles      :  *OC(C)CCNC(=O)C(CCC)OC(*)=O
# predicted smiles :  *OC(C)CCNC(=O)C(CCC)OC(*)=O
# 1421 번째 다름!
# real smiles      :  *OC(C)CN(C)CC(OC(*)=O)C(C)C
# predicted smiles :  *OC(C)CN(C)CC(CC(*)=O)C(C)C
# 1422 번째 다름!
# real smiles      :  *OCCCSCCCCCCOC(*)=O
# predicted smiles :  *OCCCCCCCCCCOC(*)=O
# 1423 번째 다름!
# real smiles      :  *OCCN(CCOC(*)=O)CCC(C)(C)C
# predicted smiles :  *OCCN(COOC(*)=O)CCC(C)(C)C
# 1424 번째 다름!
# real smiles      :  *OC(CN(C)CC#CC)CC(C)(C)OC(*)=O
# predicted smiles :  *OC(CN(C)CNCCC)C((C)(C)OC(*)=O
# 1425 번째 다름!
# real smiles      :  *OCCC(C)NC(CCOC)COC(*)=O
# predicted smiles :  *OCCC(C)NC(CCOC)OOC(*)=O
# 1426 번째 다름!
# real smiles      :  *OC(C)(C=C)CNCC(CF)OC(*)=O
# predicted smiles :  *OC(C)(C=C)CNCC(CC)OC(*)=O
# real smiles      :  *NC(CC)CN(C)CC(COC)OC(*)=O
# predicted smiles :  *NC(CC)CN(C)CC(COC)OC(*)=O
# real smiles      :  *OCC(CC)NC(C)CCCCOC(*)=O
# predicted smiles :  *OCC(CC)NC(C)CCCCOC(*)=O
# 1429 번째 다름!
# real smiles      :  *OC(CNC(=O)NCC(F)F)COC(*)=O
# predicted smiles :  *OC(CNC(=O)NCC(C)F)OOC(*)=O
# real smiles      :  *NC(C)CNC(=O)N(C)CCCNC(*)=O
# predicted smiles :  *NC(C)CNC(=O)N(C)CCCNC(*)=O
# 1431 번째 다름!
# real smiles      :  *OC(C(CC)CC)C(C)C(C)OC(*)=O
# predicted smiles :  *OC(C(=C)CC)C(C)C(C)OC(*)=O
# 1432 번째 다름!
# real smiles      :  *OCC(COC(*)=O)NCC(F)F
# predicted smiles :  *OCC(COC(*)=O)NCN(C)F
# 1433 번째 다름!
# real smiles      :  *NCC(CNC(=O)C(C)=CCC)OC(*)=O
# predicted smiles :  *NCC(CNC(=O)C(C)C#=C)OC(*)=O
# 1434 번째 다름!
# real smiles      :  *OC(CNC(=O)C(C=C)OC(*)=O)C(C)C
# predicted smiles :  *OCCCCC(C))C(C)))OC(*)=O)C(C)C
# real smiles      :  *OC(C)CCCOC(*)=O
# predicted smiles :  *OC(C)CCCOC(*)=O
# 1436 번째 다름!
# real smiles      :  *OCC(COC(*)=O)NCC(C)(C)COC
# predicted smiles :  *OCC(COC(*)=O)NCN(C)(C)COC
# 1437 번째 다름!
# real smiles      :  *OC(C)CN(N)CC(C)OC(*)=O
# predicted smiles :  *OC(C)CN(C)CC(C)OC(*)=O
# real smiles      :  *OC(C)C(COC(*)=O)NCC(C)(C)C
# predicted smiles :  *OC(C)C(COC(*)=O)NCC(C)(C)C
# 1439 번째 다름!
# real smiles      :  *OCC(NC(=O)C(C)NC(*)=O)C(C)C
# predicted smiles :  *OCC(CC(=O)C(C)NC(*)=O)C(C)C
# 1440 번째 다름!
# real smiles      :  *OC(CNC(=O)C(C)C(=O)O)COC(*)=O
# predicted smiles :  *OC(CNC(=O)C(C)((=O)))OOC(*)=O
# 1441 번째 다름!
# real smiles      :  *OCC(C)(C)CSCCCOC(*)=O
# predicted smiles :  *OCC(C)(C)CCCCCOC(*)=O
# real smiles      :  *OC(CC)CCNC(C)C(C)OC(*)=O
# predicted smiles :  *OC(CC)CCNC(C)C(C)OC(*)=O
# 1443 번째 다름!
# real smiles      :  *NCCN(CCNC(*)=O)C(C)C
# predicted smiles :  *NCCN(CONC(*)=O)C(C)C
# real smiles      :  *NCCC(C)NC(=O)CC(C)NC(*)=O
# predicted smiles :  *NCCC(C)NC(=O)CC(C)NC(*)=O
# 1445 번째 다름!
# real smiles      :  *OC(CNC)CNCC(COC)OC(*)=O
# predicted smiles :  *OC(CNCNCNCC(COC)OC(*)=O
# 1446 번째 다름!
# real smiles      :  *OCCC(CCOC(*)=O)NC(=S)NC
# predicted smiles :  *OCCC(CCOC(*)=O)NC(=C)NC
# 1447 번째 다름!
# real smiles      :  *OCC(NC(*)=O)C(=O)NCC(C)C
# predicted smiles :  *OCC(CC(*)=O)C(=O)NCN(C)C
# 1448 번째 다름!
# real smiles      :  *OCCN(CCCF)CCCOC(*)=O
# predicted smiles :  *OCCN(CN(C)CCCOC(*)=O
# 1449 번째 다름!
# real smiles      :  *NCC(OC(*)=O)C(=O)NCCCC(N)=O
# predicted smiles :  *NCC(CC(*)=O)C(=O)NCCC((=)=O
# 1450 번째 다름!
# real smiles      :  *NC(C(=O)NC)C(C)OC(*)=O
# predicted smiles :  *NC(C(=O)NCCC(C)OC(*)=O
# real smiles      :  *OCC(C)NC(=O)C(C)(C)OC(*)=O
# predicted smiles :  *OCC(C)NC(=O)C(C)(C)OC(*)=O
# real smiles      :  *NCCCC(=O)NCCCCNC(*)=O
# predicted smiles :  *NCCCC(=O)NCCCCNC(*)=O
# 1453 번째 다름!
# real smiles      :  *OCC(C)N(CC)CC(CC)OC(*)=O
# predicted smiles :  *OCC(C)C(C)NCC(CC)OC(*)=O
# real smiles      :  *OC(C(C)C)C(CC)NC(*)=O
# predicted smiles :  *OC(C(C)C)C(CC)NC(*)=O
# 1455 번째 다름!
# real smiles      :  *OC(C)(C)C(C)(C)NC(=O)COC(*)=O
# predicted smiles :  *OC(C)(C)C(C)(C)NC(=O)OOC(*)=O
# 1456 번째 다름!
# real smiles      :  *OCCCCNCC(OC(*)=O)C(=O)OC
# predicted smiles :  *OCCCCNCC(CC(*)=O)C(=O)OC
# real smiles      :  *OCC(CNC(=O)CC(C)OC)OC(*)=O
# predicted smiles :  *OCC(CNC(=O)CC(C)OC)OC(*)=O
# real smiles      :  *OCCC(C)CNCC(C)OC(*)=O
# predicted smiles :  *OCCC(C)CNCC(C)OC(*)=O
# 1459 번째 다름!
# real smiles      :  *OC(C)C(CNC(=O)C#CC(C)C)OC(*)=O
# predicted smiles :  *OC(C)C(CNC(=O)CCC#(C)C)OC(*)=O
# real smiles      :  *OC(CC)CNCC(C)CCCOC(*)=O
# predicted smiles :  *OC(CC)CNCC(C)CCCOC(*)=O
# real smiles      :  *OCCC(CC)CNC(C)CCOC(*)=O
# predicted smiles :  *OCCC(CC)CNC(C)CCOC(*)=O
# 1462 번째 다름!
# real smiles      :  *OCSi(C)(C)CCCOC(*)=O
# predicted smiles :  *OCC(C)(F)C=COC(*)=O
# 1463 번째 다름!
# real smiles      :  *NC(C(=O)N(C)CC=C)C(C)(C)OC(*)=O
# predicted smiles :  *NC(C(=C)N(C)CCCC)C(C)(C)OC(*)=O
# 1464 번째 다름!
# real smiles      :  *OCC(COC(*)=O)NC(=O)CCC=C
# predicted smiles :  *OCC(COC(*)=O)NC(=O)CCEOS=C
# 1465 번째 다름!
# real smiles      :  *OCC(O)=C(O)C(O)=C(O)COC(*)=O
# predicted smiles :  *OCN(C)=)(F)((F)CC(C)COC(*)=O
# 1466 번째 다름!
# real smiles      :  *OCC(=N)NOCCOCCOC(*)=O
# predicted smiles :  *OCN(=C)CCCOOOOOC(*)=O
# real smiles      :  *NCCCCC(=O)N(C)C(C)CNC(*)=O
# predicted smiles :  *NCCCCC(=O)N(C)C(C)CNC(*)=O
# real smiles      :  *OCCC(C)NC(CC)CCOC(*)=O
# predicted smiles :  *OCCC(C)NC(CC)CCOC(*)=O
# 1469 번째 다름!
# real smiles      :  *OC(C)(C)C(CN(C)CC#C)OC(*)=O
# predicted smiles :  *OC(C)(C)C(CN(C)CN#C)OC(*)=O
# 1470 번째 다름!
# real smiles      :  *OC(C)C(C)SC(CC)COC(*)=O
# predicted smiles :  *OC(C)C(C)CC(CC)COC(*)=O
# real smiles      :  *NC(C)(C)CCNC(=O)C(C)NC(*)=O
# predicted smiles :  *NC(C)(C)CCNC(=O)C(C)NC(*)=O
# 1472 번째 다름!
# real smiles      :  *NCCCN(C)CC(C)(C)NC(*)=O
# predicted smiles :  *NCCCN(C)CN(C)(C)NC(*)=O
# 1473 번째 다름!
# real smiles      :  *OC(CNC(=O)CC=CC=C)C(C)OC(*)=O
# predicted smiles :  *OC(CNC(=O)CC====C)C(C)OC(*)=O
# 1474 번째 다름!
# real smiles      :  *OCCCCCN(CC)CCNC(*)=O
# predicted smiles :  *OCCCCCN(CO)CONC(*)=O
# real smiles      :  *NC(C)(C)CNC(=O)C(CCC)OC(*)=O
# predicted smiles :  *NC(C)(C)CNC(=O)C(CCC)OC(*)=O
# real smiles      :  *OC(C)C(COC(*)=O)NC(=O)COC
# predicted smiles :  *OC(C)C(COC(*)=O)NC(=O)COC
# 1477 번째 다름!
# real smiles      :  *NC(CC(F)F)C(=O)NCCNC(*)=O
# predicted smiles :  *NC(CC(=)F)C(=O)NCCNC(*)=O
# real smiles      :  *OCCCC(C)NCC(CC)OC(*)=O
# predicted smiles :  *OCCCC(C)NCC(CC)OC(*)=O
# 1479 번째 다름!
# real smiles      :  *OCCN(CCC=C)CCOC(*)=O
# predicted smiles :  *OCCN(CN(=C)COOC(*)=O
# 1480 번째 다름!
# real smiles      :  *NC(CC(=O)OC)C(=O)NCCOC(*)=O
# predicted smiles :  *NC(CC(=O)CNCC(=O)NCOOC(*)=O
# 1481 번째 다름!
# real smiles      :  *OC(C)(CCN(C)C)CNC(*)=O
# predicted smiles :  *OC(C)(CCN(C)N)CNC(*)=O
# real smiles      :  *OC(C)CNC(CCOC(*)=O)C(C)(C)C
# predicted smiles :  *OC(C)CNC(CCOC(*)=O)C(C)(C)C
# real smiles      :  *NC(C)CNC(=O)CCCNC(*)=O
# predicted smiles :  *NC(C)CNC(=O)CCCNC(*)=O
# 1484 번째 다름!
# real smiles      :  *NC(C)C(=O)NCC(OC(*)=O)C(C)CC
# predicted smiles :  *NC(C)C(=O)NCC(CC(*)=O)C(C)CC
# 1485 번째 다름!
# real smiles      :  *OCC(C)(C)COC(=O)C(C)OC(*)=O
# predicted smiles :  *OCC(C)(C)CCC(=O)C(C)OC(*)=O
# real smiles      :  *OCCCC(C)NC(=O)CNC(*)=O
# predicted smiles :  *OCCCC(C)NC(=O)CNC(*)=O
# 1487 번째 다름!
# real smiles      :  *OC(C)CNC(=O)CCC(C)(C)OC(*)=O
# predicted smiles :  *OC(C)CNC(=O)CC((C)(C)OC(*)=O
# real smiles      :  *OC(C)(C=C)CNC(C)CCOC(*)=O
# predicted smiles :  *OC(C)(C=C)CNC(C)CCOC(*)=O
# 1489 번째 다름!
# real smiles      :  *OCCCCNC(C)(COC)COC(*)=O
# predicted smiles :  *OCCCCNN(C)(CO))OOC(*)=O
# 1490 번째 다름!
# real smiles      :  *OCC(COC(*)=O)NCCCCCF
# predicted smiles :  *OCC(COC(*)=O)NCCCCEOSF
# 1491 번째 다름!
# real smiles      :  *OCCCN(CC)CCCOC(*)=O
# predicted smiles :  *OCCCN(CO)CCCOC(*)=O
# 1492 번째 다름!
# real smiles      :  *OCC(CNC(=S)NCCC)OC(*)=O
# predicted smiles :  *OCC(CNN(=C)NCCC)OC(*)=O
# 1493 번째 다름!
# real smiles      :  *NCCN(CCOC(*)=O)CCOC(C)C
# predicted smiles :  *NCCN(COOC(*)=O)CCCC(C)C
# 1494 번째 다름!
# real smiles      :  *NC(C)(C)CN(C)CC(C)(C)CNC(*)=O
# predicted smiles :  *NC(C)(C)CN(C)CN(C)(C)CNC(*)=O
# 1495 번째 다름!
# real smiles      :  *OCC(CC#CC)NC(=O)COC(*)=O
# predicted smiles :  *OCC(CCCCC)NC(=O)OOC(*)=O
# 1496 번째 다름!
# real smiles      :  *OC(C)CCNC(CC)COC(*)=O
# predicted smiles :  *OC(C)CCNC(CC)OOC(*)=O
# real smiles      :  *NCCN(C)C(=O)NCCC(C)NC(*)=O
# predicted smiles :  *NCCN(C)C(=O)NCCC(C)NC(*)=O
# 1498 번째 다름!
# real smiles      :  *OCC(CNC(C)(C#N)CC)OC(*)=O
# predicted smiles :  *OCC(CNC(C)(=)C)CC)OC(*)=O
# real smiles      :  *OCC(C)NC(=O)C(CC)C(C)OC(*)=O
# predicted smiles :  *OCC(C)NC(=O)C(CC)C(C)OC(*)=O
# real smiles      :  *NC(C)C(C)NC(=O)C(CNC(*)=O)OC
# predicted smiles :  *NC(C)C(C)NC(=O)C(CNC(*)=O)OC
# 1501 번째 다름!
# real smiles      :  *OC(C)COC(=O)C(C)(C)OC(*)=O
# predicted smiles :  *OC(C)CCC(=O)C(C)(C)OC(*)=O
# real smiles      :  *OC(C)(C)CNC(COC(*)=O)C(C)(C)C
# predicted smiles :  *OC(C)(C)CNC(COC(*)=O)C(C)(C)C
# real smiles      :  *OCC(C)(COC(*)=O)C(=O)OC(C)C
# predicted smiles :  *OCC(C)(COC(*)=O)C(=O)OC(C)C
# 1504 번째 다름!
# real smiles      :  *OC(COCCOCCCC)COC(*)=O
# predicted smiles :  *OC(COOOOOCCC)COC(*)=O
# 1505 번째 다름!
# real smiles      :  *OCC(COC(*)=O)NCC
# predicted smiles :  *OCC(COC(*)=O)NCNC(
# 1506 번째 다름!
# real smiles      :  *NC(CCN(C)CC(C)NC(*)=O)C(C)C
# predicted smiles :  *NC(CCN(C)CN(C)CC(*)=O)C(C)C
# 1507 번째 다름!
# real smiles      :  *NC(CNC(C#C)COC(*)=O)CC(F)F
# predicted smiles :  *NC(CNC(CCC)COC(*)=O)CC(F)F
# 1508 번째 다름!
# real smiles      :  *OCCN(CC#CCOC)CCOC(*)=O
# predicted smiles :  *OCCN(CNCCCOC)OOOC(*)=O
# 1509 번째 다름!
# real smiles      :  *OCC=CCNC(=O)C(C=C)OC(*)=O
# predicted smiles :  *OCCC=CNC(=O)C(C=C)OC(*)=O
# 1510 번째 다름!
# real smiles      :  *OCCN(CC#CCOC(*)=O)C(C)C
# predicted smiles :  *OCCN(CNCCCOC(*)=O)C(C)C
# 1511 번째 다름!
# real smiles      :  *OC(COCCCCCC)COC(*)=O
# predicted smiles :  *OC(COONCCCC)OOC(*)=O
# 1512 번째 다름!
# real smiles      :  *OC(COC(*)=O)CN(C)C(=O)COC
# predicted smiles :  *OC(COC(*)=O)CN(C)C(=O)CCC
# real smiles      :  *NCC(CC(=O)NCCCCC)OC(*)=O
# predicted smiles :  *NCC(CC(=O)NCCCCC)OC(*)=O
# real smiles      :  *OC(C)(C)CCNC(*)=O
# predicted smiles :  *OC(C)(C)CCNC(*)=O
# real smiles      :  *NC(C)(C)C(=O)NCC(C)OC(*)=O
# predicted smiles :  *NC(C)(C)C(=O)NCC(C)OC(*)=O
# 1516 번째 다름!
# real smiles      :  *OCCCN(CCCNC)CCOC(*)=O
# predicted smiles :  *OCCCN(CCC)CCCOOC(*)=O
# real smiles      :  *OC(CCNC(*)=O)C(C)C
# predicted smiles :  *OC(CCNC(*)=O)C(C)C
# real smiles      :  *OCC(=O)NCC(CCC)CCOC(*)=O
# predicted smiles :  *OCC(=O)NCC(CCC)CCOC(*)=O
# real smiles      :  *OC(CNC(C)CCOC(*)=O)CC(C)C
# predicted smiles :  *OC(CNC(C)CCOC(*)=O)CC(C)C
# 1520 번째 다름!
# real smiles      :  *NCC(C)C(=O)NCC(CF)OC(*)=O
# predicted smiles :  *NCN(C)C(=O)NCC(CC)CC(*)=O
# 1521 번째 다름!
# real smiles      :  *OCC(=O)NCCCOCCOC(*)=O
# predicted smiles :  *OCC(=O)NCCCOOOOC(*)=O
# 1522 번째 다름!
# real smiles      :  *OC(C(C)OC(*)=O)P(=O)(O)O
# predicted smiles :  *OC(C(C)CC(*)=O)N(=C)(C)C
# real smiles      :  *NC(C)CCNC(=O)C(CNC(*)=O)OC
# predicted smiles :  *NC(C)CCNC(=O)C(CNC(*)=O)OC
# real smiles      :  *OC(CCC)CC(=O)NCCCOC(*)=O
# predicted smiles :  *OC(CCC)CC(=O)NCCCOC(*)=O
# 1525 번째 다름!
# real smiles      :  *OCCN(CCC=C)CCCOC(*)=O
# predicted smiles :  *OCCN(CC(=C)CCCOC(*)=O
# 1526 번째 다름!
# real smiles      :  *OC(C)(C)CONC(=O)C(=C)COC(*)=O
# predicted smiles :  *OC(C)(C)CNCC(=O)C(=C)COC(*)=O
# 1527 번째 다름!
# real smiles      :  *OC(C)(COC)C(=O)N(C)CCOC(*)=O
# predicted smiles :  *OC(C)(CON)C(=O)N(C)COOC(*)=O
# real smiles      :  *NCCCN(C)C(=O)C(C)(C)CNC(*)=O
# predicted smiles :  *NCCCN(C)C(=O)C(C)(C)CNC(*)=O
# real smiles      :  *OCCC(=O)NCC(CC(C)C)OC(*)=O
# predicted smiles :  *OCCC(=O)NCC(CC(C)C)OC(*)=O
# 1530 번째 다름!
# real smiles      :  *OCCC(C)SCC(C)(C)OC(*)=O
# predicted smiles :  *OCCC(C)CCC(C)(C)OC(*)=O
# 1531 번째 다름!
# real smiles      :  *OCC(NC(=CC)NC=N)C(C)OC(*)=O
# predicted smiles :  *OCC(CN(=)C)NCCC)C(C)OC(*)=O
# real smiles      :  *OCC(=C)CCOC(*)=O
# predicted smiles :  *OCC(=C)CCOC(*)=O
# 1533 번째 다름!
# real smiles      :  *NCCN(CCNC(*)=O)CC(=O)OCC
# predicted smiles :  *NCCN(CONC(*)=O)CC(=O)OOC
# 1534 번째 다름!
# real smiles      :  *NCC(NC(*)=O)C(=O)NCCON
# predicted smiles :  *NCC(CC(*)=O)C(=O)NCCCC
# real smiles      :  *OCCCCNC(=O)C(C)OC(*)=O
# predicted smiles :  *OCCCCNC(=O)C(C)OC(*)=O
# 1536 번째 다름!
# real smiles      :  *NC(C)CCNCC(C)(C=C)OC(*)=O
# predicted smiles :  *NC(C)CCNCC(C)((=C)OC(*)=O
# 1537 번째 다름!
# real smiles      :  *OCC(C)(C)NCC(OC(*)=O)C(=O)OC
# predicted smiles :  *OCC(C)(C)NCC(CC(*)=O)C(=O)OC
# 1538 번째 다름!
# real smiles      :  *OC(C)C(COC(*)=O)NC(=S)NCC
# predicted smiles :  *OC(C)C(COC(*)=O)NN(=C)NCC
# 1539 번째 다름!
# real smiles      :  *OC(CNC(*)=O)CC(=O)NCCNCC
# predicted smiles :  *OC(CNC(*)=O)NC(=O)NCCNCC
# 1540 번째 다름!
# real smiles      :  *OCC(COC(*)=O)NC(=O)CCCF
# predicted smiles :  *OCC(COC(*)=O)NC(=O)CC#N
# real smiles      :  *OC(CCNC(*)=O)C(=O)O
# predicted smiles :  *OC(CCNC(*)=O)C(=O)O
# real smiles      :  *NCC(C)CCCOC(*)=O
# predicted smiles :  *NCC(C)CCCOC(*)=O
# 1543 번째 다름!
# real smiles      :  *OC(C)(C)C(CCSC)NC(*)=O
# predicted smiles :  *OC(C)(C)C(C)CC)CC(*)=O
# 1544 번째 다름!
# real smiles      :  *OCC(CNC(C)CCCC#N)OC(*)=O
# predicted smiles :  *OCC(CNC(C)CCC##N)OC(*)=O
# real smiles      :  *NCCN(C)CCCCCOC(*)=O
# predicted smiles :  *NCCN(C)CCCCCOC(*)=O
# 1546 번째 다름!
# real smiles      :  *OC(COC(*)=O)CN(C)C(=O)C(=O)O
# predicted smiles :  *OC(COC(*)=O)CN(C)C(=O)C(=O)N
# real smiles      :  *NC(CNC(*)=O)C(=O)NCC(C)(F)F
# predicted smiles :  *NC(CNC(*)=O)C(=O)NCC(C)(F)F
# 1548 번째 다름!
# real smiles      :  *OC(COC(*)=O)COP(=O)(O)O
# predicted smiles :  *OC(COC(*)=O)CN#(=C)(F)F
# real smiles      :  *NC(C)(C)COC(*)=O
# predicted smiles :  *NC(C)(C)COC(*)=O
# real smiles      :  *OCC(=O)N(C)CC(C)(C)OC(*)=O
# predicted smiles :  *OCC(=O)N(C)CC(C)(C)OC(*)=O
# real smiles      :  *OCCCCNC(=O)CC(C)(C)NC(*)=O
# predicted smiles :  *OCCCCNC(=O)CC(C)(C)NC(*)=O
# 1552 번째 다름!
# real smiles      :  *NCCC(NC(*)=O)C(=O)N(CC)CC(=C)C
# predicted smiles :  *NCCC(CC(*)=O)C(=O)N(CC)CC(=C)C
# real smiles      :  *NC(C)(C)CCNC(C)CC(C)NC(*)=O
# predicted smiles :  *NC(C)(C)CCNC(C)CC(C)NC(*)=O
# real smiles      :  *NCC(CC(=O)NCC(C)NC(*)=O)OC
# predicted smiles :  *NCC(CC(=O)NCC(C)NC(*)=O)OC
# 1555 번째 다름!
# real smiles      :  *OCC(ONC(=O)C(C)OC(*)=O)C(C)C
# predicted smiles :  *OCC(CCC(=O)C(C)OC(*)=O)C(C)C
# 1556 번째 다름!
# real smiles      :  *OC(C)CCN(CCOC(*)=O)C(C)C
# predicted smiles :  *OC(C)CCN(COOC(*)=O)C(C)C
# 1557 번째 다름!
# real smiles      :  *OCCC(NCC(C)OC(*)=O)C(C)C
# predicted smiles :  *OCCC(COC(C)OC(*)=O)C(C)C
# real smiles      :  *OC(CC)CCNCC(C)OC(*)=O
# predicted smiles :  *OC(CC)CCNCC(C)OC(*)=O
# 1559 번째 다름!
# real smiles      :  *OC(C)C(C)NCC(C)(C)OC(*)=O
# predicted smiles :  *OC(C)C(C)NCN(C)(C)OC(*)=O
# 1560 번째 다름!
# real smiles      :  *OC(CCC)CC(=O)OCC(C)OC(*)=O
# predicted smiles :  *OC(CCC)CC(=O)CCC(C)OC(*)=O
# 1561 번째 다름!
# real smiles      :  *OC(C)CNCC(NC(*)=O)C(=O)OCC
# predicted smiles :  *OC(C)CNCC(CC(*)=O)C(=O)OOO
# real smiles      :  *OC(CCC)C(=O)NCC(C)(C)OC(*)=O
# predicted smiles :  *OC(CCC)C(=O)NCC(C)(C)OC(*)=O
# real smiles      :  *OC(C)CN(C)C(=O)CCCCOC(*)=O
# predicted smiles :  *OC(C)CN(C)C(=O)CCCCOC(*)=O
# real smiles      :  *OCCC(CCC)NC(C)CCOC(*)=O
# predicted smiles :  *OCCC(CCC)NC(C)CCOC(*)=O
# 1565 번째 다름!
# real smiles      :  *OCC(NC(N)=O)C(=O)NCCOC(*)=O
# predicted smiles :  *OCC(CC(C)=O)C(=O)NCOOC(*)=O
# 1566 번째 다름!
# real smiles      :  *OCC(CC#CC)NC(=O)CCOC(*)=O
# predicted smiles :  *OCC(CCCCC)NC(=O)CCOC(*)=O
# MAE :  0.1448651763518083

# %%
from rdkit import Chem, RDLogger
from rdkit.Chem import DataStructs, rdFingerprintGenerator
RDLogger.DisableLog('rdApp.error')

generator = rdFingerprintGenerator.GetMorganGenerator(radius=2, fpSize=2048)

def tanimoto_similarity(smiles1, smiles2):
    mol1 = Chem.MolFromSmiles(smiles1)
    mol2 = Chem.MolFromSmiles(smiles2)
    fp1 = generator.GetFingerprint(mol1)
    fp2 = generator.GetFingerprint(mol2)
    return DataStructs.TanimotoSimilarity(fp1, fp2)

def is_valid(smiles):
    return Chem.MolFromSmiles(smiles) is not None

TS = 0.0
canbe = 0
notbe = 0

for sm, orig in zip(results_smiles, origin_smiles):
    if is_valid(sm) and is_valid(orig):
        sim = tanimoto_similarity(sm, orig)
        TS += sim
        canbe += 1
    else:
        notbe += 1

if canbe > 0:
    print("Tanimoto Similarity : ", TS / canbe)
else:
    print("No valid molecules to compare.")

print("가능한 분자 개수 :", canbe)
print("불가능한 분자 개수 :", notbe)
print("Valid fraction      :", canbe / len(results_smiles))
# Out:
# Tanimoto Similarity :  0.7528875202999862
# 가능한 분자 개수 : 1112
# 불가능한 분자 개수 : 455
# Valid fraction      : 0.7096362476068921

# %%
for name, param in model.named_parameters():
    print(f"Layer: {name}, shape: {param.shape}")

state = model.state_dict()

# state 딕셔너리의 키 확인 (해당 키 이름은 named_parameters()와 동일)
print(state.keys())

# # conv1 레이어의 weight 추출
# conv1_weight = state['conv1.weight']
# print("conv1 weight shape from state_dict:", conv1_weight.shape)
# Out:
# Layer: to_means.weight, shape: torch.Size([64, 256])
# Layer: to_means.bias, shape: torch.Size([64])
# Layer: to_var.weight, shape: torch.Size([64, 256])
# Layer: to_var.bias, shape: torch.Size([64])
# Layer: to_decoder.weight, shape: torch.Size([256, 64])
# Layer: to_decoder.bias, shape: torch.Size([256])
# Layer: encoder.smiles_embbed.weight, shape: torch.Size([167, 256])
# Layer: encoder.encoder.weight_ih_l0, shape: torch.Size([1024, 256])
# Layer: encoder.encoder.weight_hh_l0, shape: torch.Size([1024, 256])
# Layer: encoder.encoder.bias_ih_l0, shape: torch.Size([1024])
# Layer: encoder.encoder.bias_hh_l0, shape: torch.Size([1024])
# Layer: encoder.encoder.weight_ih_l1, shape: torch.Size([1024, 256])
# Layer: encoder.encoder.weight_hh_l1, shape: torch.Size([1024, 256])
# Layer: encoder.encoder.bias_ih_l1, shape: torch.Size([1024])
# Layer: encoder.encoder.bias_hh_l1, shape: torch.Size([1024])
# Layer: decoder.to_memory.weight, shape: torch.Size([256, 64])
# Layer: decoder.to_memory.bias, shape: torch.Size([256])
# Layer: decoder.decoder.weight_ih_l0, shape: torch.Size([1024, 256])
# Layer: decoder.decoder.weight_hh_l0, shape: torch.Size([1024, 256])
# Layer: decoder.decoder.bias_ih_l0, shape: torch.Size([1024])
# Layer: decoder.decoder.bias_hh_l0, shape: torch.Size([1024])
# Layer: decoder.decoder.weight_ih_l1, shape: torch.Size([1024, 256])
# Layer: decoder.decoder.weight_hh_l1, shape: torch.Size([1024, 256])
# Layer: decoder.decoder.bias_ih_l1, shape: torch.Size([1024])
# Layer: decoder.decoder.bias_hh_l1, shape: torch.Size([1024])
# Layer: pdecoder.weight, shape: torch.Size([3, 17152])
# Layer: pdecoder.bias, shape: torch.Size([3])
# Layer: to_prop_z.weight, shape: torch.Size([3, 17152])
# Layer: to_prop_z.bias, shape: torch.Size([3])
# Layer: predict.weight, shape: torch.Size([167, 256])
# Layer: predict.bias, shape: torch.Size([167])
# Layer: input_embedding.0.weight, shape: torch.Size([64, 1])
# Layer: input_embedding.0.bias, shape: torch.Size([64])
# Layer: input_embedding.3.weight, shape: torch.Size([128, 64])
# Layer: input_embedding.3.bias, shape: torch.Size([128])
# Layer: input_embedding.6.weight, shape: torch.Size([256, 128])
# Layer: input_embedding.6.bias, shape: torch.Size([256])
# Layer: crossattn.multihead_attn.in_proj_weight, shape: torch.Size([192, 64])
# Layer: crossattn.multihead_attn.in_proj_bias, shape: torch.Size([192])
# Layer: crossattn.multihead_attn.out_proj.weight, shape: torch.Size([64, 64])
# Layer: crossattn.multihead_attn.out_proj.bias, shape: torch.Size([64])
# Layer: input_embedding_p.0.weight, shape: torch.Size([128, 1])
# Layer: input_embedding_p.0.bias, shape: torch.Size([128])
# Layer: input_embedding_p.2.weight, shape: torch.Size([64, 128])
# Layer: input_embedding_p.2.bias, shape: torch.Size([64])
# Layer: ff.0.weight, shape: torch.Size([32, 64])
# Layer: ff.0.bias, shape: torch.Size([32])
# Layer: ff.2.weight, shape: torch.Size([64, 32])
# Layer: ff.2.bias, shape: torch.Size([64])
# odict_keys(['to_means.weight', 'to_means.bias', 'to_var.weight', 'to_var.bias', 'to_decoder.weight', 'to_decoder.bias', 'encoder.smiles_embbed.weight', 'encoder.encoder.weight_ih_l0', 'encoder.encoder.weight_hh_l0', 'encoder.encoder.bias_ih_l0', 'encoder.encoder.bias_hh_l0', 'encoder.encoder.weight_ih_l1', 'encoder.encoder.weight_hh_l1', 'encoder.encoder.bias_ih_l1', 'encoder.encoder.bias_hh_l1', 'decoder.to_memory.weight', 'decoder.to_memory.bias', 'decoder.decoder.weight_ih_l0', 'decoder.decoder.weight_hh_l0', 'decoder.decoder.bias_ih_l0', 'decoder.decoder.bias_hh_l0', 'decoder.decoder.weight_ih_l1', 'decoder.decoder.weight_hh_l1', 'decoder.decoder.bias_ih_l1', 'decoder.decoder.bias_hh_l1', 'pdecoder.weight', 'pdecoder.bias', 'to_prop_z.weight', 'to_prop_z.bias', 'predict.weight', 'predict.bias', 'input_embedding.0.weight', 'input_embedding.0.bias', 'input_embedding.3.weight', 'input_embedding.3.bias', 'input_embedding.6.weight', 'input_embedding.6.bias', 'crossattn.multihead_attn.in_proj_weight', 'crossattn.multihead_attn.in_proj_bias', 'crossattn.multihead_attn.out_proj.weight', 'crossattn.multihead_attn.out_proj.bias', 'input_embedding_p.0.weight', 'input_embedding_p.0.bias', 'input_embedding_p.2.weight', 'input_embedding_p.2.bias', 'ff.0.weight', 'ff.0.bias', 'ff.2.weight', 'ff.2.bias'])

# %%
save_path = "model_weights_LSTM_MHA.pth"
torch.save(model.state_dict(), save_path)
save_path = "model_weights_LSTM_MHA_prior.pth"
torch.save(prior.state_dict(), save_path)

# %%
save_path = "model_weights_LSTM_MHA.pth"
state_dict = torch.load(save_path)
model.load_state_dict(state_dict)
save_path = "model_weights_LSTM_MHA_prior.pth"
state_dict = torch.load(save_path)
prior.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
tn_data = load_data("simulation-trajectory-aggregate_aligned.csv")

tn = DataLoader(tn_data, batch_size=128, shuffle=False, drop_last=False)
# Out:
# max sequence length :  265
# {'(': 0, ')': 1, '=': 2, '[O;!R;C]': 3, '[CH3;!R;C]': 4, '[CH2;!R;CN]': 5, '[CH2;!R;CC]': 6, '[CH2;!R;CO]': 7, '[*;!R;C]': 8, '[SOS]': 9, '[EOS]': 10, '[O;!R;CC]': 11, '[NH;!R;CC]': 12, '[*;!R;O]': 13, '[O;!R;*C]': 14, '[C;!R;*OO]': 15, '[CH;!R;CCO]': 16, '[CH;!R;CCN]': 17, '[C;!R;CNO]': 18, '[N;!R;CCC]': 19, '[C;!R;*NO]': 20, '[NH;!R;*C]': 21, '[*;!R;N]': 22, '[CH3;!R;N]': 23, '[CH;!R;CCC]': 24, '[C;!R;CCCO]': 25, '[CH;!R;CC]': 26, '[F;!R;C]': 27, '[CH2;!R;C]': 28, '[C;!R;COO]': 29, '[CH3;!R;O]': 30, '[C;!R;CCCN]': 31, '#': 32, '[C;!R;CCCC]': 33, '[CH2;!R;CS]': 34, '[C;!R;CC]': 35, '[OH;!R;C]': 36, '[S;!R;CC]': 37, '[N;!R;C]': 38, '[C;!R;CN]': 39, '[CH;!R;C]': 40, '[C;!R;CCC]': 41, '[NH2;!R;C]': 42, '[CH;!R;CFF]': 43, '[O;!R;S]': 44, '[O;!R;CN]': 45, '[CH;!R;CCS]': 46, '[CH2;!R;CF]': 47, '[CH3;!R;S]': 48, '[C;!R;CCO]': 49, '[NH;!R;CO]': 50, '[CH2;!R;*C]': 51, '[C;!R;NNO]': 52, '[C;!R;CFFF]': 53, '[C;!R;CCFF]': 54, '[C;!R;NOO]': 55, '[C;!R;OOO]': 56, '[S;!R;CCOO]': 57, '[CH3;!R;Si]': 58, '[C;!R;NNS]': 59, '[S;!R;C]': 60, '[NH;!R;C]': 61, '[Cl;!R;C]': 62, '[OH;!R;P]': 63, '1': 64, '[C;!R;CNN]': 65, '[CH;!R;CN]': 66, '[SH;!R;C]': 67, '[CH;!R;CCF]': 68, '[O;!R;P]': 69, '[CH2;!R;NO]': 70, '[O;R;CC]': 71, '[C;!R;CCCl]': 72, '[CH2;!R;CSi]': 73, '[CH;!R;NN]': 74, '[cH;R;CC]': 75, '[c;R;CCO]': 76, '[CH;!R;CO]': 77, '[Si;!R;CCCC]': 78, '[C;!R;CCN]': 79, '[N;!R;CN]': 80, '[NH;!R;CS]': 81, '[CH;!R;COO]': 82, '[N;!R;CCO]': 83, '[P;!R;COOO]': 84, '[C;!R;CCNN]': 85, '[N;!R;CO]': 86, '[CH;!R;CCl]': 87, '[S;!R;CNOO]': 88, '[C;!R;CCCF]': 89, '[CH2;!R;NSi]': 90, '[O;!R;CS]': 91, '[NH2;!R;O]': 92, '[NH;!R;CN]': 93, '[CH;R;CCO]': 94, '[CH2;R;CO]': 95, '[C;R;OOO]': 96, '[C;!R;CCF]': 97, '[C;!R;CCOO]': 98, '[N;!R;CCN]': 99, '[N;!R;CS]': 100, '[S;!R;CCNO]': 101, '[OH;!R;N]': 102, '[C;!R;NNN]': 103, '[S;!R;CCO]': 104, '[CH2;!R;CP]': 105, '[CH;!R;CNP]': 106, '[OH;!R;S]': 107, '[NH2;!R;N]': 108, '[N;!R;CC]': 109, '[Si;!R;*CCC]': 110, '[*;!R;Si]': 111, '[CH;!R;CS]': 112, '[C;!R;*CO]': 113, '[S;!R;COOO]': 114, '[O;!R;CP]': 115, '[S;!R;NNOO]': 116, '[NH2;!R;S]': 117, '[CH;R;*CN]': 118, '[N;R;CCC]': 119, '2': 120, '[CH2;!R;OO]': 121, '[C;!R;NN]': 122, 'N': 123, '[S;!R;COOS]': 124, '[S;!R;S]': 125, '[C;!R;CCCS]': 126, '[CH2;!R;NS]': 127, '[P;!R;OOOO]': 128, '[CH;!R;CNO]': 129, '[S;!R;OOO]': 130, '[O;!R;*S]': 131, '[CH2;!R;SS]': 132, '[CH;!R;FFO]': 133, '[CH2;!R;OP]': 134, '[C;!R;NSS]': 135, '[CH;!R;COP]': 136, '[C;!R;CFFO]': 137, '[CH;!R;CNS]': 138, '[c;R;CCC]': 139, '[CH;!R;CNN]': 140, '[C;!R;CSi]': 141, '[C;R;NNO]': 142, '[c;R;*CC]': 143, '[CH;!R;*CC]': 144, '[CH2;!R;NN]': 145, '[[N+]': 146, 'O': 147, '[[O-]': 148, '[N;!R;NO]': 149, '[CH;!R;NO]': 150, '[CH2;!R;OSi]': 151, '[CH;!R;NNN]': 152, '[P;!R;CCOO]': 153, '[C;!R;CClCl]': 154, '[C;!R;CCNO]': 155, '[C;!R;COS]': 156, '[N;!R;CCS]': 157, '[C;!R;CCCCl]': 158, '[C;!R;CCFO]': 159, '[C;!R;CCOP]': 160, '[SH;!R;O]': 161, '[S;!R;OOOO]': 162, '[C;!R;OSS]': 163, '[C;!R;CCClCl]': 164, '[PH;!R;CCO]': 165, '[PAD]': 166}
# vocab size :  167
# number of data :  6270
# torch.Size([6270, 265])
# torch.Size([6270, 3, 1])
# PSMILES :  CC(CCO[*])SCCOCCOC(=O)[*]
# After AIS encoding :  [*;!R;O] [O;!R;*C] [CH2;!R;CO] [CH2;!R;CC] [CH;!R;CCS] ( [CH3;!R;C] ) [S;!R;CC] [CH2;!R;CS] [CH2;!R;CO] [O;!R;CC] [CH2;!R;CO] [CH2;!R;CO] [O;!R;CC] [C;!R;*OO] ( [*;!R;C] ) = [O;!R;C]
# After AIS Tokenization :  ['[*;!R;O]', '[O;!R;*C]', '[CH2;!R;CO]', '[CH2;!R;CC]', '[CH;!R;CCS]', '(', '[CH3;!R;C]', ')', '[S;!R;CC]', '[CH2;!R;CS]', '[CH2;!R;CO]', '[O;!R;CC]', '[CH2;!R;CO]', '[CH2;!R;CO]', '[O;!R;CC]', '[C;!R;*OO]', '(', '[*;!R;C]', ')', '=', '[O;!R;C]']
# After to number :  tensor([ 13,  14,   7,   6,  46,   0,   4,   1,  37,  34,   7,  11,   7,   7,
#          11,  15,   0,   8,   1,   2,   3, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166,
#         166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166, 166])
# Properties :  tensor([[[21.4449],
#          [ 4.5924],
#          [ 1.1573]],
#
#         [[18.7248],
#          [-0.4077],
#          [ 1.4020]],
#
#         [[16.2511],
#          [-1.9703],
#          [ 1.0559]],
#
#         ...,
#
#         [[-1.1692],
#          [-0.7202],
#          [ 0.7727]],
#
#         [[-1.1754],
#          [-0.4077],
#          [ 1.0979]],
#
#         [[-1.2428],
#          [-0.4077],
#          [ 0.0311]]])
# 265

# %%
model.eval()
prior.eval()
results = []
origin = []
z_tn = []
mean_tn = []
log_var_tn = []
mu_p_tn=[]
var_p_tn=[]
prop=[]
with torch.no_grad():
    for (smiles_enc, smiles_dec_input, smiles_dec_output, properties) in tn:

        smiles_enc = smiles_enc.to(device)
        smiles_dec_input = smiles_dec_input.to(device)
        smiles_dec_output = smiles_dec_output.to(device)
        properties = properties.to(device)

        result, tgt, means, log_var, z = model(smiles_enc, smiles_dec_input, properties)
        mu_p, logvar_p = prior(properties.squeeze())

        mean_tn.append(means)
        log_var_tn.append(log_var)
        z_tn.append(z)
        mu_p_tn.append(mu_p)
        var_p_tn.append(logvar_p)
        prop.append(properties)

# %%
z_tn = torch.cat(z_tn, dim=0)
mean_tn = torch.cat(mean_tn, dim=0)
log_var_tn = torch.cat(log_var_tn, dim=0)
mu_p_tn = torch.cat(mu_p_tn, dim=0)
logvar_p_tn = torch.cat(var_p_tn, dim=0)
prop = torch.cat(prop, dim=0)

# %%
print(z_tn.shape)
print(mean_tn.shape)
print(log_var_tn.shape)
# Out:
# torch.Size([6270, 3])
# torch.Size([6270, 268, 64])
# torch.Size([6270, 268, 64])

# %%
z = model.reparameterize(mean_tn, log_var_tn)
z_p = model.reparameterize(mu_p_tn, logvar_p_tn)

prop = model.input_embedding_p(prop)

z_ff = model.crossattn(z, prop, prop)
z_ff = model.ff(z_ff)
z_p_ff = model.crossattn(z_p, prop, prop)
z_p_ff = model.ff(z_p_ff)

# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from matplotlib.colors import LogNorm
import umap.umap_ as UMAP
tsne = TSNE(n_components=2, perplexity=50, random_state=42)
umap = UMAP.UMAP(random_state=42, n_neighbors=150)



# posterior mean
X = mean_tn.mean(1).detach().cpu().numpy()
X_scaled = StandardScaler().fit_transform(X)
X_pca    = PCA(n_components=50, random_state=42).fit_transform(X_scaled)
print(X.shape)
reduced = umap.fit_transform(X_pca)
print(reduced.shape)

# prior mean
X_p = mu_p_tn.mean(1).detach().cpu().numpy()
X_p_scaled = StandardScaler().fit_transform(X_p)
X_p_pca    = PCA(n_components=50, random_state=42).fit_transform(X_p_scaled)
print(X.shape)
reduced_p = umap.fit_transform(X_p_pca)
print(reduced_p.shape)

# posterior z
X_z = z.mean(1).detach().cpu().numpy()
X_z_scaled = StandardScaler().fit_transform(X_z)
X_z_pca    = PCA(n_components=50, random_state=42).fit_transform(X_z_scaled)
print(X.shape)
reduced_z = umap.fit_transform(X_z_pca)

# prior z
X_z_p = z_p.mean(1).detach().cpu().numpy()
X_z_p_scaled = StandardScaler().fit_transform(X_z_p)
X_z_p_pca    = PCA(n_components=50, random_state=42).fit_transform(X_z_p_scaled)
print(X.shape)
reduced_z_p = umap.fit_transform(X_z_p_pca)

# posterior z (with ff)
X_z_ff = z_ff.mean(1).detach().cpu().numpy()
X_z_ff_scaled = StandardScaler().fit_transform(X_z_ff)
X_z_ff_pca    = PCA(n_components=50, random_state=42).fit_transform(X_z_ff_scaled)
print(X_z_ff.shape)
reduced_z_ff = umap.fit_transform(X_z_ff_pca)

# prior z (with ff)
X_z_p_ff = z_p_ff.mean(1).detach().cpu().numpy()
X_z_p_ff_scaled = StandardScaler().fit_transform(X_z_p_ff)
X_z_p_ff_pca    = PCA(n_components=50, random_state=42).fit_transform(X_z_p_ff_scaled)
print(X.shape)
reduced_z_p_ff = umap.fit_transform(X_z_p_ff_pca)
# Out:
# (6270, 64)
# /home/kiket/torch.venv/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/kiket/torch.venv/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# (6270, 2)
# (6270, 64)
# /home/kiket/torch.venv/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# (6270, 2)
# (6270, 64)
# /home/kiket/torch.venv/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# (6270, 64)
# /home/kiket/torch.venv/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# (6270, 64)
# /home/kiket/torch.venv/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# (6270, 64)
# /home/kiket/torch.venv/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
# Step 1: 라벨 생성
df = pd.read_csv("simulation-trajectory-aggregate_aligned.csv")
labels = df.iloc[:, 6:7].values.squeeze()
vmin, vmax = labels.min(), labels.max()  # 대개 -1.0, 0.5

#posterior mean
# --------------------- latent space plot with T-SNE ------------
plt.figure(figsize=(8, 6))
scatter = plt.scatter(reduced[:, 0], reduced[:, 1], 
                      c=labels, cmap='viridis', s=10, alpha=0.7,
                      norm=LogNorm(vmin=vmin, vmax=vmax) )  # 범위는 labels 값에 맞게

cbar = plt.colorbar(scatter)
cbar.set_label("Li+ Conductivity")

plt.xlabel("t-SNE 1")
plt.ylabel("t-SNE 2")
plt.tight_layout()
plt.show()

#posterior z
# --------------------- latent space plot with T-SNE ------------
plt.figure(figsize=(8, 6))
scatter = plt.scatter(reduced_z[:, 0], reduced_z[:, 1],
                      c=labels, cmap='viridis', s=10, alpha=0.7,
                      norm=LogNorm(vmin=vmin, vmax=vmax))  # 범위는 labels 값에 맞게



# Step 7: 컬러바 커스터마이징
cbar = plt.colorbar(scatter, ticks=np.arange(5))
cbar.ax.set_yticklabels(["-1.64", "0.00",  "0.22", "0.50", "1.10"])
cbar.set_label("Li+ Conductivity")

plt.xlabel("t-SNE 1")
plt.ylabel("t-SNE 2")
plt.tight_layout()
plt.show()

#posterior z (with ff)
# --------------------- latent space plot with T-SNE ------------
plt.figure(figsize=(8, 6))
scatter = plt.scatter(reduced_z_ff[:, 0], reduced_z_ff[:, 1],
                      c=labels, cmap='viridis', s=10, alpha=0.7,
                      norm=LogNorm(vmin=vmin, vmax=vmax))  # 범위는 labels 값에 맞게



# Step 7: 컬러바 커스터마이징
cbar = plt.colorbar(scatter, ticks=np.arange(5))
cbar.ax.set_yticklabels(["-1.64", "0.00",  "0.22", "0.50", "1.10"])
cbar.set_label("Li+ Conductivity")

plt.xlabel("t-SNE 1")
plt.ylabel("t-SNE 2")
plt.tight_layout()
plt.show()

# %%
from sklearn.linear_model import LinearRegression
df = pd.read_csv("simulation-trajectory-aggregate_aligned.csv")
cond = df.iloc[:,6:7].values.squeeze()
# μ 분산
mu_std = mean_tn.detach().view(-1, 64).std(0).mean()   # 목표 0.15-0.35
print(mu_std.item())
# z → conductivity 선형 R²
z_sent = z.detach().mean(1)
r2 = LinearRegression().fit(z_sent.cpu(), cond).score(z_sent.cpu(), cond)  # 목표 ≥0.3
print(r2)
# raw KLD per token
print(kld_raw.item())                                # 목표 capacity(0.2)+α
# Out:
# 0.14879661798477173
# 0.83290890006149
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 12
#      10 print(r2)
#      11 # raw KLD per token
# ---> 12 print(kld_raw.item())                                # 목표 capacity(0.2)+α
#
# NameError: name 'kld_raw' is not defined

# %%
#prior mean
# --------------------- latent space plot with T-SNE ------------
plt.figure(figsize=(8, 6))
scatter = plt.scatter(reduced_p[:, 0], reduced_p[:, 1],
                      c=labels, cmap='viridis', s=10, alpha=0.7,
                      norm=LogNorm(vmin=vmin, vmax=vmax) )  # 범위는 labels 값에 맞게


# Step 7: 컬러바 커스터마이징
cbar = plt.colorbar(scatter, ticks=np.arange(5))
cbar.ax.set_yticklabels(["-1.64", "0.00",  "0.22", "0.50", "1.10"])
cbar.set_label("Li+ Conductivity")


plt.xlabel("t-SNE 1")
plt.ylabel("t-SNE 2")
plt.tight_layout()
plt.show()

#prior z
# --------------------- latent space plot with T-SNE ------------
plt.figure(figsize=(8, 6))
scatter = plt.scatter(reduced_z_p[:, 0], reduced_z_p[:, 1],
                      c=labels, cmap='viridis', s=10, alpha=0.7,
                      norm=LogNorm(vmin=vmin, vmax=vmax) )  # 범위는 labels 값에 맞게


# Step 7: 컬러바 커스터마이징
cbar = plt.colorbar(scatter, ticks=np.arange(5))
cbar.ax.set_yticklabels(["-1.64", "0.00",  "0.22", "0.50", "1.10"])
cbar.set_label("Li+ Conductivity")

plt.xlabel("t-SNE 1")
plt.ylabel("t-SNE 2")
plt.tight_layout()
plt.show()

#prior z (with ff)
# --------------------- latent space plot with T-SNE ------------
plt.figure(figsize=(8, 6))
scatter = plt.scatter(reduced_z_p_ff[:, 0], reduced_z_p_ff[:, 1],
                      c=labels, cmap='viridis', s=10, alpha=0.7,
                      norm=LogNorm(vmin=vmin, vmax=vmax) )  # 범위는 labels 값에 맞게


# Step 7: 컬러바 커스터마이징
cbar = plt.colorbar(scatter, ticks=np.arange(5))
cbar.ax.set_yticklabels(["-1.64", "0.00",  "0.22", "0.50", "1.10"])
cbar.set_label("Li+ Conductivity")

plt.xlabel("t-SNE 1")
plt.ylabel("t-SNE 2")
plt.tight_layout()
plt.show()

# %%
import math, random, torch, torch.nn.functional as F
from torch.distributions.normal import Normal
from scipy.linalg import sqrtm    # (W2 계산용)

PAD_IDX = 166
DEVICE  = next(model.parameters()).device       # 이미 학습된 model, prior 사용

# -------------------------------------------------------------
# 0. 헬퍼 함수
# -------------------------------------------------------------
def decode_tokens(model, z, properties):
    prop_p = model.input_embedding_p(properties)
    z_z    = model.crossattn(z, prop_p, prop_p)
    z_z    = model.ff(z_z)
    dec    = model.decoder(z_z)
    return model.predict(dec)                  # [B, L, vocab]

def log_px_z(logits, target):
    ll = -F.cross_entropy(
        logits.transpose(1, 2), target,
        reduction='none', ignore_index=PAD_IDX
    )
    return ll.sum(dim=1)                       # [B]

@torch.no_grad()
def iwae_bound(model, prior, sm_enc, sm_dec_tgt, props, K=64):
    enc   = model.encoder(sm_enc, model.input_embedding(props))
    mu_q, lv_q = model.to_means(enc), model.to_var(enc)
    q     = Normal(mu_q, (0.5 * lv_q).exp())          # [B,L,D]
    mu_p, lv_p = prior(props.squeeze())
    p     = Normal(mu_p, (0.5 * lv_p).exp())

    log_ws = []
    for _ in range(K):
        z       = q.rsample()
        logits  = decode_tokens(model, z, props)
        log_px  = log_px_z(logits, sm_dec_tgt)         # [B]
        log_qz  = q.log_prob(z).sum((1, 2))
        log_pz  = p.log_prob(z).sum((1, 2))
        log_ws.append(log_px + log_pz - log_qz)        # [B]

    log_ws = torch.stack(log_ws)                       # [K,B]
    return torch.logsumexp(log_ws, 0) - math.log(K)    # [B]

@torch.no_grad()
def kl_decompose_minibatch(mu_b, lv_b, dataset_size):
    m, D = mu_b.size()
    q    = Normal(mu_b, (0.5 * lv_b).exp())
    z    = q.rsample()                                 # [m, D]

    log_q_ij = (-0.5 * (
        ((z[:, None] - mu_b[None]) ** 2) / lv_b.exp()[None]
        + lv_b[None] + math.log(2 * math.pi)
    ).sum(-1))                                         # [m, m]

    log_qz        = torch.logsumexp(log_q_ij, dim=1) - math.log(dataset_size)
    log_qz_prod   = q.log_prob(z).sum(-1)
    log_pz        = Normal(0, 1).log_prob(z).sum(-1)

    mi = (q.log_prob(z).sum(-1) - log_qz).mean()
    tc = (log_qz - log_qz_prod).mean()
    dw = (log_qz_prod - log_pz).mean()
    return {'MI': mi.item(), 'TC': tc.item(), 'DimKL': dw.item()}

def active_units(mu, eps=1e-2):
    return (mu.var(0) > eps).sum().item()

def _rbf(x, sigma):
    diff2 = ((x[:, None] - x[None]) ** 2).sum(-1)
    return torch.exp(-diff2 / (2 * sigma ** 2))

# ---------------------------------------------------
# RFF 기반 HSIC  (unbiased, ^2-norm kernel)
# ---------------------------------------------------
def hsic_rff(x, y, num_feat=512, sigma=1.0):
    """
    x: [N, Dx], y: [N, Dy]  (GPU or CPU)
    """
    N, Dx = x.size(); Dy = y.size(1)
    w_x = torch.randn(Dx, num_feat, device=x.device) / sigma
    w_y = torch.randn(Dy, num_feat, device=y.device) / sigma
    b_x = 2 * math.pi * torch.rand(num_feat, device=x.device)
    b_y = 2 * math.pi * torch.rand(num_feat, device=y.device)

    z_x = (x  @ w_x + b_x).cos() * math.sqrt(2 / num_feat)   # [N, F]
    z_y = (y  @ w_y + b_y).cos() * math.sqrt(2 / num_feat)

    z_xc = z_x - z_x.mean(0, keepdim=True)                   # center
    z_yc = z_y - z_y.mean(0, keepdim=True)
    return (z_xc * z_yc).sum().pow(2) / (N - 1) ** 2         # scalar

def get_random_batch(dataloader):
    idx = random.randrange(len(dataloader))
    for i, batch in enumerate(dataloader):
        if i == idx:
            return batch

# -------------------------------------------------------------
# 1. 무작위 배치 가져오기
# -------------------------------------------------------------
batch = get_random_batch(val_dataloader)       # (*batch 형태에 맞게 수정*)
sm_enc, _, sm_dec_tgt, props = (t.to(DEVICE) for t in batch)

# -------------------------------------------------------------
# 2. IWAE
# -------------------------------------------------------------
iwae = iwae_bound(model, prior, sm_enc, sm_dec_tgt, props).mean().item()
print(f"IWAE  : {iwae:.3f}")

# -------------------------------------------------------------
# 3. posterior 파라미터 & z 샘플
# -------------------------------------------------------------
with torch.no_grad():
    enc  = model.encoder(sm_enc, model.input_embedding(props))
    mu_q = model.to_means(enc)                       # [B,L,64]
    lv_q = model.to_var(enc)
    z    = model.reparameterize(mu_q, lv_q)          # [B,L,64]

mu_flat = mu_q.reshape(-1, 64).cpu()                 # [N,D] → CPU
lv_flat = lv_q.reshape(-1, 64).cpu()

# ----- KL 분해 (서브샘플 4096개) --------------------------
m = min(4096, mu_flat.size(0))
sub_idx   = torch.randint(0, mu_flat.size(0), (m,))
mu_sub, lv_sub = mu_flat[sub_idx].to(DEVICE), lv_flat[sub_idx].to(DEVICE)

dataset_size = len(val_dataloader.dataset)
kl_stats = kl_decompose_minibatch(mu_sub, lv_sub, dataset_size)
print("KL-decomp:", kl_stats)

# ----- Active Units --------------------------------------
au = active_units(mu_flat)
print(f"Active Units: {au}")

# -------------------------------------------------
# 1. z 플랫
# -------------------------------------------------
z_flat = z.reshape(-1, z.size(-1))           # [B*L, 64]

# -------------------------------------------------
# 2. props -> [B, P] 로 만든 뒤 토큰 수만큼 복제
#    (props 가 [B, 1] 이든 [B, 3] 이든 자동 처리)
# -------------------------------------------------
props_2d = props.reshape(props.size(0), -1)   # [B, P]
cond_flat = props_2d.repeat_interleave(z.size(1), 0)  # [B*L, P]

# -------------------------------------------------
# 3. HSIC(RFF) 계산
# -------------------------------------------------
m_rff = 1024          # feature 개수
sigma = 1.0

hsic_score = hsic_rff(z_flat, cond_flat, num_feat=m_rff, sigma=sigma).item()
print(f"HSIC_RFF(z,c): {hsic_score:.4f}")
# Out:
# IWAE  : -14090.165
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[19], line 128
#     125 mu_sub, lv_sub = mu_flat[sub_idx].to(DEVICE), lv_flat[sub_idx].to(DEVICE)
#     127 dataset_size = len(val_dataloader.dataset)
# --> 128 kl_stats = kl_decompose_minibatch(mu_sub, lv_sub, dataset_size)
#     129 print("KL-decomp:", kl_stats)
#     131 # ----- Active Units --------------------------------------
#
# File ~/torch.venv/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# Cell In[19], line 52, in kl_decompose_minibatch(mu_b, lv_b, dataset_size)
#      48 q    = Normal(mu_b, (0.5 * lv_b).exp())
#      49 z    = q.rsample()                                 # [m, D]
#      51 log_q_ij = (-0.5 * (
# ---> 52     ((z[:, None] - mu_b[None]) ** 2) / lv_b.exp()[None]
#      53     + lv_b[None] + math.log(2 * math.pi)
#      54 ).sum(-1))                                         # [m, m]
#      56 log_qz        = torch.logsumexp(log_q_ij, dim=1) - math.log(dataset_size)
#      57 log_qz_prod   = q.log_prob(z).sum(-1)
#
# File ~/torch.venv/lib/python3.12/site-packages/torch/_tensor.py:39, in _handle_torch_function_and_wrap_type_error_to_not_implemented.<locals>.wrapped(*args, **kwargs)
#      37     if has_torch_function(args):
#      38         return handle_torch_function(wrapped, args, *args, **kwargs)
# ---> 39     return f(*args, **kwargs)
#      40 except TypeError:
#      41     return NotImplemented
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 4.00 GiB. GPU 0 has a total capacity of 15.48 GiB of which 536.75 MiB is free. Including non-PyTorch memory, this process has 12.12 GiB memory in use. Of the allocated memory 11.19 GiB is allocated by PyTorch, and 676.19 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
cond_flat.std(0)
# Out:
# tensor([0.8256, 0.6990, 0.7645], device='cuda:0')
